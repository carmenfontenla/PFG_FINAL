# %%
import pandas as pd
import numpy as np
import matplotlib.patches as mpatches
import matplotlib.pyplot as plt
import seaborn as sns
from prophet import Prophet
from sklearn.preprocessing import LabelEncoder
from datetime import datetime, timedelta
import statsmodels.api as sm
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import PowerTransformer
from scipy.stats import poisson
import datetime as dt
import matplotlib.pyplot as plt
import statsmodels as st
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.api import ExponentialSmoothing, SimpleExpSmoothing, Holt
import statsmodels.api as sm
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
import seaborn as sns
from tabulate import tabulate
import pmdarima as pm
from dateutil.relativedelta import relativedelta
from keras.models import Sequential
from keras.layers import Dense,Activation,Flatten
from sklearn.preprocessing import MinMaxScaler

# %%
df = pd.read_csv('Datos_preprocesados_accidentes_y_victimas_accidentes.csv')

# %%
db_provincia40 = df[df['COD_PROVINCIA'] == 40]

# %%
num_victimas_dia_semana40 = db_provincia40.groupby(['ANYO', 'MES', 'DIA_SEMANA'])['TOTAL_VICTIMAS_24H'].sum()

# %%
num_victimas_dia_semana40 = num_victimas_dia_semana40.reset_index()

# %%
num_victimas_dia_semana40['FECHA'] = num_victimas_dia_semana40.apply(lambda row: str(row['ANYO']) + '/' + str(row['MES']) + '/' + str(row['DIA_SEMANA']), axis = 1)

# %%
num_accidentes_por_dia_semana40 = db_provincia40.groupby(['ANYO', 'MES'])['DIA_SEMANA'].value_counts()

# %%
num_accidentes_por_dia_semana40
# Out:
# ANYO  MES  DIA_SEMANA
# 2016  1    6             6
#            4             4
#            7             4
#            1             3
#            5             2
#                         ..
# 2020  12   3             4
#            4             4
#            5             4
#            6             4
#            2             2
# Name: count, Length: 400, dtype: int64

# %%
plt.plot(num_accidentes_por_dia_semana40.values)

# %%
plt.plot(num_victimas_dia_semana40['TOTAL_VICTIMAS_24H'])

# %%
num_accidentes_por_dia_semana40 = num_accidentes_por_dia_semana40.reset_index()

# %%
num_accidentes_por_dia_semana40['FECHA'] = num_accidentes_por_dia_semana40.apply(lambda row: str(row['ANYO']) + '/' + str(row['MES']) + '/' + str(row['DIA_SEMANA']), axis = 1)

# %%
num_accidentes_por_dia_semana40
# Out:
#      ANYO  MES  DIA_SEMANA  count      FECHA
# 0    2016    1           6      6   2016/1/6
# 1    2016    1           4      4   2016/1/4
# 2    2016    1           7      4   2016/1/7
# 3    2016    1           1      3   2016/1/1
# 4    2016    1           5      2   2016/1/5
# ..    ...  ...         ...    ...        ...
# 395  2020   12           3      4  2020/12/3
# 396  2020   12           4      4  2020/12/4
# 397  2020   12           5      4  2020/12/5
# 398  2020   12           6      4  2020/12/6
# 399  2020   12           2      2  2020/12/2
#
# [400 rows x 5 columns]

# %%
num_victimas_dia_semana40 = num_victimas_dia_semana40.reset_index()

# %%
num_victimas_dia_semana40
# Out:
#      index  ANYO  MES  DIA_SEMANA  TOTAL_VICTIMAS_24H      FECHA
# 0        0  2016    1           1                   3   2016/1/1
# 1        1  2016    1           3                   1   2016/1/3
# 2        2  2016    1           4                   4   2016/1/4
# 3        3  2016    1           5                   3   2016/1/5
# 4        4  2016    1           6                   6   2016/1/6
# ..     ...   ...  ...         ...                 ...        ...
# 395    395  2020   12           2                   2  2020/12/2
# 396    396  2020   12           3                   6  2020/12/3
# 397    397  2020   12           4                   4  2020/12/4
# 398    398  2020   12           5                   4  2020/12/5
# 399    399  2020   12           6                   5  2020/12/6
#
# [400 rows x 6 columns]

# %%
num_victimas_dia_semana40['FECHA'] = num_victimas_dia_semana40.apply(lambda row: str(row['ANYO']) + '/' + str(row['MES']) + '/' + str(row['DIA_SEMANA']), axis = 1)

# %%
num_victimas_dia_semana40
# Out:
#      index  ANYO  MES  DIA_SEMANA  TOTAL_VICTIMAS_24H      FECHA
# 0        0  2016    1           1                   3   2016/1/1
# 1        1  2016    1           3                   1   2016/1/3
# 2        2  2016    1           4                   4   2016/1/4
# 3        3  2016    1           5                   3   2016/1/5
# 4        4  2016    1           6                   6   2016/1/6
# ..     ...   ...  ...         ...                 ...        ...
# 395    395  2020   12           2                   2  2020/12/2
# 396    396  2020   12           3                   6  2020/12/3
# 397    397  2020   12           4                   4  2020/12/4
# 398    398  2020   12           5                   4  2020/12/5
# 399    399  2020   12           6                   5  2020/12/6
#
# [400 rows x 6 columns]

# %%
num_accidentes_por_dia_semana40
# Out:
#      ANYO  MES  DIA_SEMANA  count      FECHA
# 0    2016    1           6      6   2016/1/6
# 1    2016    1           4      4   2016/1/4
# 2    2016    1           7      4   2016/1/7
# 3    2016    1           1      3   2016/1/1
# 4    2016    1           5      2   2016/1/5
# ..    ...  ...         ...    ...        ...
# 395  2020   12           3      4  2020/12/3
# 396  2020   12           4      4  2020/12/4
# 397  2020   12           5      4  2020/12/5
# 398  2020   12           6      4  2020/12/6
# 399  2020   12           2      2  2020/12/2
#
# [400 rows x 5 columns]

# %%
num_victimas_dia_semana40
# Out:
#      index  ANYO  MES  DIA_SEMANA  TOTAL_VICTIMAS_24H      FECHA
# 0        0  2016    1           1                   3   2016/1/1
# 1        1  2016    1           3                   1   2016/1/3
# 2        2  2016    1           4                   4   2016/1/4
# 3        3  2016    1           5                   3   2016/1/5
# 4        4  2016    1           6                   6   2016/1/6
# ..     ...   ...  ...         ...                 ...        ...
# 395    395  2020   12           2                   2  2020/12/2
# 396    396  2020   12           3                   6  2020/12/3
# 397    397  2020   12           4                   4  2020/12/4
# 398    398  2020   12           5                   4  2020/12/5
# 399    399  2020   12           6                   5  2020/12/6
#
# [400 rows x 6 columns]

# %%
df_provincia40 = num_accidentes_por_dia_semana40.merge(num_victimas_dia_semana40, on = 'FECHA')

# %%
df_provincia40 = df_provincia40[['ANYO_x', 'FECHA', 'count', 'TOTAL_VICTIMAS_24H']]

# %%
df_provincia40.describe()
# Out:
#             ANYO_x       count  TOTAL_VICTIMAS_24H
# count   400.000000  400.000000          400.000000
# mean   2017.960000    3.790000            5.372500
# std       1.399391    2.054618            3.486277
# min    2016.000000    1.000000            1.000000
# 25%    2017.000000    2.000000            3.000000
# 50%    2018.000000    3.000000            5.000000
# 75%    2019.000000    5.000000            7.000000
# max    2020.000000   11.000000           33.000000

# %% [markdown]
# # PREDICCION DE NÚMERO DE ACCIDENTES

# %% [markdown]
# ### MODELO PROPHET

# %%
df_provincia40['y'] = df_provincia40['count']
df_provincia40['ds'] = pd.to_datetime(pd.to_datetime(df_provincia40['FECHA']).dt.date)

# %%
ts = df_provincia40[['ds', 'y']]
model = Prophet(
   yearly_seasonality=True,
   seasonality_mode=['additive','multiplicative'][0]
   ).add_country_holidays(country_name='ESP'
   ).fit(ts)

future = model.make_future_dataframe(periods=10)
forecast = model.predict(future)
fig1 = model.plot(forecast)
# Out:
# 21:14:46 - cmdstanpy - INFO - Chain [1] start processing
# 21:14:46 - cmdstanpy - INFO - Chain [1] done processing
# c:\Users\---\AppData\Local\Programs\Python\Python312\Lib\site-packages\prophet\plot.py:72: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   fcst_t = fcst['ds'].dt.to_pydatetime()
# c:\Users\---\AppData\Local\Programs\Python\Python312\Lib\site-packages\prophet\plot.py:73: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   ax.plot(m.history['ds'].dt.to_pydatetime(), m.history['y'], 'k.',

# %%
fig2 = model.plot_components(forecast)
# Out:
# c:\Users\---\AppData\Local\Programs\Python\Python312\Lib\site-packages\prophet\plot.py:228: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   fcst_t = fcst['ds'].dt.to_pydatetime()
# c:\Users\---\AppData\Local\Programs\Python\Python312\Lib\site-packages\prophet\plot.py:351: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   df_y['ds'].dt.to_pydatetime(), seas[name], ls='-', c='#0072B2')
# c:\Users\---\AppData\Local\Programs\Python\Python312\Lib\site-packages\prophet\plot.py:354: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   df_y['ds'].dt.to_pydatetime(), seas[name + '_lower'],

# %%
from prophet.diagnostics import cross_validation
df_cv = cross_validation(model, initial='336 days', period='84 days', horizon = '20 days')
# Out:
# Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
#   0%|          | 0/16 [00:00<?, ?it/s]21:14:47 - cmdstanpy - INFO - Chain [1] start processing
# 21:14:47 - cmdstanpy - INFO - Chain [1] done processing
#   6%|▋         | 1/16 [00:00<00:05,  2.76it/s]21:14:47 - cmdstanpy - INFO - Chain [1] start processing
# 21:14:47 - cmdstanpy - INFO - Chain [1] done processing
#  12%|█▎        | 2/16 [00:00<00:03,  4.00it/s]21:14:47 - cmdstanpy - INFO - Chain [1] start processing
# 21:14:47 - cmdstanpy - INFO - Chain [1] done processing
#  19%|█▉        | 3/16 [00:00<00:02,  4.89it/s]21:14:47 - cmdstanpy - INFO - Chain [1] start processing
# 21:14:47 - cmdstanpy - INFO - Chain [1] done processing
#  25%|██▌       | 4/16 [00:00<00:02,  5.48it/s]21:14:47 - cmdstanpy - INFO - Chain [1] start processing
# 21:14:47 - cmdstanpy - INFO - Chain [1] done processing
#  31%|███▏      | 5/16 [00:01<00:02,  5.46it/s]21:14:48 - cmdstanpy - INFO - Chain [1] start processing
# 21:14:48 - cmdstanpy - INFO - Chain [1] done processing
#  38%|███▊      | 6/16 [00:01<00:01,  5.65it/s]21:14:48 - cmdstanpy - INFO - Chain [1] start processing
# 21:14:48 - cmdstanpy - INFO - Chain [1] done processing
#  44%|████▍     | 7/16 [00:01<00:01,  5.97it/s]21:14:48 - cmdstanpy - INFO - Chain [1] start processing
# 21:14:48 - cmdstanpy - INFO - Chain [1] done processing
#  50%|█████     | 8/16 [00:01<00:01,  5.98it/s]21:14:48 - cmdstanpy - INFO - Chain [1] start processing
# 21:14:48 - cmdstanpy - INFO - Chain [1] done processing
#  56%|█████▋    | 9/16 [00:01<00:01,  6.06it/s]21:14:48 - cmdstanpy - INFO - Chain [1] start processing
# 21:14:48 - cmdstanpy - INFO - Chain [1] done processing
#  62%|██████▎   | 10/16 [00:01<00:00,  6.22it/s]21:14:48 - cmdstanpy - INFO - Chain [1] start processing
# 21:14:48 - cmdstanpy - INFO - Chain [1] done processing
#  69%|██████▉   | 11/16 [00:01<00:00,  6.03it/s]21:14:49 - cmdstanpy - INFO - Chain [1] start processing
# 21:14:49 - cmdstanpy - INFO - Chain [1] done processing
#  75%|███████▌  | 12/16 [00:02<00:00,  6.02it/s]21:14:49 - cmdstanpy - INFO - Chain [1] start processing
# 21:14:49 - cmdstanpy - INFO - Chain [1] done processing
#  81%|████████▏ | 13/16 [00:02<00:00,  5.91it/s]21:14:49 - cmdstanpy - INFO - Chain [1] start processing
# 21:14:49 - cmdstanpy - INFO - Chain [1] done processing
#  88%|████████▊ | 14/16 [00:02<00:00,  5.77it/s]21:14:49 - cmdstanpy - INFO - Chain [1] start processing
# 21:14:49 - cmdstanpy - INFO - Chain [1] done processing
#  94%|█████████▍| 15/16 [00:02<00:00,  5.72it/s]21:14:49 - cmdstanpy - INFO - Chain [1] start processing
# 21:14:49 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 16/16 [00:02<00:00,  5.57it/s]

# %%
from prophet.diagnostics import performance_metrics
df_p = performance_metrics(df_cv)

# %%
from prophet.plot import plot_cross_validation_metric
fig = plot_cross_validation_metric(df_cv, metric='mape') # MAPE ES EL ERROR ABSOLUTO (+-) PORCENTUAL
# Out:
# c:\Users\---\AppData\Local\Programs\Python\Python312\Lib\site-packages\prophet\plot.py:546: FutureWarning: Series.view is deprecated and will be removed in a future version. Use ``astype`` as an alternative to change the dtype.
#   x_plt = df_none['horizon'].astype('timedelta64[ns]').view(np.int64) / float(dt_conversions[i])
# c:\Users\---\AppData\Local\Programs\Python\Python312\Lib\site-packages\prophet\plot.py:547: FutureWarning: Series.view is deprecated and will be removed in a future version. Use ``astype`` as an alternative to change the dtype.
#   x_plt_h = df_h['horizon'].astype('timedelta64[ns]').view(np.int64) / float(dt_conversions[i])

# %%
df_provincia40.describe()
# Out:
#             ANYO_x       count  TOTAL_VICTIMAS_24H           y  \
# count   400.000000  400.000000          400.000000  400.000000
# mean   2017.960000    3.790000            5.372500    3.790000
# min    2016.000000    1.000000            1.000000    1.000000
# 25%    2017.000000    2.000000            3.000000    2.000000
# 50%    2018.000000    3.000000            5.000000    3.000000
# 75%    2019.000000    5.000000            7.000000    5.000000
# max    2020.000000   11.000000           33.000000   11.000000
# std       1.399391    2.054618            3.486277    2.054618
#
#                                   ds
# count                            400
# mean   2018-06-06 05:49:12.000000256
# min              2016-01-01 00:00:00
# 25%              2017-03-04 18:00:00
# 50%              2018-06-04 12:00:00
# 75%              2019-08-13 06:00:00
# max              2020-12-06 00:00:00
# std                              NaN

# %% [markdown]
# De acuerdo con los datos de validación de nuestro modelo de Prophet, se realiza una predicción anual donde hay periodos donde pueden ocurrir o 0 accidentes o el doble. En la gráfica están alrededor del 5º y 13º en adelante, que corresponden con viernes y sábado (es decir, le resulta dificil predecir la cantidad de accidentes por esas fechas).

# %% [markdown]
# ### MODELO REDES NEURONALES

# %%
PASOS=84
 
# convert series to supervised learning
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
    n_vars = 1 if type(data) is list else data.shape[1]
    df = pd.DataFrame(data)
    cols, names = list(), list()
    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
        else:
            names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
    # put it all together
    agg = pd.concat(cols, axis=1)
    agg.columns = names
    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    return agg
 
# load dataset
values = df_provincia40['count'].values
# ensure all data is float
values = values.astype('float32')
# normalize features
scaler = MinMaxScaler(feature_range=(-1, 1))
values=values.reshape(-1, 1) # esto lo hacemos porque tenemos 1 sola dimension
scaled = scaler.fit_transform(values)
# frame as supervised learning
reframed = series_to_supervised(scaled, PASOS, 1)
reframed.head()
# Out:
#     var1(t-84)  var1(t-83)  var1(t-82)  var1(t-81)  var1(t-80)  var1(t-79)  \
# 84         0.0        -0.4        -0.4        -0.6        -0.8        -1.0
# 85        -0.4        -0.4        -0.6        -0.8        -1.0        -0.2
# 86        -0.4        -0.6        -0.8        -1.0        -0.2        -0.6
# 87        -0.6        -0.8        -1.0        -0.2        -0.6        -0.6
# 88        -0.8        -1.0        -0.2        -0.6        -0.6        -0.8
#
#     var1(t-78)  var1(t-77)  var1(t-76)  var1(t-75)  ...  var1(t-9)  var1(t-8)  \
# 84        -0.2        -0.6        -0.6        -0.8  ...       -0.6       -0.6
# 85        -0.6        -0.6        -0.8        -0.8  ...       -0.6       -0.8
# 86        -0.6        -0.8        -0.8        -1.0  ...       -0.8       -0.8
# 87        -0.8        -0.8        -1.0        -1.0  ...       -0.8       -0.8
# 88        -0.8        -1.0        -1.0        -0.2  ...       -0.8       -0.8
#
#     var1(t-7)  var1(t-6)  var1(t-5)  var1(t-4)  var1(t-3)  var1(t-2)  \
# 84       -0.8       -0.8       -0.8       -0.8       -1.0        0.4
# 85       -0.8       -0.8       -0.8       -1.0        0.4       -0.2
# 86       -0.8       -0.8       -1.0        0.4       -0.2       -0.4
# 87       -0.8       -1.0        0.4       -0.2       -0.4       -0.6
# 88       -1.0        0.4       -0.2       -0.4       -0.6       -0.6
#
#     var1(t-1)  var1(t)
# 84       -0.2     -0.4
# 85       -0.4     -0.6
# 86       -0.6     -0.6
# 87       -0.6     -0.8
# 88       -0.8     -1.0
#
# [5 rows x 85 columns]

# %%
values = reframed.values
n_train_days = 300
train = values[:n_train_days, :]
test = values[n_train_days:, :]
# split isnto input and outputs
x_train, y_train = train[:, :-1], train[:, -1]
x_val, y_val = test[:, :-1], test[:, -1]
# reshape input to be 3D [samples, timesteps, features]
x_train = x_train.reshape((x_train.shape[0], 1, x_train.shape[1]))
x_val = x_val.reshape((x_val.shape[0], 1, x_val.shape[1]))
print(x_train.shape, y_train.shape, x_val.shape, y_val.shape)
# Out:
# (300, 1, 84) (300,) (16, 1, 84) (16,)

# %%
len(values)
# Out:
# 316

# %%
def crear_modeloFF():
    model = Sequential()
    model.add(Dense(PASOS, input_shape=(1,PASOS),activation='tanh'))
    model.add(Flatten())
    model.add(Dense(1, activation='tanh'))
    model.compile(loss='mse',optimizer='Adam',metrics=["mae"])
    model.summary()
    return model

# %%
EPOCHS=20

model = crear_modeloFF()
 
history=model.fit(x_train,y_train,epochs=EPOCHS,validation_data=(x_val,y_val),batch_size=PASOS)
# Out:
# c:\Users\---\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_4 (Dense)                 │ (None, 1, 84)          │         7,140 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_2 (Flatten)             │ (None, 84)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 1)              │            85 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 7,225 (28.22 KB)
#  Trainable params: 7,225 (28.22 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.3007 - mae: 0.4299 - val_loss: 0.1068 - val_mae: 0.2522
# Epoch 2/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2403 - mae: 0.3683 - val_loss: 0.0643 - val_mae: 0.1974
# Epoch 3/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2051 - mae: 0.3436 - val_loss: 0.0896 - val_mae: 0.2585
# Epoch 4/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1737 - mae: 0.3075 - val_loss: 0.0510 - val_mae: 0.1706
# Epoch 5/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1431 - mae: 0.2819 - val_loss: 0.0472 - val_mae: 0.1705
# Epoch 6/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1219 - mae: 0.2627 - val_loss: 0.0835 - val_mae: 0.2442
# Epoch 7/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1207 - mae: 0.2591 - val_loss: 0.0661 - val_mae: 0.2047
# Epoch 8/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1178 - mae: 0.2566 - val_loss: 0.0467 - val_mae: 0.1803
# Epoch 9/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0972 - mae: 0.2239 - val_loss: 0.0817 - val_mae: 0.2310
# Epoch 10/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0944 - mae: 0.2332 - val_loss: 0.0890 - val_mae: 0.2446
# Epoch 11/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0906 - mae: 0.2227 - val_loss: 0.0469 - val_mae: 0.1714
# Epoch 12/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0936 - mae: 0.2194 - val_loss: 0.0752 - val_mae: 0.2234
# Epoch 13/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0850 - mae: 0.2169 - val_loss: 0.0671 - val_mae: 0.2101
# Epoch 14/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0883 - mae: 0.2191 - val_loss: 0.0411 - val_mae: 0.1553
# Epoch 15/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0760 - mae: 0.2073 - val_loss: 0.0702 - val_mae: 0.2180
# Epoch 16/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0745 - mae: 0.2062 - val_loss: 0.0631 - val_mae: 0.2028
# Epoch 17/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0801 - mae: 0.2104 - val_loss: 0.0472 - val_mae: 0.1683
# Epoch 18/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0694 - mae: 0.1992 - val_loss: 0.0653 - val_mae: 0.2078
# Epoch 19/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0751 - mae: 0.2077 - val_loss: 0.0600 - val_mae: 0.1985
# Epoch 20/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0724 - mae: 0.2071 - val_loss: 0.0447 - val_mae: 0.1652

# %%
results=model.predict(x_val)
plt.scatter(range(len(y_val)),y_val,c='g')
plt.scatter(range(len(results)),results,c='r')
plt.title('validate')
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step

# %%
loss = history.history['mae']
val_loss = history.history['val_mae']

# Graficar la función de pérdida durante el entrenamiento
epochs = range(1, len(loss) + 1)

plt.plot(epochs, loss, 'bo', label='Pérdida de entrenamiento')
plt.plot(epochs, val_loss, 'b', label='Pérdida de validación')
plt.title('Función de pérdida durante el entrenamiento')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
resultados_viajes = scaler.inverse_transform(results)
resultados_viajes
# Out:
# array([[2.4301105],
#        [2.5137756],
#        [3.0600085],
#        [4.3031726],
#        [3.1146445],
#        [3.0532336],
#        [3.56161  ],
#        [2.2172043],
#        [1.7465675],
#        [2.4711595],
#        [4.8467617],
#        [3.4952786],
#        [4.396374 ],
#        [4.537925 ],
#        [2.3106782],
#        [1.9337221]], dtype=float32)

# %% [markdown]
# Si bien el modelo de redes neuronales hace una buena predicción, para el número de accidentes en cada día de la semana para los meses en un año, el modelo no tiene la mejor curva de aprendizaje, por lo que los resultados son poco confiables. Por otro lado, Prophet, es el que tiene un mejor rendimiento, aunque hay que tener cuidado en los meses de abril y diciembre, donde los resultados no son tan confiables. Por tanto nos quedaremos con el modelo de Prophet para futuras predicciones.

# %% [markdown]
# # PREDICCIÓN PARA EL NÚMERO DE VICTIMAS

# %% [markdown]
# ### MODELO PROPHET

# %% [markdown]
# CAMBIAR COUNT POR TOTAL_VICTIMAS_24H

# %%
df_provincia40['y'] = df_provincia40['TOTAL_VICTIMAS_24H']
df_provincia40['ds'] = pd.to_datetime(pd.to_datetime(df_provincia40['FECHA']).dt.date)

# %%
ts = df_provincia40[['ds', 'y']]
model = Prophet(
   yearly_seasonality=True,
   seasonality_mode=['additive','multiplicative'][0]
   ).add_country_holidays(country_name='ESP'
   ).fit(ts)

future = model.make_future_dataframe(periods=10)
forecast = model.predict(future)
fig1 = model.plot(forecast)
# Out:
# 21:14:52 - cmdstanpy - INFO - Chain [1] start processing
# 21:14:52 - cmdstanpy - INFO - Chain [1] done processing
# c:\Users\---\AppData\Local\Programs\Python\Python312\Lib\site-packages\prophet\plot.py:72: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   fcst_t = fcst['ds'].dt.to_pydatetime()
# c:\Users\---\AppData\Local\Programs\Python\Python312\Lib\site-packages\prophet\plot.py:73: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   ax.plot(m.history['ds'].dt.to_pydatetime(), m.history['y'], 'k.',

# %%
fig2 = model.plot_components(forecast)
# Out:
# c:\Users\---\AppData\Local\Programs\Python\Python312\Lib\site-packages\prophet\plot.py:228: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   fcst_t = fcst['ds'].dt.to_pydatetime()
# c:\Users\---\AppData\Local\Programs\Python\Python312\Lib\site-packages\prophet\plot.py:351: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   df_y['ds'].dt.to_pydatetime(), seas[name], ls='-', c='#0072B2')
# c:\Users\---\AppData\Local\Programs\Python\Python312\Lib\site-packages\prophet\plot.py:354: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   df_y['ds'].dt.to_pydatetime(), seas[name + '_lower'],

# %%
from prophet.diagnostics import cross_validation
df_cv = cross_validation(model, initial='336 days', period='84 days', horizon = '20 days')
# Out:
# Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
#   0%|          | 0/16 [00:00<?, ?it/s]21:14:53 - cmdstanpy - INFO - Chain [1] start processing
# 21:14:53 - cmdstanpy - INFO - Chain [1] done processing
#   6%|▋         | 1/16 [00:00<00:04,  3.33it/s]21:14:53 - cmdstanpy - INFO - Chain [1] start processing
# 21:14:54 - cmdstanpy - INFO - Chain [1] done processing
#  12%|█▎        | 2/16 [00:00<00:03,  4.32it/s]21:14:54 - cmdstanpy - INFO - Chain [1] start processing
# 21:14:54 - cmdstanpy - INFO - Chain [1] done processing
#  19%|█▉        | 3/16 [00:00<00:02,  4.99it/s]21:14:54 - cmdstanpy - INFO - Chain [1] start processing
# 21:14:54 - cmdstanpy - INFO - Chain [1] done processing
#  25%|██▌       | 4/16 [00:00<00:02,  5.14it/s]21:14:54 - cmdstanpy - INFO - Chain [1] start processing
# 21:14:54 - cmdstanpy - INFO - Chain [1] done processing
#  31%|███▏      | 5/16 [00:01<00:02,  5.37it/s]21:14:54 - cmdstanpy - INFO - Chain [1] start processing
# 21:14:54 - cmdstanpy - INFO - Chain [1] done processing
#  38%|███▊      | 6/16 [00:01<00:01,  5.24it/s]21:14:54 - cmdstanpy - INFO - Chain [1] start processing
# 21:14:54 - cmdstanpy - INFO - Chain [1] done processing
#  44%|████▍     | 7/16 [00:01<00:01,  5.23it/s]21:14:55 - cmdstanpy - INFO - Chain [1] start processing
# 21:14:55 - cmdstanpy - INFO - Chain [1] done processing
#  50%|█████     | 8/16 [00:01<00:01,  5.44it/s]21:14:55 - cmdstanpy - INFO - Chain [1] start processing
# 21:14:55 - cmdstanpy - INFO - Chain [1] done processing
#  56%|█████▋    | 9/16 [00:01<00:01,  5.67it/s]21:14:55 - cmdstanpy - INFO - Chain [1] start processing
# 21:14:55 - cmdstanpy - INFO - Chain [1] done processing
#  62%|██████▎   | 10/16 [00:01<00:01,  5.37it/s]21:14:55 - cmdstanpy - INFO - Chain [1] start processing
# 21:14:55 - cmdstanpy - INFO - Chain [1] done processing
#  69%|██████▉   | 11/16 [00:02<00:00,  5.43it/s]21:14:55 - cmdstanpy - INFO - Chain [1] start processing
# 21:14:55 - cmdstanpy - INFO - Chain [1] done processing
#  75%|███████▌  | 12/16 [00:02<00:00,  5.28it/s]21:14:55 - cmdstanpy - INFO - Chain [1] start processing
# 21:14:56 - cmdstanpy - INFO - Chain [1] done processing
#  81%|████████▏ | 13/16 [00:02<00:00,  5.20it/s]21:14:56 - cmdstanpy - INFO - Chain [1] start processing
# 21:14:56 - cmdstanpy - INFO - Chain [1] done processing
#  88%|████████▊ | 14/16 [00:02<00:00,  5.27it/s]21:14:56 - cmdstanpy - INFO - Chain [1] start processing
# 21:14:56 - cmdstanpy - INFO - Chain [1] done processing
#  94%|█████████▍| 15/16 [00:02<00:00,  5.36it/s]21:14:56 - cmdstanpy - INFO - Chain [1] start processing
# 21:14:56 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 16/16 [00:03<00:00,  5.23it/s]

# %%
from prophet.diagnostics import performance_metrics
df_p = performance_metrics(df_cv)

# %%
from prophet.plot import plot_cross_validation_metric
fig = plot_cross_validation_metric(df_cv, metric='mape') # MAPE ES EL ERROR ABSOLUTO (+-) PORCENTUAL
# Out:
# c:\Users\---\AppData\Local\Programs\Python\Python312\Lib\site-packages\prophet\plot.py:546: FutureWarning: Series.view is deprecated and will be removed in a future version. Use ``astype`` as an alternative to change the dtype.
#   x_plt = df_none['horizon'].astype('timedelta64[ns]').view(np.int64) / float(dt_conversions[i])
# c:\Users\---\AppData\Local\Programs\Python\Python312\Lib\site-packages\prophet\plot.py:547: FutureWarning: Series.view is deprecated and will be removed in a future version. Use ``astype`` as an alternative to change the dtype.
#   x_plt_h = df_h['horizon'].astype('timedelta64[ns]').view(np.int64) / float(dt_conversions[i])

# %%
df_provincia40.describe()
# Out:
#             ANYO_x       count  TOTAL_VICTIMAS_24H           y  \
# count   400.000000  400.000000          400.000000  400.000000
# mean   2017.960000    3.790000            5.372500    5.372500
# min    2016.000000    1.000000            1.000000    1.000000
# 25%    2017.000000    2.000000            3.000000    3.000000
# 50%    2018.000000    3.000000            5.000000    5.000000
# 75%    2019.000000    5.000000            7.000000    7.000000
# max    2020.000000   11.000000           33.000000   33.000000
# std       1.399391    2.054618            3.486277    3.486277
#
#                                   ds
# count                            400
# mean   2018-06-06 05:49:12.000000256
# min              2016-01-01 00:00:00
# 25%              2017-03-04 18:00:00
# 50%              2018-06-04 12:00:00
# 75%              2019-08-13 06:00:00
# max              2020-12-06 00:00:00
# std                              NaN

# %% [markdown]
# ### MODELO REDES NEURONALES

# %%
PASOS=84
 
# convert series to supervised learning
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
    n_vars = 1 if type(data) is list else data.shape[1]
    df = pd.DataFrame(data)
    cols, names = list(), list()
    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
        else:
            names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
    # put it all together
    agg = pd.concat(cols, axis=1)
    agg.columns = names
    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    return agg
 
# load dataset
values = df_provincia40['TOTAL_VICTIMAS_24H'].values
# ensure all data is float
values = values.astype('float32')
# normalize features
scaler = MinMaxScaler(feature_range=(-1, 1))
values=values.reshape(-1, 1) # esto lo hacemos porque tenemos 1 sola dimension
scaled = scaler.fit_transform(values)
# frame as supervised learning
reframed = series_to_supervised(scaled, PASOS, 1)
reframed.head()
# Out:
#     var1(t-84)  var1(t-83)  var1(t-82)  var1(t-81)  var1(t-80)  var1(t-79)  \
# 84     -0.6875     -0.8125      -0.750     -0.8750     -0.8750     -1.0000
# 85     -0.8125     -0.7500      -0.875     -0.8750     -1.0000     -0.7500
# 86     -0.7500     -0.8750      -0.875     -1.0000     -0.7500     -0.5625
# 87     -0.8750     -0.8750      -1.000     -0.7500     -0.5625     -0.8125
# 88     -0.8750     -1.0000      -0.750     -0.5625     -0.8125     -0.9375
#
#     var1(t-78)  var1(t-77)  var1(t-76)  var1(t-75)  ...  var1(t-9)  var1(t-8)  \
# 84     -0.7500     -0.5625     -0.8125     -0.9375  ...    -0.7500    -0.8750
# 85     -0.5625     -0.8125     -0.9375     -0.4375  ...    -0.8750    -0.9375
# 86     -0.8125     -0.9375     -0.4375     -1.0000  ...    -0.9375    -0.9375
# 87     -0.9375     -0.4375     -1.0000     -1.0000  ...    -0.9375    -0.8750
# 88     -0.4375     -1.0000     -1.0000     -0.5000  ...    -0.8750    -0.6875
#
#     var1(t-7)  var1(t-6)  var1(t-5)  var1(t-4)  var1(t-3)  var1(t-2)  \
# 84    -0.9375    -0.9375    -0.8750    -0.6875    -1.0000    -0.1250
# 85    -0.9375    -0.8750    -0.6875    -1.0000    -0.1250    -0.7500
# 86    -0.8750    -0.6875    -1.0000    -0.1250    -0.7500    -0.8125
# 87    -0.6875    -1.0000    -0.1250    -0.7500    -0.8125    -0.8750
# 88    -1.0000    -0.1250    -0.7500    -0.8125    -0.8750    -0.8125
#
#     var1(t-1)  var1(t)
# 84    -0.7500  -0.8125
# 85    -0.8125  -0.8750
# 86    -0.8750  -0.8125
# 87    -0.8125  -0.8750
# 88    -0.8750  -1.0000
#
# [5 rows x 85 columns]

# %%
values = reframed.values
n_train_days = 300
train = values[:n_train_days, :]
test = values[n_train_days:, :]
# split isnto input and outputs
x_train, y_train = train[:, :-1], train[:, -1]
x_val, y_val = test[:, :-1], test[:, -1]
# reshape input to be 3D [samples, timesteps, features]
x_train = x_train.reshape((x_train.shape[0], 1, x_train.shape[1]))
x_val = x_val.reshape((x_val.shape[0], 1, x_val.shape[1]))
print(x_train.shape, y_train.shape, x_val.shape, y_val.shape)
# Out:
# (300, 1, 84) (300,) (16, 1, 84) (16,)

# %%
len(values)
# Out:
# 316

# %%
def crear_modeloFF():
    model = Sequential()
    model.add(Dense(PASOS, input_shape=(1,PASOS),activation='tanh'))
    model.add(Flatten())
    model.add(Dense(1, activation='tanh'))
    model.compile(loss='mse',optimizer='Adam',metrics=["mae"])
    model.summary()
    return model

# %%
EPOCHS=20

model = crear_modeloFF()
 
history=model.fit(x_train,y_train,epochs=EPOCHS,validation_data=(x_val,y_val),batch_size=PASOS)
# Out:
# c:\Users\---\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_6 (Dense)                 │ (None, 1, 84)          │         7,140 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_3 (Flatten)             │ (None, 84)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 1)              │            85 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 7,225 (28.22 KB)
#  Trainable params: 7,225 (28.22 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.9223 - mae: 0.8592 - val_loss: 0.0182 - val_mae: 0.0989
# Epoch 2/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0711 - mae: 0.1939 - val_loss: 0.0348 - val_mae: 0.1423
# Epoch 3/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.1060 - mae: 0.2444 - val_loss: 0.0381 - val_mae: 0.1512
# Epoch 4/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1219 - mae: 0.2755 - val_loss: 0.0390 - val_mae: 0.1536
# Epoch 5/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1262 - mae: 0.2731 - val_loss: 0.0393 - val_mae: 0.1544
# Epoch 6/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1331 - mae: 0.2784 - val_loss: 0.0395 - val_mae: 0.1548
# Epoch 7/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1181 - mae: 0.2710 - val_loss: 0.0395 - val_mae: 0.1550
# Epoch 8/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1189 - mae: 0.2719 - val_loss: 0.0396 - val_mae: 0.1551
# Epoch 9/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1207 - mae: 0.2693 - val_loss: 0.0396 - val_mae: 0.1552
# Epoch 10/20
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.1104 - mae: 0.2572
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1179 - mae: 0.2666 - val_loss: 0.0396 - val_mae: 0.1552
# Epoch 11/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1227 - mae: 0.2719 - val_loss: 0.0396 - val_mae: 0.1552
# Epoch 12/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1199 - mae: 0.2745 - val_loss: 0.0396 - val_mae: 0.1552
# Epoch 13/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1279 - mae: 0.2711 - val_loss: 0.0396 - val_mae: 0.1552
# Epoch 14/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1148 - mae: 0.2691 - val_loss: 0.0396 - val_mae: 0.1551
# Epoch 15/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1159 - mae: 0.2678 - val_loss: 0.0396 - val_mae: 0.1551
# Epoch 16/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1152 - mae: 0.2666 - val_loss: 0.0396 - val_mae: 0.1550
# Epoch 17/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1317 - mae: 0.2739 - val_loss: 0.0395 - val_mae: 0.1550
# Epoch 18/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1341 - mae: 0.2781 - val_loss: 0.0395 - val_mae: 0.1549
# Epoch 19/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1154 - mae: 0.2677 - val_loss: 0.0395 - val_mae: 0.1548
# Epoch 20/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1286 - mae: 0.2726 - val_loss: 0.0394 - val_mae: 0.1548

# %%
results=model.predict(x_val)
plt.scatter(range(len(y_val)),y_val,c='g')
plt.scatter(range(len(results)),results,c='r')
plt.title('validate')
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step

# %%
loss = history.history['mae']
val_loss = history.history['val_mae']

# Graficar la función de pérdida durante el entrenamiento
epochs = range(1, len(loss) + 1)

plt.plot(epochs, loss, 'bo', label='Pérdida de entrenamiento')
plt.plot(epochs, val_loss, 'b', label='Pérdida de validación')
plt.title('Función de pérdida durante el entrenamiento')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
resultados_viajes = scaler.inverse_transform(results)
resultados_viajes
# Out:
# array([[1.0414534],
#        [1.0280151],
#        [1.0259485],
#        [1.0246668],
#        [1.0365686],
#        [1.0319176],
#        [1.041337 ],
#        [1.0316782],
#        [1.024498 ],
#        [1.0317392],
#        [1.0259333],
#        [1.0424166],
#        [1.0239553],
#        [1.0280991],
#        [1.0311584],
#        [1.019639 ]], dtype=float32)
