# %%
import pandas as pd
import numpy as np
import matplotlib.patches as mpatches
import matplotlib.pyplot as plt
import seaborn as sns
from prophet import Prophet
from sklearn.preprocessing import LabelEncoder
from datetime import datetime, timedelta
import statsmodels.api as sm
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import PowerTransformer
from scipy.stats import poisson
import datetime as dt
import matplotlib.pyplot as plt
import statsmodels as st
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.api import ExponentialSmoothing, SimpleExpSmoothing, Holt
import statsmodels.api as sm
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
import seaborn as sns
from tabulate import tabulate
import pmdarima as pm
from dateutil.relativedelta import relativedelta
from keras.models import Sequential
from keras.layers import Dense,Activation,Flatten
from sklearn.preprocessing import MinMaxScaler

# %%
df = pd.read_csv('Datos_preprocesados_accidentes_y_victimas_accidentes.csv')

# %%
db_provincia5 = df[df['COD_PROVINCIA'] == 5]

# %%
num_victimas_dia_semana5 = db_provincia5.groupby(['ANYO', 'MES', 'DIA_SEMANA', 'HORA'])['TOTAL_VICTIMAS_24H'].sum()

# %%
num_victimas_dia_semana5
# Out:
# ANYO  MES  DIA_SEMANA  HORA
# 2016  1    1           11      1
#                        14      2
#            2           9       1
#                        19      4
#            3           10      1
#                               ..
# 2020  12   5           18      1
#            6           18      1
#            7           11      2
#                        12      1
#                        22      1
# Name: TOTAL_VICTIMAS_24H, Length: 1540, dtype: int64

# %%
num_accidentes_por_dia_semana5 = db_provincia5.groupby(['ANYO', 'MES'])['DIA_SEMANA'].value_counts()

# %%
num_accidentes_por_dia_semana5
# Out:
# ANYO  MES  DIA_SEMANA
# 2016  1    6             5
#            5             4
#            1             3
#            3             3
#            4             3
#                         ..
# 2020  12   5             4
#            1             3
#            7             3
#            2             2
#            6             1
# Name: count, Length: 404, dtype: int64

# %%
plt.plot(num_accidentes_por_dia_semana5.values)

# %%
plt.plot(num_victimas_dia_semana5.values)

# %%
num_accidentes_por_dia_semana5 = num_accidentes_por_dia_semana5.reset_index()

# %%
num_accidentes_por_dia_semana5['FECHA'] = num_accidentes_por_dia_semana5.apply(lambda row: str(row['ANYO']) + '/' + str(row['MES']) + '/' + str(row['DIA_SEMANA']), axis = 1)

# %%
num_accidentes_por_dia_semana5
# Out:
#      ANYO  MES  DIA_SEMANA  count      FECHA
# 0    2016    1           6      5   2016/1/6
# 1    2016    1           5      4   2016/1/5
# 2    2016    1           1      3   2016/1/1
# 3    2016    1           3      3   2016/1/3
# 4    2016    1           4      3   2016/1/4
# ..    ...  ...         ...    ...        ...
# 399  2020   12           5      4  2020/12/5
# 400  2020   12           1      3  2020/12/1
# 401  2020   12           7      3  2020/12/7
# 402  2020   12           2      2  2020/12/2
# 403  2020   12           6      1  2020/12/6
#
# [404 rows x 5 columns]

# %%
num_victimas_dia_semana5 = num_victimas_dia_semana5.reset_index()

# %%
num_victimas_dia_semana5
# Out:
#       ANYO  MES  DIA_SEMANA  HORA  TOTAL_VICTIMAS_24H
# 0     2016    1           1    11                   1
# 1     2016    1           1    14                   2
# 2     2016    1           2     9                   1
# 3     2016    1           2    19                   4
# 4     2016    1           3    10                   1
# ...    ...  ...         ...   ...                 ...
# 1535  2020   12           5    18                   1
# 1536  2020   12           6    18                   1
# 1537  2020   12           7    11                   2
# 1538  2020   12           7    12                   1
# 1539  2020   12           7    22                   1
#
# [1540 rows x 5 columns]

# %%
num_victimas_dia_semana5['FECHA'] = num_victimas_dia_semana5.apply(lambda row: str(row['ANYO']) + '/' + str(row['MES']) + '/' + str(row['DIA_SEMANA']), axis = 1)

# %%
num_victimas_dia_semana5
# Out:
#       ANYO  MES  DIA_SEMANA  HORA  TOTAL_VICTIMAS_24H      FECHA
# 0     2016    1           1    11                   1   2016/1/1
# 1     2016    1           1    14                   2   2016/1/1
# 2     2016    1           2     9                   1   2016/1/2
# 3     2016    1           2    19                   4   2016/1/2
# 4     2016    1           3    10                   1   2016/1/3
# ...    ...  ...         ...   ...                 ...        ...
# 1535  2020   12           5    18                   1  2020/12/5
# 1536  2020   12           6    18                   1  2020/12/6
# 1537  2020   12           7    11                   2  2020/12/7
# 1538  2020   12           7    12                   1  2020/12/7
# 1539  2020   12           7    22                   1  2020/12/7
#
# [1540 rows x 6 columns]

# %%
num_accidentes_por_dia_semana5
# Out:
#      ANYO  MES  DIA_SEMANA  count      FECHA
# 0    2016    1           6      5   2016/1/6
# 1    2016    1           5      4   2016/1/5
# 2    2016    1           1      3   2016/1/1
# 3    2016    1           3      3   2016/1/3
# 4    2016    1           4      3   2016/1/4
# ..    ...  ...         ...    ...        ...
# 399  2020   12           5      4  2020/12/5
# 400  2020   12           1      3  2020/12/1
# 401  2020   12           7      3  2020/12/7
# 402  2020   12           2      2  2020/12/2
# 403  2020   12           6      1  2020/12/6
#
# [404 rows x 5 columns]

# %%
num_victimas_dia_semana5
# Out:
#       ANYO  MES  DIA_SEMANA  HORA  TOTAL_VICTIMAS_24H      FECHA
# 0     2016    1           1    11                   1   2016/1/1
# 1     2016    1           1    14                   2   2016/1/1
# 2     2016    1           2     9                   1   2016/1/2
# 3     2016    1           2    19                   4   2016/1/2
# 4     2016    1           3    10                   1   2016/1/3
# ...    ...  ...         ...   ...                 ...        ...
# 1535  2020   12           5    18                   1  2020/12/5
# 1536  2020   12           6    18                   1  2020/12/6
# 1537  2020   12           7    11                   2  2020/12/7
# 1538  2020   12           7    12                   1  2020/12/7
# 1539  2020   12           7    22                   1  2020/12/7
#
# [1540 rows x 6 columns]

# %%
df_provincia5 = num_accidentes_por_dia_semana5.merge(num_victimas_dia_semana5, on = 'FECHA')

# %%
df_provincia5 = df_provincia5[['ANYO_x', 'FECHA', 'count', 'TOTAL_VICTIMAS_24H']]

# %%
df_provincia5.describe()
# Out:
#             ANYO_x        count  TOTAL_VICTIMAS_24H
# count  1540.000000  1540.000000         1540.000000
# mean   2017.760390     5.572727            1.604545
# std       1.362875     2.602400            1.062739
# min    2016.000000     1.000000            1.000000
# 25%    2017.000000     4.000000            1.000000
# 50%    2018.000000     5.000000            1.000000
# 75%    2019.000000     7.000000            2.000000
# max    2020.000000    14.000000            9.000000

# %% [markdown]
# ### MODELO PROPHET

# %%
df_provincia5['y'] = df_provincia5['count']
df_provincia5['ds'] = pd.to_datetime(pd.to_datetime(df_provincia5['FECHA']).dt.date)

# %%
ts = df_provincia5[['ds', 'y']]
model = Prophet(
   yearly_seasonality=True,
   seasonality_mode=['additive','multiplicative'][0]
   ).add_country_holidays(country_name='ESP'
   ).fit(ts)

future = model.make_future_dataframe(periods=10)
forecast = model.predict(future)
fig1 = model.plot(forecast)
# Out:
# 22:36:34 - cmdstanpy - INFO - Chain [1] start processing
# 22:36:35 - cmdstanpy - INFO - Chain [1] done processing
# c:\Users\---\AppData\Local\Programs\Python\Python312\Lib\site-packages\prophet\plot.py:72: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   fcst_t = fcst['ds'].dt.to_pydatetime()
# c:\Users\---\AppData\Local\Programs\Python\Python312\Lib\site-packages\prophet\plot.py:73: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   ax.plot(m.history['ds'].dt.to_pydatetime(), m.history['y'], 'k.',

# %%
fig2 = model.plot_components(forecast)
# Out:
# c:\Users\---\AppData\Local\Programs\Python\Python312\Lib\site-packages\prophet\plot.py:228: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   fcst_t = fcst['ds'].dt.to_pydatetime()
# c:\Users\---\AppData\Local\Programs\Python\Python312\Lib\site-packages\prophet\plot.py:351: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   df_y['ds'].dt.to_pydatetime(), seas[name], ls='-', c='#0072B2')
# c:\Users\---\AppData\Local\Programs\Python\Python312\Lib\site-packages\prophet\plot.py:354: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   df_y['ds'].dt.to_pydatetime(), seas[name + '_lower'],

# %% [markdown]
# ### MODELO REDES NEURONALES

# %%
PASOS=336
 
# convert series to supervised learning
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
    n_vars = 1 if type(data) is list else data.shape[1]
    df = pd.DataFrame(data)
    cols, names = list(), list()
    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
        else:
            names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
    # put it all together
    agg = pd.concat(cols, axis=1)
    agg.columns = names
    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    return agg
 
# load dataset
values = df_provincia5['count'].values
# ensure all data is float
values = values.astype('float32')
# normalize features
scaler = MinMaxScaler(feature_range=(-1, 1))
values=values.reshape(-1, 1) # esto lo hacemos porque tenemos 1 sola dimension
scaled = scaler.fit_transform(values)
# frame as supervised learning
reframed = series_to_supervised(scaled, PASOS, 1)
reframed.head()
# Out:
#      var1(t-336)  var1(t-335)  var1(t-334)  var1(t-333)  var1(t-332)  \
# 336    -0.384615    -0.384615    -0.384615    -0.384615    -0.384615
# 337    -0.384615    -0.384615    -0.384615    -0.384615    -0.538462
# 338    -0.384615    -0.384615    -0.384615    -0.538462    -0.538462
# 339    -0.384615    -0.384615    -0.538462    -0.538462    -0.538462
# 340    -0.384615    -0.538462    -0.538462    -0.538462    -0.538462
#
#      var1(t-331)  var1(t-330)  var1(t-329)  var1(t-328)  var1(t-327)  ...  \
# 336    -0.538462    -0.538462    -0.538462    -0.538462    -0.692308  ...
# 337    -0.538462    -0.538462    -0.538462    -0.692308    -0.692308  ...
# 338    -0.538462    -0.538462    -0.692308    -0.692308    -0.692308  ...
# 339    -0.538462    -0.692308    -0.692308    -0.692308    -0.692308  ...
# 340    -0.692308    -0.692308    -0.692308    -0.692308    -0.692308  ...
#
#      var1(t-9)  var1(t-8)  var1(t-7)  var1(t-6)  var1(t-5)  var1(t-4)  \
# 336   0.230769   0.230769   0.230769  -0.076923  -0.076923  -0.076923
# 337   0.230769   0.230769  -0.076923  -0.076923  -0.076923  -0.076923
# 338   0.230769  -0.076923  -0.076923  -0.076923  -0.076923  -0.076923
# 339  -0.076923  -0.076923  -0.076923  -0.076923  -0.076923  -0.076923
# 340  -0.076923  -0.076923  -0.076923  -0.076923  -0.076923  -0.384615
#
#      var1(t-3)  var1(t-2)  var1(t-1)   var1(t)
# 336  -0.076923  -0.076923  -0.076923 -0.384615
# 337  -0.076923  -0.076923  -0.384615 -0.384615
# 338  -0.076923  -0.384615  -0.384615 -0.384615
# 339  -0.384615  -0.384615  -0.384615 -0.384615
# 340  -0.384615  -0.384615  -0.384615 -0.538462
#
# [5 rows x 337 columns]

# %%
values = reframed.values
n_train_days = 1000
train = values[:n_train_days, :]
test = values[n_train_days:, :]
# split isnto input and outputs
x_train, y_train = train[:, :-1], train[:, -1]
x_val, y_val = test[:, :-1], test[:, -1]
# reshape input to be 3D [samples, timesteps, features]
x_train = x_train.reshape((x_train.shape[0], 1, x_train.shape[1]))
x_val = x_val.reshape((x_val.shape[0], 1, x_val.shape[1]))
print(x_train.shape, y_train.shape, x_val.shape, y_val.shape)
# Out:
# (1000, 1, 336) (1000,) (204, 1, 336) (204,)

# %%
len(values)
# Out:
# 1204

# %%
def crear_modeloFF():
    model = Sequential()
    model.add(Dense(PASOS, input_shape=(1,PASOS),activation='tanh'))
    model.add(Flatten())
    model.add(Dense(1, activation='tanh'))
    model.compile(loss='mean_absolute_error',optimizer='Adam',metrics=["mse"])
    model.summary()
    return model

# %%
EPOCHS=40

model = crear_modeloFF()
 
history=model.fit(x_train,y_train,epochs=EPOCHS,validation_data=(x_val,y_val),batch_size=PASOS)
# Out:
# c:\Users\---\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 1, 336)         │       113,232 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 336)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │           337 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 113,569 (443.63 KB)
#  Trainable params: 113,569 (443.63 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/40
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 112ms/step - loss: 0.4064 - mse: 0.2649 - val_loss: 0.3659 - val_mse: 0.2042
# Epoch 2/40
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.3706 - mse: 0.2145 - val_loss: 0.3080 - val_mse: 0.1685
# Epoch 3/40
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.3396 - mse: 0.1853 - val_loss: 0.3158 - val_mse: 0.1577
# Epoch 4/40
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.3007 - mse: 0.1523 - val_loss: 0.2774 - val_mse: 0.1348
# Epoch 5/40
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.2728 - mse: 0.1252 - val_loss: 0.3147 - val_mse: 0.1561
# Epoch 6/40
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.2297 - mse: 0.0977 - val_loss: 0.2483 - val_mse: 0.1088
# Epoch 7/40
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.2298 - mse: 0.0993 - val_loss: 0.2482 - val_mse: 0.1047
# Epoch 8/40
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.2044 - mse: 0.0855 - val_loss: 0.2413 - val_mse: 0.0978
# Epoch 9/40
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1903 - mse: 0.0751 - val_loss: 0.2160 - val_mse: 0.0798
# Epoch 10/40
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.1801 - mse: 0.0718 - val_loss: 0.2267 - val_mse: 0.0867
# Epoch 11/40
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 0.1733 - mse: 0.0632 - val_loss: 0.2269 - val_mse: 0.0851
# Epoch 12/40
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.1620 - mse: 0.0558 - val_loss: 0.1893 - val_mse: 0.0684
# Epoch 13/40
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 0.1505 - mse: 0.0541 - val_loss: 0.1836 - val_mse: 0.0653
# Epoch 14/40
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.1502 - mse: 0.0565 - val_loss: 0.1776 - val_mse: 0.0600
# Epoch 15/40
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.1447 - mse: 0.0526 - val_loss: 0.1781 - val_mse: 0.0591
# Epoch 16/40
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.1333 - mse: 0.0486 - val_loss: 0.1776 - val_mse: 0.0603
# Epoch 17/40
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.1296 - mse: 0.0464 - val_loss: 0.2187 - val_mse: 0.0763
# Epoch 18/40
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.1377 - mse: 0.0469 - val_loss: 0.2245 - val_mse: 0.0788
# Epoch 19/40
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.1304 - mse: 0.0439 - val_loss: 0.2019 - val_mse: 0.0688
# Epoch 20/40
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.1262 - mse: 0.0407 - val_loss: 0.2011 - val_mse: 0.0681
# Epoch 21/40
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.1257 - mse: 0.0446 - val_loss: 0.2302 - val_mse: 0.0808
# Epoch 22/40
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.1314 - mse: 0.0416 - val_loss: 0.2303 - val_mse: 0.0804
# Epoch 23/40
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.1326 - mse: 0.0444 - val_loss: 0.1655 - val_mse: 0.0537
# Epoch 24/40
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.1087 - mse: 0.0373 - val_loss: 0.1567 - val_mse: 0.0506
# Epoch 25/40
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.1069 - mse: 0.0369 - val_loss: 0.1604 - val_mse: 0.0515
# Epoch 26/40
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.1025 - mse: 0.0347 - val_loss: 0.1639 - val_mse: 0.0526
# Epoch 27/40
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.1140 - mse: 0.0405 - val_loss: 0.1532 - val_mse: 0.0488
# Epoch 28/40
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.1092 - mse: 0.0368 - val_loss: 0.1600 - val_mse: 0.0502
# Epoch 29/40
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.0978 - mse: 0.0345 - val_loss: 0.1563 - val_mse: 0.0507
# Epoch 30/40
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0.1210 - mse: 0.0410 - val_loss: 0.1799 - val_mse: 0.0582
# Epoch 31/40
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.1038 - mse: 0.0345 - val_loss: 0.1462 - val_mse: 0.0461
# Epoch 32/40
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.1024 - mse: 0.0345 - val_loss: 0.1846 - val_mse: 0.0586
# Epoch 33/40
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.1087 - mse: 0.0364 - val_loss: 0.1759 - val_mse: 0.0550
# Epoch 34/40
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.1055 - mse: 0.0328 - val_loss: 0.1520 - val_mse: 0.0464
# Epoch 35/40
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1056 - mse: 0.0385 - val_loss: 0.1496 - val_mse: 0.0465
# Epoch 36/40
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.1061 - mse: 0.0368 - val_loss: 0.1698 - val_mse: 0.0537
# Epoch 37/40
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1047 - mse: 0.0375 - val_loss: 0.1536 - val_mse: 0.0479
# Epoch 38/40
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0918 - mse: 0.0314 - val_loss: 0.1574 - val_mse: 0.0500
# Epoch 39/40
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1330 - mse: 0.0399 - val_loss: 0.1699 - val_mse: 0.0529
# Epoch 40/40
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1366 - mse: 0.0468 - val_loss: 0.2416 - val_mse: 0.0864

# %%
results=model.predict(x_val)
plt.scatter(range(len(y_val)),y_val,c='g')
plt.scatter(range(len(results)),results,c='r')
plt.title('validate')
plt.show()
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']

# Graficar la función de pérdida durante el entrenamiento
epochs = range(1, len(loss) + 1)

plt.plot(epochs, loss, 'bo', label='Pérdida de entrenamiento')
plt.plot(epochs, val_loss, 'b', label='Pérdida de validación')
plt.title('Función de pérdida durante el entrenamiento')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
resultados_viajes = scaler.inverse_transform(results)
resultados_viajes
# Out:
# array([[ 4.1840563],
#        [ 4.353786 ],
#        [ 4.2522316],
#        [ 5.100248 ],
#        [ 5.190742 ],
#        [ 5.4885044],
#        [ 5.624709 ],
#        [ 5.048536 ],
#        [ 4.8877897],
#        [ 4.6704435],
#        [ 3.6241977],
#        [ 4.8301153],
#        [ 4.500186 ],
#        [ 4.415079 ],
#        [ 3.9556649],
#        [ 4.317834 ],
#        [ 3.284451 ],
#        [ 5.0970755],
#        [ 6.2827516],
#        [ 6.044915 ],
#        [ 5.2889485],
#        [ 5.9434285],
#        [ 5.5762186],
#        [ 5.019008 ],
#        [ 4.205658 ],
#        [ 4.5109487],
#        [ 6.0940585],
#        [ 5.3786774],
#        [ 4.2575417],
#        [ 4.005214 ],
#        [ 3.6861904],
#        [ 3.7598126],
#        [ 3.71714  ],
#        [ 5.306806 ],
#        [ 4.953952 ],
#        [ 4.8405323],
#        [ 5.3668456],
#        [ 3.8933406],
#        [ 3.4510822],
#        [ 2.9061816],
#        [ 2.7503502],
#        [ 2.7198777],
#        [ 2.6322646],
#        [ 3.0963833],
#        [ 2.9178846],
#        [ 5.9935203],
#        [ 7.392156 ],
#        [ 7.4500685],
#        [ 7.5969834],
#        [ 6.2255545],
#        [ 3.5106876],
#        [ 3.1558988],
#        [ 3.0002   ],
#        [ 2.3915477],
#        [ 2.150153 ],
#        [ 2.3105767],
#        [ 3.4006417],
#        [ 5.0167313],
#        [ 4.6944695],
#        [ 3.5793135],
#        [ 3.5760026],
#        [ 3.7792516],
#        [ 3.6278117],
#        [ 4.2523932],
#        [ 4.607696 ],
#        [ 4.324461 ],
#        [ 4.603363 ],
#        [ 4.7036552],
#        [ 4.8134265],
#        [ 4.3945165],
#        [ 4.8481717],
#        [ 4.545393 ],
#        [ 3.6770468],
#        [ 3.7808967],
#        [11.723558 ],
#        [11.935342 ],
#        [11.67495  ],
#        [11.911075 ],
#        [11.662434 ],
#        [11.520907 ],
#        [12.126532 ],
#        [11.891951 ],
#        [ 7.587311 ],
#        [ 6.0667396],
#        [ 6.9363513],
#        [ 7.723411 ],
#        [ 7.227964 ],
#        [ 7.287234 ],
#        [ 6.195744 ],
#        [ 5.8203683],
#        [ 5.762144 ],
#        [ 4.8859844],
#        [ 4.1448846],
#        [ 4.7208033],
#        [ 4.598636 ],
#        [ 4.9475956],
#        [ 4.784826 ],
#        [ 4.904977 ],
#        [ 5.417946 ],
#        [ 4.3968754],
#        [ 4.358002 ],
#        [ 4.786907 ],
#        [ 4.7504277],
#        [ 4.888999 ],
#        [ 8.047494 ],
#        [ 8.812877 ],
#        [ 9.006267 ],
#        [ 8.432708 ],
#        [ 8.820201 ],
#        [ 7.9893575],
#        [ 6.6706495],
#        [ 4.9951715],
#        [ 5.7649875],
#        [ 6.656668 ],
#        [ 6.2094207],
#        [ 7.0303335],
#        [ 7.4405146],
#        [ 7.1564374],
#        [ 7.1545453],
#        [ 5.3978033],
#        [ 5.4191966],
#        [ 5.387937 ],
#        [ 5.642184 ],
#        [ 5.59786  ],
#        [ 5.423593 ],
#        [ 5.11681  ],
#        [ 5.2634606],
#        [ 6.238449 ],
#        [ 5.6448655],
#        [ 4.7499523],
#        [ 5.7201743],
#        [ 5.1368957],
#        [ 4.4638224],
#        [ 4.7690043],
#        [ 7.880319 ],
#        [ 7.48993  ],
#        [ 8.80284  ],
#        [ 8.924081 ],
#        [ 8.745942 ],
#        [ 7.6846046],
#        [ 8.035188 ],
#        [ 6.3562503],
#        [ 5.3770423],
#        [ 6.1448884],
#        [ 6.4649367],
#        [ 5.0792847],
#        [ 4.570397 ],
#        [ 4.355941 ],
#        [ 3.9892426],
#        [ 3.796234 ],
#        [ 3.706505 ],
#        [ 3.4781075],
#        [ 3.1833553],
#        [ 3.372404 ],
#        [ 4.1896353],
#        [ 4.663063 ],
#        [ 2.9025044],
#        [ 5.974374 ],
#        [ 8.145476 ],
#        [ 7.2462416],
#        [ 7.124988 ],
#        [ 7.3522925],
#        [ 6.8471184],
#        [ 5.480251 ],
#        [ 4.922981 ],
#        [ 4.7054186],
#        [ 4.7358737],
#        [ 5.2872014],
#        [ 4.512301 ],
#        [ 4.232082 ],
#        [ 4.201276 ],
#        [ 3.3014545],
#        [ 4.4509864],
#        [ 5.1141667],
#        [ 3.616149 ],
#        [ 4.550313 ],
#        [ 5.530852 ],
#        [ 4.8809743],
#        [ 4.1714506],
#        [ 3.6752052],
#        [ 3.2006843],
#        [ 2.9383805],
#        [ 2.8615644],
#        [ 6.375987 ],
#        [ 6.232848 ],
#        [ 7.3839498],
#        [ 8.174035 ],
#        [ 7.519801 ],
#        [ 5.8992786],
#        [ 5.665211 ],
#        [ 5.198997 ],
#        [ 4.961802 ],
#        [ 5.47502  ],
#        [ 6.0289817],
#        [ 6.436456 ],
#        [ 6.200503 ],
#        [ 5.6024694],
#        [ 5.616209 ],
#        [ 4.9481015],
#        [ 4.822682 ],
#        [ 3.930321 ],
#        [ 4.0926127],
#        [ 2.969569 ],
#        [ 3.3353024]], dtype=float32)
