# %%
import pandas as pd
import numpy as np
import matplotlib.patches as mpatches
import matplotlib.pyplot as plt
import seaborn as sns
from prophet import Prophet
from sklearn.preprocessing import LabelEncoder
from datetime import datetime, timedelta
import statsmodels.api as sm
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import PowerTransformer
from scipy.stats import poisson
import datetime as dt
import matplotlib.pyplot as plt
import statsmodels as st
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.api import ExponentialSmoothing, SimpleExpSmoothing, Holt
import statsmodels.api as sm
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
import seaborn as sns
from tabulate import tabulate
import pmdarima as pm
from dateutil.relativedelta import relativedelta
from keras.models import Sequential
from keras.layers import Dense,Activation,Flatten
from sklearn.preprocessing import MinMaxScaler

# %%
df = pd.read_csv('Datos_preprocesados_accidentes_y_victimas_accidentes.csv')

# %%
db_provincia5 = df[df['COD_PROVINCIA'] == 5]

# %%
num_victimas_dia_semana5 = db_provincia5.groupby(['ANYO', 'MES', 'DIA_SEMANA'])['TOTAL_VICTIMAS_24H'].sum()

# %%
num_victimas_dia_semana5 = num_victimas_dia_semana5.reset_index()

# %%
num_victimas_dia_semana5['FECHA'] = num_victimas_dia_semana5.apply(lambda row: str(row['ANYO']) + '/' + str(row['MES']) + '/' + str(row['DIA_SEMANA']), axis = 1)

# %%
num_accidentes_por_dia_semana5 = db_provincia5.groupby(['ANYO', 'MES'])['DIA_SEMANA'].value_counts()

# %%
num_accidentes_por_dia_semana5
# Out:
# ANYO  MES  DIA_SEMANA
# 2016  1    6             5
#            5             4
#            1             3
#            3             3
#            4             3
#                         ..
# 2020  12   5             4
#            1             3
#            7             3
#            2             2
#            6             1
# Name: count, Length: 404, dtype: int64

# %%
plt.plot(num_accidentes_por_dia_semana5.values)

# %%
plt.plot(num_victimas_dia_semana5['TOTAL_VICTIMAS_24H'])

# %%
num_accidentes_por_dia_semana5 = num_accidentes_por_dia_semana5.reset_index()

# %%
num_accidentes_por_dia_semana5['FECHA'] = num_accidentes_por_dia_semana5.apply(lambda row: str(row['ANYO']) + '/' + str(row['MES']) + '/' + str(row['DIA_SEMANA']), axis = 1)

# %%
num_accidentes_por_dia_semana5
# Out:
#      ANYO  MES  DIA_SEMANA  count      FECHA
# 0    2016    1           6      5   2016/1/6
# 1    2016    1           5      4   2016/1/5
# 2    2016    1           1      3   2016/1/1
# 3    2016    1           3      3   2016/1/3
# 4    2016    1           4      3   2016/1/4
# ..    ...  ...         ...    ...        ...
# 399  2020   12           5      4  2020/12/5
# 400  2020   12           1      3  2020/12/1
# 401  2020   12           7      3  2020/12/7
# 402  2020   12           2      2  2020/12/2
# 403  2020   12           6      1  2020/12/6
#
# [404 rows x 5 columns]

# %%
num_victimas_dia_semana5 = num_victimas_dia_semana5.reset_index()

# %%
num_victimas_dia_semana5
# Out:
#      index  ANYO  MES  DIA_SEMANA  TOTAL_VICTIMAS_24H      FECHA
# 0        0  2016    1           1                   3   2016/1/1
# 1        1  2016    1           2                   5   2016/1/2
# 2        2  2016    1           3                   3   2016/1/3
# 3        3  2016    1           4                   3   2016/1/4
# 4        4  2016    1           5                   5   2016/1/5
# ..     ...   ...  ...         ...                 ...        ...
# 399    399  2020   12           3                   7  2020/12/3
# 400    400  2020   12           4                   4  2020/12/4
# 401    401  2020   12           5                   5  2020/12/5
# 402    402  2020   12           6                   1  2020/12/6
# 403    403  2020   12           7                   4  2020/12/7
#
# [404 rows x 6 columns]

# %%
num_victimas_dia_semana5['FECHA'] = num_victimas_dia_semana5.apply(lambda row: str(row['ANYO']) + '/' + str(row['MES']) + '/' + str(row['DIA_SEMANA']), axis = 1)

# %%
num_victimas_dia_semana5
# Out:
#      index  ANYO  MES  DIA_SEMANA  TOTAL_VICTIMAS_24H      FECHA
# 0        0  2016    1           1                   3   2016/1/1
# 1        1  2016    1           2                   5   2016/1/2
# 2        2  2016    1           3                   3   2016/1/3
# 3        3  2016    1           4                   3   2016/1/4
# 4        4  2016    1           5                   5   2016/1/5
# ..     ...   ...  ...         ...                 ...        ...
# 399    399  2020   12           3                   7  2020/12/3
# 400    400  2020   12           4                   4  2020/12/4
# 401    401  2020   12           5                   5  2020/12/5
# 402    402  2020   12           6                   1  2020/12/6
# 403    403  2020   12           7                   4  2020/12/7
#
# [404 rows x 6 columns]

# %%
num_accidentes_por_dia_semana5
# Out:
#      ANYO  MES  DIA_SEMANA  count      FECHA
# 0    2016    1           6      5   2016/1/6
# 1    2016    1           5      4   2016/1/5
# 2    2016    1           1      3   2016/1/1
# 3    2016    1           3      3   2016/1/3
# 4    2016    1           4      3   2016/1/4
# ..    ...  ...         ...    ...        ...
# 399  2020   12           5      4  2020/12/5
# 400  2020   12           1      3  2020/12/1
# 401  2020   12           7      3  2020/12/7
# 402  2020   12           2      2  2020/12/2
# 403  2020   12           6      1  2020/12/6
#
# [404 rows x 5 columns]

# %%
num_victimas_dia_semana5
# Out:
#      index  ANYO  MES  DIA_SEMANA  TOTAL_VICTIMAS_24H      FECHA
# 0        0  2016    1           1                   3   2016/1/1
# 1        1  2016    1           2                   5   2016/1/2
# 2        2  2016    1           3                   3   2016/1/3
# 3        3  2016    1           4                   3   2016/1/4
# 4        4  2016    1           5                   5   2016/1/5
# ..     ...   ...  ...         ...                 ...        ...
# 399    399  2020   12           3                   7  2020/12/3
# 400    400  2020   12           4                   4  2020/12/4
# 401    401  2020   12           5                   5  2020/12/5
# 402    402  2020   12           6                   1  2020/12/6
# 403    403  2020   12           7                   4  2020/12/7
#
# [404 rows x 6 columns]

# %%
df_provincia5 = num_accidentes_por_dia_semana5.merge(num_victimas_dia_semana5, on = 'FECHA')

# %%
df_provincia5 = df_provincia5[['ANYO_x', 'FECHA', 'count', 'TOTAL_VICTIMAS_24H']]

# %%
df_provincia5.describe()
# Out:
#             ANYO_x       count  TOTAL_VICTIMAS_24H
# count   404.000000  404.000000          404.000000
# mean   2017.955446    4.405941            6.116337
# std       1.401168    2.463342            4.061418
# min    2016.000000    1.000000            1.000000
# 25%    2017.000000    3.000000            3.000000
# 50%    2018.000000    4.000000            5.000000
# 75%    2019.000000    6.000000            8.000000
# max    2020.000000   14.000000           27.000000

# %% [markdown]
# # PREDICCION DE NÚMERO DE ACCIDENTES

# %% [markdown]
# ### MODELO PROPHET

# %%
df_provincia5['y'] = df_provincia5['count']
df_provincia5['ds'] = pd.to_datetime(pd.to_datetime(df_provincia5['FECHA']).dt.date)

# %%
ts = df_provincia5[['ds', 'y']]
model = Prophet(
   yearly_seasonality=True,
   seasonality_mode=['additive','multiplicative'][0]
   ).add_country_holidays(country_name='ESP'
   ).fit(ts)

future = model.make_future_dataframe(periods=10)
forecast = model.predict(future)
fig1 = model.plot(forecast)
# Out:
# 19:28:42 - cmdstanpy - INFO - Chain [1] start processing
# 19:28:42 - cmdstanpy - INFO - Chain [1] done processing
# c:\Users\---\AppData\Local\Programs\Python\Python312\Lib\site-packages\prophet\plot.py:72: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   fcst_t = fcst['ds'].dt.to_pydatetime()
# c:\Users\---\AppData\Local\Programs\Python\Python312\Lib\site-packages\prophet\plot.py:73: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   ax.plot(m.history['ds'].dt.to_pydatetime(), m.history['y'], 'k.',

# %%
fig2 = model.plot_components(forecast)
# Out:
# c:\Users\---\AppData\Local\Programs\Python\Python312\Lib\site-packages\prophet\plot.py:228: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   fcst_t = fcst['ds'].dt.to_pydatetime()
# c:\Users\---\AppData\Local\Programs\Python\Python312\Lib\site-packages\prophet\plot.py:351: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   df_y['ds'].dt.to_pydatetime(), seas[name], ls='-', c='#0072B2')
# c:\Users\---\AppData\Local\Programs\Python\Python312\Lib\site-packages\prophet\plot.py:354: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   df_y['ds'].dt.to_pydatetime(), seas[name + '_lower'],

# %%
from prophet.diagnostics import cross_validation
df_cv = cross_validation(model, initial='336 days', period='84 days', horizon = '20 days')
# Out:
# Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
#   0%|          | 0/16 [00:00<?, ?it/s]19:28:42 - cmdstanpy - INFO - Chain [1] start processing
# 19:28:43 - cmdstanpy - INFO - Chain [1] done processing
#   6%|▋         | 1/16 [00:00<00:05,  2.63it/s]19:28:43 - cmdstanpy - INFO - Chain [1] start processing
# 19:28:43 - cmdstanpy - INFO - Chain [1] done processing
#  12%|█▎        | 2/16 [00:00<00:03,  4.09it/s]19:28:43 - cmdstanpy - INFO - Chain [1] start processing
# 19:28:43 - cmdstanpy - INFO - Chain [1] done processing
#  19%|█▉        | 3/16 [00:00<00:02,  4.97it/s]19:28:43 - cmdstanpy - INFO - Chain [1] start processing
# 19:28:43 - cmdstanpy - INFO - Chain [1] done processing
#  25%|██▌       | 4/16 [00:00<00:02,  5.44it/s]19:28:43 - cmdstanpy - INFO - Chain [1] start processing
# 19:28:43 - cmdstanpy - INFO - Chain [1] done processing
#  31%|███▏      | 5/16 [00:00<00:01,  5.88it/s]19:28:43 - cmdstanpy - INFO - Chain [1] start processing
# 19:28:43 - cmdstanpy - INFO - Chain [1] done processing
#  38%|███▊      | 6/16 [00:01<00:01,  6.20it/s]19:28:43 - cmdstanpy - INFO - Chain [1] start processing
# 19:28:44 - cmdstanpy - INFO - Chain [1] done processing
#  44%|████▍     | 7/16 [00:01<00:01,  6.36it/s]19:28:44 - cmdstanpy - INFO - Chain [1] start processing
# 19:28:44 - cmdstanpy - INFO - Chain [1] done processing
#  50%|█████     | 8/16 [00:01<00:01,  6.32it/s]19:28:44 - cmdstanpy - INFO - Chain [1] start processing
# 19:28:44 - cmdstanpy - INFO - Chain [1] done processing
#  56%|█████▋    | 9/16 [00:01<00:01,  6.38it/s]19:28:44 - cmdstanpy - INFO - Chain [1] start processing
# 19:28:44 - cmdstanpy - INFO - Chain [1] done processing
#  62%|██████▎   | 10/16 [00:01<00:00,  6.58it/s]19:28:44 - cmdstanpy - INFO - Chain [1] start processing
# 19:28:44 - cmdstanpy - INFO - Chain [1] done processing
#  69%|██████▉   | 11/16 [00:01<00:00,  6.30it/s]19:28:44 - cmdstanpy - INFO - Chain [1] start processing
# 19:28:44 - cmdstanpy - INFO - Chain [1] done processing
#  75%|███████▌  | 12/16 [00:02<00:00,  6.28it/s]19:28:44 - cmdstanpy - INFO - Chain [1] start processing
# 19:28:44 - cmdstanpy - INFO - Chain [1] done processing
#  81%|████████▏ | 13/16 [00:02<00:00,  6.30it/s]19:28:45 - cmdstanpy - INFO - Chain [1] start processing
# 19:28:45 - cmdstanpy - INFO - Chain [1] done processing
#  88%|████████▊ | 14/16 [00:02<00:00,  6.29it/s]19:28:45 - cmdstanpy - INFO - Chain [1] start processing
# 19:28:45 - cmdstanpy - INFO - Chain [1] done processing
#  94%|█████████▍| 15/16 [00:02<00:00,  6.29it/s]19:28:45 - cmdstanpy - INFO - Chain [1] start processing
# 19:28:45 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 16/16 [00:02<00:00,  5.91it/s]

# %%
from prophet.diagnostics import performance_metrics
df_p = performance_metrics(df_cv)

# %%
from prophet.plot import plot_cross_validation_metric
fig = plot_cross_validation_metric(df_cv, metric='mape') # MAPE ES EL ERROR ABSOLUTO (+-) PORCENTUAL
# Out:
# c:\Users\---\AppData\Local\Programs\Python\Python312\Lib\site-packages\prophet\plot.py:546: FutureWarning: Series.view is deprecated and will be removed in a future version. Use ``astype`` as an alternative to change the dtype.
#   x_plt = df_none['horizon'].astype('timedelta64[ns]').view(np.int64) / float(dt_conversions[i])
# c:\Users\---\AppData\Local\Programs\Python\Python312\Lib\site-packages\prophet\plot.py:547: FutureWarning: Series.view is deprecated and will be removed in a future version. Use ``astype`` as an alternative to change the dtype.
#   x_plt_h = df_h['horizon'].astype('timedelta64[ns]').view(np.int64) / float(dt_conversions[i])

# %%
df_provincia5.describe()
# Out:
#             ANYO_x       count  TOTAL_VICTIMAS_24H           y  \
# count   404.000000  404.000000          404.000000  404.000000
# mean   2017.955446    4.405941            6.116337    4.405941
# min    2016.000000    1.000000            1.000000    1.000000
# 25%    2017.000000    3.000000            3.000000    3.000000
# 50%    2018.000000    4.000000            5.000000    4.000000
# 75%    2019.000000    6.000000            8.000000    6.000000
# max    2020.000000   14.000000           27.000000   14.000000
# std       1.401168    2.463342            4.061418    2.463342
#
#                                   ds
# count                            404
# mean   2018-06-04 18:53:27.920792064
# min              2016-01-01 00:00:00
# 25%              2017-03-05 18:00:00
# 50%              2018-06-03 12:00:00
# 75%              2019-08-13 06:00:00
# max              2020-12-07 00:00:00
# std                              NaN

# %% [markdown]
# De acuerdo con los datos de validación de nuestro modelo de Prophet, se realiza una predicción anual donde hay periodos donde pueden ocurrir o 0 accidentes o el doble. En la gráfica están alrededor del 5º y 13º en adelante, que corresponden con viernes y sábado (es decir, le resulta dificil predecir la cantidad de accidentes por esas fechas).

# %% [markdown]
# ### MODELO REDES NEURONALES

# %%
PASOS=84
 
# convert series to supervised learning
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
    n_vars = 1 if type(data) is list else data.shape[1]
    df = pd.DataFrame(data)
    cols, names = list(), list()
    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
        else:
            names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
    # put it all together
    agg = pd.concat(cols, axis=1)
    agg.columns = names
    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    return agg
 
# load dataset
values = df_provincia5['count'].values
# ensure all data is float
values = values.astype('float32')
# normalize features
scaler = MinMaxScaler(feature_range=(-1, 1))
values=values.reshape(-1, 1) # esto lo hacemos porque tenemos 1 sola dimension
scaled = scaler.fit_transform(values)
# frame as supervised learning
reframed = series_to_supervised(scaled, PASOS, 1)
reframed.head()
# Out:
#     var1(t-84)  var1(t-83)  var1(t-82)  var1(t-81)  var1(t-80)  var1(t-79)  \
# 84   -0.384615   -0.538462   -0.692308   -0.692308   -0.692308   -0.692308
# 85   -0.538462   -0.692308   -0.692308   -0.692308   -0.692308   -0.846154
# 86   -0.692308   -0.692308   -0.692308   -0.692308   -0.846154   -0.384615
# 87   -0.692308   -0.692308   -0.692308   -0.846154   -0.384615   -0.538462
# 88   -0.692308   -0.692308   -0.846154   -0.384615   -0.538462   -0.692308
#
#     var1(t-78)  var1(t-77)  var1(t-76)  var1(t-75)  ...  var1(t-9)  var1(t-8)  \
# 84   -0.846154   -0.384615   -0.538462   -0.692308  ...  -0.692308  -0.384615
# 85   -0.384615   -0.538462   -0.692308   -0.846154  ...  -0.384615  -0.384615
# 86   -0.538462   -0.692308   -0.846154   -0.846154  ...  -0.384615  -0.538462
# 87   -0.692308   -0.846154   -0.846154   -0.846154  ...  -0.538462  -0.692308
# 88   -0.846154   -0.846154   -0.846154   -0.076923  ...  -0.692308  -0.692308
#
#     var1(t-7)  var1(t-6)  var1(t-5)  var1(t-4)  var1(t-3)  var1(t-2)  \
# 84  -0.384615  -0.538462  -0.692308  -0.692308  -0.846154  -0.846154
# 85  -0.538462  -0.692308  -0.692308  -0.846154  -0.846154  -0.230769
# 86  -0.692308  -0.692308  -0.846154  -0.846154  -0.230769  -0.230769
# 87  -0.692308  -0.846154  -0.846154  -0.230769  -0.230769  -0.384615
# 88  -0.846154  -0.846154  -0.230769  -0.230769  -0.384615  -0.384615
#
#     var1(t-1)   var1(t)
# 84  -0.230769 -0.230769
# 85  -0.230769 -0.384615
# 86  -0.384615 -0.384615
# 87  -0.384615 -0.692308
# 88  -0.692308 -0.692308
#
# [5 rows x 85 columns]

# %%
values = reframed.values
n_train_days = 300
train = values[:n_train_days, :]
test = values[n_train_days:, :]
# split isnto input and outputs
x_train, y_train = train[:, :-1], train[:, -1]
x_val, y_val = test[:, :-1], test[:, -1]
# reshape input to be 3D [samples, timesteps, features]
x_train = x_train.reshape((x_train.shape[0], 1, x_train.shape[1]))
x_val = x_val.reshape((x_val.shape[0], 1, x_val.shape[1]))
print(x_train.shape, y_train.shape, x_val.shape, y_val.shape)
# Out:
# (300, 1, 84) (300,) (20, 1, 84) (20,)

# %%
len(values)
# Out:
# 320

# %%
def crear_modeloFF():
    model = Sequential()
    model.add(Dense(PASOS, input_shape=(1,PASOS),activation='tanh'))
    model.add(Flatten())
    model.add(Dense(1, activation='tanh'))
    model.compile(loss='mse',optimizer='Adam',metrics=["mae"])
    model.summary()
    return model

# %%
EPOCHS=20

model = crear_modeloFF()
 
history=model.fit(x_train,y_train,epochs=EPOCHS,validation_data=(x_val,y_val),batch_size=PASOS)
# Out:
# c:\Users\---\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_6 (Dense)                 │ (None, 1, 84)          │         7,140 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_3 (Flatten)             │ (None, 84)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 1)              │            85 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 7,225 (28.22 KB)
#  Trainable params: 7,225 (28.22 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.6487 - mae: 0.7045 - val_loss: 0.0762 - val_mae: 0.2313
# Epoch 2/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1861 - mae: 0.3155 - val_loss: 0.0825 - val_mae: 0.2041
# Epoch 3/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2639 - mae: 0.3917 - val_loss: 0.0842 - val_mae: 0.2054
# Epoch 4/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2584 - mae: 0.3866 - val_loss: 0.0737 - val_mae: 0.1914
# Epoch 5/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1914 - mae: 0.3372 - val_loss: 0.0639 - val_mae: 0.2076
# Epoch 6/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1267 - mae: 0.2615 - val_loss: 0.1447 - val_mae: 0.3212
# Epoch 7/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1180 - mae: 0.2565 - val_loss: 0.1755 - val_mae: 0.3552
# Epoch 8/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1190 - mae: 0.2526 - val_loss: 0.0975 - val_mae: 0.2646
# Epoch 9/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1154 - mae: 0.2542 - val_loss: 0.0635 - val_mae: 0.2091
# Epoch 10/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1204 - mae: 0.2557 - val_loss: 0.0670 - val_mae: 0.2149
# Epoch 11/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0987 - mae: 0.2326 - val_loss: 0.0916 - val_mae: 0.2549
# Epoch 12/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0979 - mae: 0.2386 - val_loss: 0.1178 - val_mae: 0.2893
# Epoch 13/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0974 - mae: 0.2294 - val_loss: 0.0986 - val_mae: 0.2633
# Epoch 14/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1000 - mae: 0.2318 - val_loss: 0.0766 - val_mae: 0.2329
# Epoch 15/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0861 - mae: 0.2180 - val_loss: 0.0756 - val_mae: 0.2318
# Epoch 16/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0890 - mae: 0.2186 - val_loss: 0.0991 - val_mae: 0.2646
# Epoch 17/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0812 - mae: 0.2094 - val_loss: 0.1044 - val_mae: 0.2732
# Epoch 18/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0753 - mae: 0.2046 - val_loss: 0.0884 - val_mae: 0.2503
# Epoch 19/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0810 - mae: 0.2078 - val_loss: 0.0811 - val_mae: 0.2400
# Epoch 20/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0792 - mae: 0.2112 - val_loss: 0.0912 - val_mae: 0.2558

# %%
results=model.predict(x_val)
plt.scatter(range(len(y_val)),y_val,c='g')
plt.scatter(range(len(results)),results,c='r')
plt.title('validate')
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step

# %%
loss = history.history['mae']
val_loss = history.history['val_mae']

# Graficar la función de pérdida durante el entrenamiento
epochs = range(1, len(loss) + 1)

plt.plot(epochs, loss, 'bo', label='Pérdida de entrenamiento')
plt.plot(epochs, val_loss, 'b', label='Pérdida de validación')
plt.title('Función de pérdida durante el entrenamiento')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
resultados_viajes = scaler.inverse_transform(results)
resultados_viajes
# Out:
# array([[3.0854795],
#        [5.933732 ],
#        [6.174608 ],
#        [4.4270253],
#        [5.10344  ],
#        [3.0145853],
#        [4.1514645],
#        [3.3998165],
#        [4.5124846],
#        [5.081391 ],
#        [3.5130196],
#        [3.182797 ],
#        [2.3402991],
#        [2.2581553],
#        [3.199498 ],
#        [4.210181 ],
#        [3.8575811],
#        [2.434416 ],
#        [2.264756 ],
#        [2.7606077]], dtype=float32)

# %% [markdown]
# Si bien el modelo de redes neuronales hace una buena predicción, para el número de accidentes en cada día de la semana para los meses en un año, el modelo no tiene la mejor curva de aprendizaje, por lo que los resultados son poco confiables. Por otro lado, Prophet, es el que tiene un mejor rendimiento, aunque hay que tener cuidado en los meses de abril y diciembre, donde los resultados no son tan confiables. Por tanto nos quedaremos con el modelo de Prophet para futuras predicciones.

# %% [markdown]
# # PREDICCIÓN PARA EL NÚMERO DE VICTIMAS

# %% [markdown]
# ### MODELO PROPHET

# %% [markdown]
# CAMBIAR COUNT POR TOTAL_VICTIMAS_24H

# %%
df_provincia5['y'] = df_provincia5['TOTAL_VICTIMAS_24H']
df_provincia5['ds'] = pd.to_datetime(pd.to_datetime(df_provincia5['FECHA']).dt.date)

# %%
ts = df_provincia5[['ds', 'y']]
model = Prophet(
   yearly_seasonality=True,
   seasonality_mode=['additive','multiplicative'][0]
   ).add_country_holidays(country_name='ESP'
   ).fit(ts)

future = model.make_future_dataframe(periods=10)
forecast = model.predict(future)
fig1 = model.plot(forecast)
# Out:
# 19:28:47 - cmdstanpy - INFO - Chain [1] start processing
# 19:28:47 - cmdstanpy - INFO - Chain [1] done processing
# c:\Users\---\AppData\Local\Programs\Python\Python312\Lib\site-packages\prophet\plot.py:72: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   fcst_t = fcst['ds'].dt.to_pydatetime()
# c:\Users\---\AppData\Local\Programs\Python\Python312\Lib\site-packages\prophet\plot.py:73: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   ax.plot(m.history['ds'].dt.to_pydatetime(), m.history['y'], 'k.',

# %%
fig2 = model.plot_components(forecast)
# Out:
# c:\Users\---\AppData\Local\Programs\Python\Python312\Lib\site-packages\prophet\plot.py:228: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   fcst_t = fcst['ds'].dt.to_pydatetime()
# c:\Users\---\AppData\Local\Programs\Python\Python312\Lib\site-packages\prophet\plot.py:351: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   df_y['ds'].dt.to_pydatetime(), seas[name], ls='-', c='#0072B2')
# c:\Users\---\AppData\Local\Programs\Python\Python312\Lib\site-packages\prophet\plot.py:354: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   df_y['ds'].dt.to_pydatetime(), seas[name + '_lower'],

# %%
from prophet.diagnostics import cross_validation
df_cv = cross_validation(model, initial='336 days', period='84 days', horizon = '20 days')
# Out:
# Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
#   0%|          | 0/16 [00:00<?, ?it/s]19:28:48 - cmdstanpy - INFO - Chain [1] start processing
# 19:28:48 - cmdstanpy - INFO - Chain [1] done processing
#   6%|▋         | 1/16 [00:00<00:04,  3.64it/s]19:28:49 - cmdstanpy - INFO - Chain [1] start processing
# 19:28:49 - cmdstanpy - INFO - Chain [1] done processing
#  12%|█▎        | 2/16 [00:00<00:02,  4.97it/s]19:28:49 - cmdstanpy - INFO - Chain [1] start processing
# 19:28:49 - cmdstanpy - INFO - Chain [1] done processing
#  19%|█▉        | 3/16 [00:00<00:02,  5.77it/s]19:28:49 - cmdstanpy - INFO - Chain [1] start processing
# 19:28:49 - cmdstanpy - INFO - Chain [1] done processing
#  25%|██▌       | 4/16 [00:00<00:01,  6.04it/s]19:28:49 - cmdstanpy - INFO - Chain [1] start processing
# 19:28:49 - cmdstanpy - INFO - Chain [1] done processing
#  31%|███▏      | 5/16 [00:00<00:01,  6.13it/s]19:28:49 - cmdstanpy - INFO - Chain [1] start processing
# 19:28:49 - cmdstanpy - INFO - Chain [1] done processing
#  38%|███▊      | 6/16 [00:01<00:01,  5.36it/s]19:28:49 - cmdstanpy - INFO - Chain [1] start processing
# 19:28:49 - cmdstanpy - INFO - Chain [1] done processing
#  44%|████▍     | 7/16 [00:01<00:01,  5.75it/s]19:28:50 - cmdstanpy - INFO - Chain [1] start processing
# 19:28:50 - cmdstanpy - INFO - Chain [1] done processing
#  50%|█████     | 8/16 [00:01<00:01,  5.97it/s]19:28:50 - cmdstanpy - INFO - Chain [1] start processing
# 19:28:50 - cmdstanpy - INFO - Chain [1] done processing
#  56%|█████▋    | 9/16 [00:01<00:01,  6.01it/s]19:28:50 - cmdstanpy - INFO - Chain [1] start processing
# 19:28:50 - cmdstanpy - INFO - Chain [1] done processing
#  62%|██████▎   | 10/16 [00:01<00:01,  5.96it/s]19:28:50 - cmdstanpy - INFO - Chain [1] start processing
# 19:28:50 - cmdstanpy - INFO - Chain [1] done processing
#  69%|██████▉   | 11/16 [00:01<00:00,  6.04it/s]19:28:50 - cmdstanpy - INFO - Chain [1] start processing
# 19:28:50 - cmdstanpy - INFO - Chain [1] done processing
#  75%|███████▌  | 12/16 [00:02<00:00,  6.02it/s]19:28:50 - cmdstanpy - INFO - Chain [1] start processing
# 19:28:50 - cmdstanpy - INFO - Chain [1] done processing
#  81%|████████▏ | 13/16 [00:02<00:00,  5.97it/s]19:28:51 - cmdstanpy - INFO - Chain [1] start processing
# 19:28:51 - cmdstanpy - INFO - Chain [1] done processing
#  88%|████████▊ | 14/16 [00:02<00:00,  5.96it/s]19:28:51 - cmdstanpy - INFO - Chain [1] start processing
# 19:28:51 - cmdstanpy - INFO - Chain [1] done processing
#  94%|█████████▍| 15/16 [00:02<00:00,  6.04it/s]19:28:51 - cmdstanpy - INFO - Chain [1] start processing
# 19:28:51 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 16/16 [00:02<00:00,  5.79it/s]

# %%
from prophet.diagnostics import performance_metrics
df_p = performance_metrics(df_cv)

# %%
from prophet.plot import plot_cross_validation_metric
fig = plot_cross_validation_metric(df_cv, metric='mape') # MAPE ES EL ERROR ABSOLUTO (+-) PORCENTUAL
# Out:
# c:\Users\---\AppData\Local\Programs\Python\Python312\Lib\site-packages\prophet\plot.py:546: FutureWarning: Series.view is deprecated and will be removed in a future version. Use ``astype`` as an alternative to change the dtype.
#   x_plt = df_none['horizon'].astype('timedelta64[ns]').view(np.int64) / float(dt_conversions[i])
# c:\Users\---\AppData\Local\Programs\Python\Python312\Lib\site-packages\prophet\plot.py:547: FutureWarning: Series.view is deprecated and will be removed in a future version. Use ``astype`` as an alternative to change the dtype.
#   x_plt_h = df_h['horizon'].astype('timedelta64[ns]').view(np.int64) / float(dt_conversions[i])

# %%
df_provincia5.describe()
# Out:
#             ANYO_x       count  TOTAL_VICTIMAS_24H           y  \
# count   404.000000  404.000000          404.000000  404.000000
# mean   2017.955446    4.405941            6.116337    6.116337
# min    2016.000000    1.000000            1.000000    1.000000
# 25%    2017.000000    3.000000            3.000000    3.000000
# 50%    2018.000000    4.000000            5.000000    5.000000
# 75%    2019.000000    6.000000            8.000000    8.000000
# max    2020.000000   14.000000           27.000000   27.000000
# std       1.401168    2.463342            4.061418    4.061418
#
#                                   ds
# count                            404
# mean   2018-06-04 18:53:27.920792064
# min              2016-01-01 00:00:00
# 25%              2017-03-05 18:00:00
# 50%              2018-06-03 12:00:00
# 75%              2019-08-13 06:00:00
# max              2020-12-07 00:00:00
# std                              NaN

# %% [markdown]
# ### MODELO REDES NEURONALES

# %%
PASOS=84
 
# convert series to supervised learning
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
    n_vars = 1 if type(data) is list else data.shape[1]
    df = pd.DataFrame(data)
    cols, names = list(), list()
    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
        else:
            names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
    # put it all together
    agg = pd.concat(cols, axis=1)
    agg.columns = names
    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    return agg
 
# load dataset
values = df_provincia5['TOTAL_VICTIMAS_24H'].values
# ensure all data is float
values = values.astype('float32')
# normalize features
scaler = MinMaxScaler(feature_range=(-1, 1))
values=values.reshape(-1, 1) # esto lo hacemos porque tenemos 1 sola dimension
scaled = scaler.fit_transform(values)
# frame as supervised learning
reframed = series_to_supervised(scaled, PASOS, 1)
reframed.head()
# Out:
#     var1(t-84)  var1(t-83)  var1(t-82)  var1(t-81)  var1(t-80)  var1(t-79)  \
# 84   -0.615385   -0.692308   -0.846154   -0.846154   -0.846154   -0.769231
# 85   -0.692308   -0.846154   -0.846154   -0.846154   -0.769231   -0.692308
# 86   -0.846154   -0.846154   -0.846154   -0.769231   -0.692308   -0.384615
# 87   -0.846154   -0.846154   -0.769231   -0.692308   -0.384615   -0.769231
# 88   -0.846154   -0.769231   -0.692308   -0.384615   -0.769231   -0.846154
#
#     var1(t-78)  var1(t-77)  var1(t-76)  var1(t-75)  ...  var1(t-9)  var1(t-8)  \
# 84   -0.692308   -0.384615   -0.769231   -0.846154  ...  -0.846154  -0.615385
# 85   -0.384615   -0.769231   -0.846154   -0.923077  ...  -0.615385  -0.153846
# 86   -0.769231   -0.846154   -0.923077   -0.846154  ...  -0.153846  -0.692308
# 87   -0.846154   -0.923077   -0.846154   -0.923077  ...  -0.692308  -0.769231
# 88   -0.923077   -0.846154   -0.923077   -0.307692  ...  -0.769231  -0.230769
#
#     var1(t-7)  var1(t-6)  var1(t-5)  var1(t-4)  var1(t-3)  var1(t-2)  \
# 84  -0.153846  -0.692308  -0.769231  -0.230769  -0.923077  -0.692308
# 85  -0.692308  -0.769231  -0.230769  -0.923077  -0.692308  -0.307692
# 86  -0.769231  -0.230769  -0.923077  -0.692308  -0.307692  -0.461538
# 87  -0.230769  -0.923077  -0.692308  -0.307692  -0.461538  -0.615385
# 88  -0.923077  -0.692308  -0.307692  -0.461538  -0.615385  -0.384615
#
#     var1(t-1)   var1(t)
# 84  -0.307692 -0.461538
# 85  -0.461538 -0.615385
# 86  -0.615385 -0.384615
# 87  -0.384615 -0.769231
# 88  -0.769231 -0.692308
#
# [5 rows x 85 columns]

# %%
values = reframed.values
n_train_days = 300
train = values[:n_train_days, :]
test = values[n_train_days:, :]
# split isnto input and outputs
x_train, y_train = train[:, :-1], train[:, -1]
x_val, y_val = test[:, :-1], test[:, -1]
# reshape input to be 3D [samples, timesteps, features]
x_train = x_train.reshape((x_train.shape[0], 1, x_train.shape[1]))
x_val = x_val.reshape((x_val.shape[0], 1, x_val.shape[1]))
print(x_train.shape, y_train.shape, x_val.shape, y_val.shape)
# Out:
# (300, 1, 84) (300,) (20, 1, 84) (20,)

# %%
len(values)
# Out:
# 320

# %%
def crear_modeloFF():
    model = Sequential()
    model.add(Dense(PASOS, input_shape=(1,PASOS),activation='tanh'))
    model.add(Flatten())
    model.add(Dense(1, activation='tanh'))
    model.compile(loss='mse',optimizer='Adam',metrics=["mae"])
    model.summary()
    return model

# %%
EPOCHS=20

model = crear_modeloFF()
 
history=model.fit(x_train,y_train,epochs=EPOCHS,validation_data=(x_val,y_val),batch_size=PASOS)
# Out:
# c:\Users\---\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_8 (Dense)                 │ (None, 1, 84)          │         7,140 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_4 (Flatten)             │ (None, 84)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 1)              │            85 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 7,225 (28.22 KB)
#  Trainable params: 7,225 (28.22 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.7690 - mae: 0.7710 - val_loss: 0.0273 - val_mae: 0.1355
# Epoch 2/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1210 - mae: 0.2472 - val_loss: 0.0407 - val_mae: 0.1501
# Epoch 3/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1813 - mae: 0.3327 - val_loss: 0.0441 - val_mae: 0.1574
# Epoch 4/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2131 - mae: 0.3630 - val_loss: 0.0449 - val_mae: 0.1591
# Epoch 5/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2128 - mae: 0.3604 - val_loss: 0.0452 - val_mae: 0.1597
# Epoch 6/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2166 - mae: 0.3662 - val_loss: 0.0454 - val_mae: 0.1600
# Epoch 7/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2149 - mae: 0.3735 - val_loss: 0.0454 - val_mae: 0.1600
# Epoch 8/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2229 - mae: 0.3752 - val_loss: 0.0454 - val_mae: 0.1600
# Epoch 9/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2210 - mae: 0.3764 - val_loss: 0.0453 - val_mae: 0.1599
# Epoch 10/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2180 - mae: 0.3696 - val_loss: 0.0452 - val_mae: 0.1597
# Epoch 11/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2162 - mae: 0.3701 - val_loss: 0.0450 - val_mae: 0.1593
# Epoch 12/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.2122 - mae: 0.3695 - val_loss: 0.0448 - val_mae: 0.1589
# Epoch 13/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2160 - mae: 0.3703 - val_loss: 0.0445 - val_mae: 0.1582
# Epoch 14/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2195 - mae: 0.3632 - val_loss: 0.0439 - val_mae: 0.1571
# Epoch 15/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2015 - mae: 0.3540 - val_loss: 0.0431 - val_mae: 0.1552
# Epoch 16/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2034 - mae: 0.3503 - val_loss: 0.0414 - val_mae: 0.1517
# Epoch 17/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1798 - mae: 0.3247 - val_loss: 0.0382 - val_mae: 0.1440
# Epoch 18/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1661 - mae: 0.3093 - val_loss: 0.0312 - val_mae: 0.1284
# Epoch 19/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1230 - mae: 0.2534 - val_loss: 0.0269 - val_mae: 0.1357
# Epoch 20/20
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0825 - mae: 0.1915
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0930 - mae: 0.2128 - val_loss: 0.0695 - val_mae: 0.2315

# %%
results=model.predict(x_val)
plt.scatter(range(len(y_val)),y_val,c='g')
plt.scatter(range(len(results)),results,c='r')
plt.title('validate')
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step

# %%
loss = history.history['mae']
val_loss = history.history['val_mae']

# Graficar la función de pérdida durante el entrenamiento
epochs = range(1, len(loss) + 1)

plt.plot(epochs, loss, 'bo', label='Pérdida de entrenamiento')
plt.plot(epochs, val_loss, 'b', label='Pérdida de validación')
plt.title('Función de pérdida durante el entrenamiento')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
resultados_viajes = scaler.inverse_transform(results)
resultados_viajes
# Out:
# array([[4.1336384],
#        [5.2801757],
#        [5.907548 ],
#        [6.1355596],
#        [4.118286 ],
#        [5.625738 ],
#        [2.2718394],
#        [2.8522043],
#        [5.597279 ],
#        [7.2079735],
#        [8.403979 ],
#        [5.216798 ],
#        [5.004414 ],
#        [3.1859143],
#        [2.781992 ],
#        [5.6266785],
#        [6.262288 ],
#        [7.276656 ],
#        [8.758563 ],
#        [5.583065 ]], dtype=float32)
