# %%
import pandas as pd
import numpy as np
import matplotlib.patches as mpatches
import matplotlib.pyplot as plt
import seaborn as sns
from prophet import Prophet
from sklearn.preprocessing import LabelEncoder
from datetime import datetime, timedelta
import statsmodels.api as sm
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import PowerTransformer
from scipy.stats import poisson
import datetime as dt
import matplotlib.pyplot as plt
import statsmodels as st
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.api import ExponentialSmoothing, SimpleExpSmoothing, Holt
import statsmodels.api as sm
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
import seaborn as sns
from tabulate import tabulate
import pmdarima as pm
from dateutil.relativedelta import relativedelta
from keras.models import Sequential
from keras.layers import Dense,Activation,Flatten
from sklearn.preprocessing import MinMaxScaler

# %%
df = pd.read_csv('Datos_preprocesados_accidentes_y_victimas_accidentes.csv')

# %%
db_provincia11 = df[df['COD_PROVINCIA'] == 11]

# %%
num_victimas_dia_semana11 = db_provincia11.groupby(['ANYO', 'MES', 'DIA_SEMANA', 'HORA'])['TOTAL_VICTIMAS_24H'].sum()

# %%
num_victimas_dia_semana11
# Out:
# ANYO  MES  DIA_SEMANA  HORA
# 2016  1    1           0       3
#                        7       5
#                        8       3
#                        9       5
#                        11      1
#                               ..
# 2020  12   7           18      1
#                        19      1
#                        21      2
#                        22      4
#                        23      4
# Name: TOTAL_VICTIMAS_24H, Length: 6071, dtype: int64

# %%
num_accidentes_por_dia_semana11 = db_provincia11.groupby(['ANYO', 'MES'])['DIA_SEMANA'].value_counts()

# %%
num_accidentes_por_dia_semana11
# Out:
# ANYO  MES  DIA_SEMANA
# 2016  1    2             44
#            6             41
#            1             37
#            3             33
#            7             30
#                          ..
# 2020  12   6             28
#            1             25
#            2             24
#            5             23
#            7             20
# Name: count, Length: 420, dtype: int64

# %%
plt.plot(num_accidentes_por_dia_semana11.values)

# %%
plt.plot(num_victimas_dia_semana11.values)

# %%
num_accidentes_por_dia_semana11 = num_accidentes_por_dia_semana11.reset_index()

# %%
num_accidentes_por_dia_semana11['FECHA'] = num_accidentes_por_dia_semana11.apply(lambda row: str(row['ANYO']) + '/' + str(row['MES']) + '/' + str(row['DIA_SEMANA']), axis = 1)

# %%
num_accidentes_por_dia_semana11
# Out:
#      ANYO  MES  DIA_SEMANA  count      FECHA
# 0    2016    1           2     44   2016/1/2
# 1    2016    1           6     41   2016/1/6
# 2    2016    1           1     37   2016/1/1
# 3    2016    1           3     33   2016/1/3
# 4    2016    1           7     30   2016/1/7
# ..    ...  ...         ...    ...        ...
# 415  2020   12           6     28  2020/12/6
# 416  2020   12           1     25  2020/12/1
# 417  2020   12           2     24  2020/12/2
# 418  2020   12           5     23  2020/12/5
# 419  2020   12           7     20  2020/12/7
#
# [420 rows x 5 columns]

# %%
num_victimas_dia_semana11 = num_victimas_dia_semana11.reset_index()

# %%
num_victimas_dia_semana11
# Out:
#       ANYO  MES  DIA_SEMANA  HORA  TOTAL_VICTIMAS_24H
# 0     2016    1           1     0                   3
# 1     2016    1           1     7                   5
# 2     2016    1           1     8                   3
# 3     2016    1           1     9                   5
# 4     2016    1           1    11                   1
# ...    ...  ...         ...   ...                 ...
# 6066  2020   12           7    18                   1
# 6067  2020   12           7    19                   1
# 6068  2020   12           7    21                   2
# 6069  2020   12           7    22                   4
# 6070  2020   12           7    23                   4
#
# [6071 rows x 5 columns]

# %%
num_victimas_dia_semana11['FECHA'] = num_victimas_dia_semana11.apply(lambda row: str(row['ANYO']) + '/' + str(row['MES']) + '/' + str(row['DIA_SEMANA']), axis = 1)

# %%
num_victimas_dia_semana11
# Out:
#       ANYO  MES  DIA_SEMANA  HORA  TOTAL_VICTIMAS_24H      FECHA
# 0     2016    1           1     0                   3   2016/1/1
# 1     2016    1           1     7                   5   2016/1/1
# 2     2016    1           1     8                   3   2016/1/1
# 3     2016    1           1     9                   5   2016/1/1
# 4     2016    1           1    11                   1   2016/1/1
# ...    ...  ...         ...   ...                 ...        ...
# 6066  2020   12           7    18                   1  2020/12/7
# 6067  2020   12           7    19                   1  2020/12/7
# 6068  2020   12           7    21                   2  2020/12/7
# 6069  2020   12           7    22                   4  2020/12/7
# 6070  2020   12           7    23                   4  2020/12/7
#
# [6071 rows x 6 columns]

# %%
num_accidentes_por_dia_semana11
# Out:
#      ANYO  MES  DIA_SEMANA  count      FECHA
# 0    2016    1           2     44   2016/1/2
# 1    2016    1           6     41   2016/1/6
# 2    2016    1           1     37   2016/1/1
# 3    2016    1           3     33   2016/1/3
# 4    2016    1           7     30   2016/1/7
# ..    ...  ...         ...    ...        ...
# 415  2020   12           6     28  2020/12/6
# 416  2020   12           1     25  2020/12/1
# 417  2020   12           2     24  2020/12/2
# 418  2020   12           5     23  2020/12/5
# 419  2020   12           7     20  2020/12/7
#
# [420 rows x 5 columns]

# %%
num_victimas_dia_semana11
# Out:
#       ANYO  MES  DIA_SEMANA  HORA  TOTAL_VICTIMAS_24H      FECHA
# 0     2016    1           1     0                   3   2016/1/1
# 1     2016    1           1     7                   5   2016/1/1
# 2     2016    1           1     8                   3   2016/1/1
# 3     2016    1           1     9                   5   2016/1/1
# 4     2016    1           1    11                   1   2016/1/1
# ...    ...  ...         ...   ...                 ...        ...
# 6066  2020   12           7    18                   1  2020/12/7
# 6067  2020   12           7    19                   1  2020/12/7
# 6068  2020   12           7    21                   2  2020/12/7
# 6069  2020   12           7    22                   4  2020/12/7
# 6070  2020   12           7    23                   4  2020/12/7
#
# [6071 rows x 6 columns]

# %%
df_provincia11 = num_accidentes_por_dia_semana11.merge(num_victimas_dia_semana11, on = 'FECHA')

# %%
df_provincia11 = df_provincia11[['ANYO_x', 'FECHA', 'count', 'TOTAL_VICTIMAS_24H']]

# %%
df_provincia11.describe()
# Out:
#             ANYO_x        count  TOTAL_VICTIMAS_24H
# count  6071.000000  6071.000000         6071.000000
# mean   2017.940866    32.739746            3.145775
# std       1.395673     9.382875            2.373314
# min    2016.000000     2.000000            1.000000
# 25%    2017.000000    26.000000            1.000000
# 50%    2018.000000    32.000000            2.000000
# 75%    2019.000000    38.000000            4.000000
# max    2020.000000    58.000000           26.000000

# %% [markdown]
# ### MODELO PROPHET

# %%
df_provincia11['y'] = df_provincia11['count']
df_provincia11['ds'] = pd.to_datetime(pd.to_datetime(df_provincia11['FECHA']).dt.date)

# %%
ts = df_provincia11[['ds', 'y']]
model = Prophet(
   yearly_seasonality=True,
   seasonality_mode=['additive','multiplicative'][0]
   ).add_country_holidays(country_name='ESP'
   ).fit(ts)

future = model.make_future_dataframe(periods=10)
forecast = model.predict(future)
fig1 = model.plot(forecast)
# Out:
# 16:42:55 - cmdstanpy - INFO - Chain [1] start processing
# 16:42:56 - cmdstanpy - INFO - Chain [1] done processing
# c:\Users\---\AppData\Local\Programs\Python\Python312\Lib\site-packages\prophet\plot.py:72: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   fcst_t = fcst['ds'].dt.to_pydatetime()
# c:\Users\---\AppData\Local\Programs\Python\Python312\Lib\site-packages\prophet\plot.py:73: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   ax.plot(m.history['ds'].dt.to_pydatetime(), m.history['y'], 'k.',

# %%
fig2 = model.plot_components(forecast)
# Out:
# c:\Users\---\AppData\Local\Programs\Python\Python312\Lib\site-packages\prophet\plot.py:228: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   fcst_t = fcst['ds'].dt.to_pydatetime()
# c:\Users\---\AppData\Local\Programs\Python\Python312\Lib\site-packages\prophet\plot.py:351: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   df_y['ds'].dt.to_pydatetime(), seas[name], ls='-', c='#0072B2')
# c:\Users\---\AppData\Local\Programs\Python\Python312\Lib\site-packages\prophet\plot.py:354: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   df_y['ds'].dt.to_pydatetime(), seas[name + '_lower'],

# %% [markdown]
# ### MODELO REDES NEURONALES

# %%
PASOS=336
 
# convert series to supervised learning
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
    n_vars = 1 if type(data) is list else data.shape[1]
    df = pd.DataFrame(data)
    cols, names = list(), list()
    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
        else:
            names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
    # put it all together
    agg = pd.concat(cols, axis=1)
    agg.columns = names
    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    return agg
 
# load dataset
values = df_provincia11['count'].values
# ensure all data is float
values = values.astype('float32')
# normalize features
scaler = MinMaxScaler(feature_range=(-1, 1))
values=values.reshape(-1, 1) # esto lo hacemos porque tenemos 1 sola dimension
scaled = scaler.fit_transform(values)
# frame as supervised learning
reframed = series_to_supervised(scaled, PASOS, 1)
reframed.head()
# Out:
#      var1(t-336)  var1(t-335)  var1(t-334)  var1(t-333)  var1(t-332)  \
# 336          0.5          0.5          0.5          0.5          0.5
# 337          0.5          0.5          0.5          0.5          0.5
# 338          0.5          0.5          0.5          0.5          0.5
# 339          0.5          0.5          0.5          0.5          0.5
# 340          0.5          0.5          0.5          0.5          0.5
#
#      var1(t-331)  var1(t-330)  var1(t-329)  var1(t-328)  var1(t-327)  ...  \
# 336          0.5          0.5          0.5          0.5          0.5  ...
# 337          0.5          0.5          0.5          0.5          0.5  ...
# 338          0.5          0.5          0.5          0.5          0.5  ...
# 339          0.5          0.5          0.5          0.5          0.5  ...
# 340          0.5          0.5          0.5          0.5          0.5  ...
#
#      var1(t-9)  var1(t-8)  var1(t-7)  var1(t-6)  var1(t-5)  var1(t-4)  \
# 336   0.285714   0.285714   0.285714   0.285714   0.285714   0.285714
# 337   0.285714   0.285714   0.285714   0.285714   0.285714   0.285714
# 338   0.285714   0.285714   0.285714   0.285714   0.285714   0.285714
# 339   0.285714   0.285714   0.285714   0.285714   0.285714   0.285714
# 340   0.285714   0.285714   0.285714   0.285714   0.285714   0.285714
#
#      var1(t-3)  var1(t-2)  var1(t-1)   var1(t)
# 336   0.285714   0.285714   0.285714  0.285714
# 337   0.285714   0.285714   0.285714  0.285714
# 338   0.285714   0.285714   0.285714  0.285714
# 339   0.285714   0.285714   0.285714  0.285714
# 340   0.285714   0.285714   0.285714  0.285714
#
# [5 rows x 337 columns]

# %%
values = reframed.values
n_train_days = 5500
train = values[:n_train_days, :]
test = values[n_train_days:, :]
# split isnto input and outputs
x_train, y_train = train[:, :-1], train[:, -1]
x_val, y_val = test[:, :-1], test[:, -1]
# reshape input to be 3D [samples, timesteps, features]
x_train = x_train.reshape((x_train.shape[0], 1, x_train.shape[1]))
x_val = x_val.reshape((x_val.shape[0], 1, x_val.shape[1]))
print(x_train.shape, y_train.shape, x_val.shape, y_val.shape)
# Out:
# (5500, 1, 336) (5500,) (235, 1, 336) (235,)

# %%
len(values)
# Out:
# 5735

# %%
def crear_modeloFF():
    model = Sequential()
    model.add(Dense(PASOS, input_shape=(1,PASOS),activation='tanh'))
    model.add(Flatten())
    model.add(Dense(1, activation='tanh'))
    model.compile(loss='mean_absolute_error',optimizer='Adam',metrics=["mse"])
    model.summary()
    return model

# %%
EPOCHS=40

model = crear_modeloFF()
 
history=model.fit(x_train,y_train,epochs=EPOCHS,validation_data=(x_val,y_val),batch_size=PASOS)
# Out:
# c:\Users\---\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 1, 336)         │       113,232 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 336)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │           337 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 113,569 (443.63 KB)
#  Trainable params: 113,569 (443.63 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/40
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.3566 - mse: 0.1982 - val_loss: 0.1766 - val_mse: 0.0481
# Epoch 2/40
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.1392 - mse: 0.0363 - val_loss: 0.1205 - val_mse: 0.0254
# Epoch 3/40
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.1036 - mse: 0.0243 - val_loss: 0.0894 - val_mse: 0.0133
# Epoch 4/40
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.0917 - mse: 0.0199 - val_loss: 0.0627 - val_mse: 0.0080
# Epoch 5/40
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0704 - mse: 0.0131 - val_loss: 0.0594 - val_mse: 0.0074
# Epoch 6/40
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 0.0692 - mse: 0.0144 - val_loss: 0.0691 - val_mse: 0.0087
# Epoch 7/40
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.0626 - mse: 0.0120 - val_loss: 0.0624 - val_mse: 0.0074
# Epoch 8/40
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 0.0607 - mse: 0.0126 - val_loss: 0.0625 - val_mse: 0.0078
# Epoch 9/40
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.0821 - mse: 0.0170 - val_loss: 0.0507 - val_mse: 0.0056
# Epoch 10/40
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0717 - mse: 0.0137 - val_loss: 0.0551 - val_mse: 0.0065
# Epoch 11/40
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0565 - mse: 0.0109 - val_loss: 0.0539 - val_mse: 0.0057
# Epoch 12/40
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0698 - mse: 0.0137 - val_loss: 0.0707 - val_mse: 0.0094
# Epoch 13/40
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.0624 - mse: 0.0132 - val_loss: 0.0621 - val_mse: 0.0074
# Epoch 14/40
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.0624 - mse: 0.0129 - val_loss: 0.0645 - val_mse: 0.0074
# Epoch 15/40
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0559 - mse: 0.0105 - val_loss: 0.0633 - val_mse: 0.0078
# Epoch 16/40
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0676 - mse: 0.0129 - val_loss: 0.0489 - val_mse: 0.0050
# Epoch 17/40
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0630 - mse: 0.0126 - val_loss: 0.0408 - val_mse: 0.0042
# Epoch 18/40
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.0557 - mse: 0.0100 - val_loss: 0.0550 - val_mse: 0.0061
# Epoch 19/40
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0625 - mse: 0.0111 - val_loss: 0.0396 - val_mse: 0.0040
# Epoch 20/40
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0409 - mse: 0.0086 - val_loss: 0.0577 - val_mse: 0.0061
# Epoch 21/40
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0471 - mse: 0.0098 - val_loss: 0.0485 - val_mse: 0.0048
# Epoch 22/40
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0442 - mse: 0.0098 - val_loss: 0.0512 - val_mse: 0.0052
# Epoch 23/40
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.0531 - mse: 0.0112 - val_loss: 0.0412 - val_mse: 0.0043
# Epoch 24/40
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0463 - mse: 0.0104 - val_loss: 0.0684 - val_mse: 0.0076
# Epoch 25/40
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.0637 - mse: 0.0115 - val_loss: 0.0574 - val_mse: 0.0060
# Epoch 26/40
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.0598 - mse: 0.0128 - val_loss: 0.0493 - val_mse: 0.0050
# Epoch 27/40
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.0575 - mse: 0.0106 - val_loss: 0.0482 - val_mse: 0.0051
# Epoch 28/40
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.0531 - mse: 0.0108 - val_loss: 0.0525 - val_mse: 0.0060
# Epoch 29/40
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0548 - mse: 0.0115 - val_loss: 0.0402 - val_mse: 0.0038
# Epoch 30/40
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0415 - mse: 0.0101 - val_loss: 0.0539 - val_mse: 0.0057
# Epoch 31/40
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0468 - mse: 0.0089 - val_loss: 0.0375 - val_mse: 0.0039
# Epoch 32/40
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.0430 - mse: 0.0091 - val_loss: 0.0432 - val_mse: 0.0046
# Epoch 33/40
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0614 - mse: 0.0117 - val_loss: 0.0389 - val_mse: 0.0041
# Epoch 34/40
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0557 - mse: 0.0109 - val_loss: 0.0533 - val_mse: 0.0057
# Epoch 35/40
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0457 - mse: 0.0102 - val_loss: 0.0542 - val_mse: 0.0056
# Epoch 36/40
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0478 - mse: 0.0095 - val_loss: 0.0550 - val_mse: 0.0055
# Epoch 37/40
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.0445 - mse: 0.0088 - val_loss: 0.0309 - val_mse: 0.0034
# Epoch 38/40
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0517 - mse: 0.0105 - val_loss: 0.0312 - val_mse: 0.0035
# Epoch 39/40
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0552 - mse: 0.0097 - val_loss: 0.0334 - val_mse: 0.0036
# Epoch 40/40
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0472 - mse: 0.0096 - val_loss: 0.0558 - val_mse: 0.0060

# %%
results=model.predict(x_val)
plt.scatter(range(len(y_val)),y_val,c='g')
plt.scatter(range(len(results)),results,c='r')
plt.title('validate')
plt.show()
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']

# Graficar la función de pérdida durante el entrenamiento
epochs = range(1, len(loss) + 1)

plt.plot(epochs, loss, 'bo', label='Pérdida de entrenamiento')
plt.plot(epochs, val_loss, 'b', label='Pérdida de validación')
plt.title('Función de pérdida durante el entrenamiento')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
resultados_viajes = scaler.inverse_transform(results)
resultados_viajes
# Out:
# array([[28.14343 ],
#        [27.461687],
#        [27.376787],
#        [27.505693],
#        [27.324257],
#        [27.880625],
#        [27.003227],
#        [27.441378],
#        [26.718185],
#        [27.95303 ],
#        [27.960993],
#        [28.150415],
#        [28.014011],
#        [27.597971],
#        [28.851498],
#        [29.291336],
#        [28.091442],
#        [28.17044 ],
#        [29.208223],
#        [29.403399],
#        [29.218552],
#        [29.209967],
#        [29.638914],
#        [29.890863],
#        [25.772394],
#        [24.755053],
#        [24.375847],
#        [24.944054],
#        [25.307695],
#        [25.562384],
#        [25.890388],
#        [25.990158],
#        [26.23241 ],
#        [25.94741 ],
#        [25.355627],
#        [24.601337],
#        [24.28158 ],
#        [24.19663 ],
#        [25.42873 ],
#        [25.17859 ],
#        [25.437881],
#        [24.951164],
#        [25.159826],
#        [25.097376],
#        [24.467472],
#        [24.95949 ],
#        [25.140146],
#        [24.455425],
#        [24.211948],
#        [25.388794],
#        [25.126509],
#        [25.228706],
#        [25.30249 ],
#        [24.61114 ],
#        [24.908205],
#        [25.042803],
#        [24.033205],
#        [22.424648],
#        [23.24751 ],
#        [22.50053 ],
#        [23.886625],
#        [25.051237],
#        [24.88481 ],
#        [25.448093],
#        [25.37224 ],
#        [25.663433],
#        [24.967106],
#        [25.833153],
#        [25.460234],
#        [24.66089 ],
#        [24.533634],
#        [24.275934],
#        [24.120378],
#        [20.696596],
#        [20.691477],
#        [19.965078],
#        [20.928385],
#        [21.399231],
#        [21.309927],
#        [20.811937],
#        [20.249996],
#        [20.131449],
#        [20.157518],
#        [21.268227],
#        [20.319542],
#        [20.173698],
#        [20.296831],
#        [20.326286],
#        [20.240282],
#        [20.402555],
#        [20.686882],
#        [20.797255],
#        [20.53346 ],
#        [20.092703],
#        [20.396711],
#        [20.897694],
#        [20.834534],
#        [20.67094 ],
#        [20.825975],
#        [20.916967],
#        [20.180508],
#        [20.506607],
#        [20.32682 ],
#        [20.661604],
#        [20.19645 ],
#        [20.59879 ],
#        [20.745728],
#        [20.767273],
#        [20.713568],
#        [20.924965],
#        [21.330881],
#        [20.84957 ],
#        [18.12314 ],
#        [17.65038 ],
#        [17.752195],
#        [18.201908],
#        [18.525993],
#        [18.068647],
#        [18.148476],
#        [18.367138],
#        [18.26291 ],
#        [18.737991],
#        [19.461823],
#        [19.145664],
#        [18.901163],
#        [15.990131],
#        [16.018663],
#        [16.109226],
#        [15.96061 ],
#        [15.80494 ],
#        [15.570468],
#        [15.458584],
#        [15.594597],
#        [15.984963],
#        [15.879955],
#        [11.03587 ],
#        [10.93065 ],
#        [10.658137],
#        [11.108893],
#        [10.881082],
#        [11.324236],
#        [11.312318],
#        [11.6268  ],
#        [28.86112 ],
#        [30.15405 ],
#        [30.23023 ],
#        [30.523615],
#        [30.5842  ],
#        [30.012865],
#        [30.547874],
#        [30.633247],
#        [30.844347],
#        [31.108809],
#        [31.524479],
#        [31.59627 ],
#        [30.36168 ],
#        [30.369152],
#        [29.987066],
#        [29.913761],
#        [29.942005],
#        [29.663048],
#        [28.771105],
#        [28.289501],
#        [27.926706],
#        [28.101664],
#        [28.74579 ],
#        [28.969864],
#        [28.729982],
#        [28.381622],
#        [27.39593 ],
#        [26.951561],
#        [27.537382],
#        [27.105541],
#        [27.078026],
#        [26.78275 ],
#        [25.809902],
#        [25.96158 ],
#        [25.639784],
#        [25.337475],
#        [25.07592 ],
#        [26.279398],
#        [26.786474],
#        [26.165474],
#        [23.472569],
#        [23.375004],
#        [23.072763],
#        [23.102663],
#        [23.167194],
#        [23.304117],
#        [23.673113],
#        [24.181938],
#        [24.308266],
#        [23.754332],
#        [23.30156 ],
#        [23.539276],
#        [23.244442],
#        [22.750591],
#        [22.947403],
#        [22.036234],
#        [22.401299],
#        [22.646158],
#        [23.099638],
#        [23.192276],
#        [23.172592],
#        [22.60849 ],
#        [22.705017],
#        [23.032068],
#        [23.292746],
#        [22.66105 ],
#        [22.068611],
#        [22.317076],
#        [22.633707],
#        [23.35506 ],
#        [22.803812],
#        [22.932507],
#        [23.101082],
#        [23.582113],
#        [23.755655],
#        [23.465778],
#        [23.747017],
#        [23.637724],
#        [23.84168 ],
#        [20.71376 ],
#        [20.823944],
#        [20.094492],
#        [20.076881],
#        [19.837664],
#        [19.70561 ],
#        [19.375051],
#        [19.7343  ],
#        [19.375517],
#        [19.079542],
#        [19.267574],
#        [19.032658],
#        [19.448906]], dtype=float32)
