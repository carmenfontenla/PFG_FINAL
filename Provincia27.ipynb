# %%
import pandas as pd
import numpy as np
import matplotlib.patches as mpatches
import matplotlib.pyplot as plt
import seaborn as sns
from prophet import Prophet
from sklearn.preprocessing import LabelEncoder
from datetime import datetime, timedelta
import statsmodels.api as sm
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import PowerTransformer
from scipy.stats import poisson
import datetime as dt
import matplotlib.pyplot as plt
import statsmodels as st
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.api import ExponentialSmoothing, SimpleExpSmoothing, Holt
import statsmodels.api as sm
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
import seaborn as sns
from tabulate import tabulate
import pmdarima as pm
from dateutil.relativedelta import relativedelta
from keras.models import Sequential
from keras.layers import Dense,Activation,Flatten
from sklearn.preprocessing import MinMaxScaler

# %%
df = pd.read_csv('Datos_preprocesados_accidentes_y_victimas_accidentes.csv')

# %%
db_provincia27 = df[df['COD_PROVINCIA'] == 27]

# %%
num_victimas_dia_semana27 = db_provincia27.groupby(['ANYO', 'MES', 'DIA_SEMANA', 'HORA'])['TOTAL_VICTIMAS_24H'].sum()

# %%
num_victimas_dia_semana27
# Out:
# ANYO  MES  DIA_SEMANA  HORA
# 2016  1    1           11      3
#                        15      2
#                        18      1
#            2           0       1
#                        7       1
#                               ..
# 2020  12   5           19      3
#                        20      2
#                        23      1
#            6           11      2
#                        22      1
# Name: TOTAL_VICTIMAS_24H, Length: 2131, dtype: int64

# %%
num_accidentes_por_dia_semana27 = db_provincia27.groupby(['ANYO', 'MES'])['DIA_SEMANA'].value_counts()

# %%
num_accidentes_por_dia_semana27
# Out:
# ANYO  MES  DIA_SEMANA
# 2016  1    2             10
#            4             10
#            7              9
#            6              8
#            3              7
#                          ..
# 2020  12   2              7
#            1              5
#            3              5
#            4              4
#            6              2
# Name: count, Length: 414, dtype: int64

# %%
plt.plot(num_accidentes_por_dia_semana27.values)

# %%
plt.plot(num_victimas_dia_semana27.values)

# %%
num_accidentes_por_dia_semana27 = num_accidentes_por_dia_semana27.reset_index()

# %%
num_accidentes_por_dia_semana27['FECHA'] = num_accidentes_por_dia_semana27.apply(lambda row: str(row['ANYO']) + '/' + str(row['MES']) + '/' + str(row['DIA_SEMANA']), axis = 1)

# %%
num_accidentes_por_dia_semana27
# Out:
#      ANYO  MES  DIA_SEMANA  count      FECHA
# 0    2016    1           2     10   2016/1/2
# 1    2016    1           4     10   2016/1/4
# 2    2016    1           7      9   2016/1/7
# 3    2016    1           6      8   2016/1/6
# 4    2016    1           3      7   2016/1/3
# ..    ...  ...         ...    ...        ...
# 409  2020   12           2      7  2020/12/2
# 410  2020   12           1      5  2020/12/1
# 411  2020   12           3      5  2020/12/3
# 412  2020   12           4      4  2020/12/4
# 413  2020   12           6      2  2020/12/6
#
# [414 rows x 5 columns]

# %%
num_victimas_dia_semana27 = num_victimas_dia_semana27.reset_index()

# %%
num_victimas_dia_semana27
# Out:
#       ANYO  MES  DIA_SEMANA  HORA  TOTAL_VICTIMAS_24H
# 0     2016    1           1    11                   3
# 1     2016    1           1    15                   2
# 2     2016    1           1    18                   1
# 3     2016    1           2     0                   1
# 4     2016    1           2     7                   1
# ...    ...  ...         ...   ...                 ...
# 2126  2020   12           5    19                   3
# 2127  2020   12           5    20                   2
# 2128  2020   12           5    23                   1
# 2129  2020   12           6    11                   2
# 2130  2020   12           6    22                   1
#
# [2131 rows x 5 columns]

# %%
num_victimas_dia_semana27['FECHA'] = num_victimas_dia_semana27.apply(lambda row: str(row['ANYO']) + '/' + str(row['MES']) + '/' + str(row['DIA_SEMANA']), axis = 1)

# %%
num_victimas_dia_semana27
# Out:
#       ANYO  MES  DIA_SEMANA  HORA  TOTAL_VICTIMAS_24H      FECHA
# 0     2016    1           1    11                   3   2016/1/1
# 1     2016    1           1    15                   2   2016/1/1
# 2     2016    1           1    18                   1   2016/1/1
# 3     2016    1           2     0                   1   2016/1/2
# 4     2016    1           2     7                   1   2016/1/2
# ...    ...  ...         ...   ...                 ...        ...
# 2126  2020   12           5    19                   3  2020/12/5
# 2127  2020   12           5    20                   2  2020/12/5
# 2128  2020   12           5    23                   1  2020/12/5
# 2129  2020   12           6    11                   2  2020/12/6
# 2130  2020   12           6    22                   1  2020/12/6
#
# [2131 rows x 6 columns]

# %%
num_accidentes_por_dia_semana27
# Out:
#      ANYO  MES  DIA_SEMANA  count      FECHA
# 0    2016    1           2     10   2016/1/2
# 1    2016    1           4     10   2016/1/4
# 2    2016    1           7      9   2016/1/7
# 3    2016    1           6      8   2016/1/6
# 4    2016    1           3      7   2016/1/3
# ..    ...  ...         ...    ...        ...
# 409  2020   12           2      7  2020/12/2
# 410  2020   12           1      5  2020/12/1
# 411  2020   12           3      5  2020/12/3
# 412  2020   12           4      4  2020/12/4
# 413  2020   12           6      2  2020/12/6
#
# [414 rows x 5 columns]

# %%
num_victimas_dia_semana27
# Out:
#       ANYO  MES  DIA_SEMANA  HORA  TOTAL_VICTIMAS_24H      FECHA
# 0     2016    1           1    11                   3   2016/1/1
# 1     2016    1           1    15                   2   2016/1/1
# 2     2016    1           1    18                   1   2016/1/1
# 3     2016    1           2     0                   1   2016/1/2
# 4     2016    1           2     7                   1   2016/1/2
# ...    ...  ...         ...   ...                 ...        ...
# 2126  2020   12           5    19                   3  2020/12/5
# 2127  2020   12           5    20                   2  2020/12/5
# 2128  2020   12           5    23                   1  2020/12/5
# 2129  2020   12           6    11                   2  2020/12/6
# 2130  2020   12           6    22                   1  2020/12/6
#
# [2131 rows x 6 columns]

# %%
df_provincia27 = num_accidentes_por_dia_semana27.merge(num_victimas_dia_semana27, on = 'FECHA')

# %%
df_provincia27 = df_provincia27[['ANYO_x', 'FECHA', 'count', 'TOTAL_VICTIMAS_24H']]

# %%
df_provincia27.describe()
# Out:
#             ANYO_x        count  TOTAL_VICTIMAS_24H
# count  2131.000000  2131.000000         2131.000000
# mean   2017.807133     7.155326            1.738151
# std       1.380571     2.661461            1.208322
# min    2016.000000     1.000000            1.000000
# 25%    2017.000000     5.000000            1.000000
# 50%    2018.000000     7.000000            1.000000
# 75%    2019.000000     9.000000            2.000000
# max    2020.000000    15.000000           17.000000

# %% [markdown]
# ### MODELO PROPHET

# %%
df_provincia27['y'] = df_provincia27['count']
df_provincia27['ds'] = pd.to_datetime(pd.to_datetime(df_provincia27['FECHA']).dt.date)

# %%
ts = df_provincia27[['ds', 'y']]
model = Prophet(
   yearly_seasonality=True,
   seasonality_mode=['additive','multiplicative'][0]
   ).add_country_holidays(country_name='ESP'
   ).fit(ts)

future = model.make_future_dataframe(periods=10)
forecast = model.predict(future)
fig1 = model.plot(forecast)
# Out:
# 17:35:54 - cmdstanpy - INFO - Chain [1] start processing
# 17:35:54 - cmdstanpy - INFO - Chain [1] done processing
# c:\Users\---\AppData\Local\Programs\Python\Python312\Lib\site-packages\prophet\plot.py:72: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   fcst_t = fcst['ds'].dt.to_pydatetime()
# c:\Users\---\AppData\Local\Programs\Python\Python312\Lib\site-packages\prophet\plot.py:73: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   ax.plot(m.history['ds'].dt.to_pydatetime(), m.history['y'], 'k.',

# %%
fig2 = model.plot_components(forecast)
# Out:
# c:\Users\---\AppData\Local\Programs\Python\Python312\Lib\site-packages\prophet\plot.py:228: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   fcst_t = fcst['ds'].dt.to_pydatetime()
# c:\Users\---\AppData\Local\Programs\Python\Python312\Lib\site-packages\prophet\plot.py:351: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   df_y['ds'].dt.to_pydatetime(), seas[name], ls='-', c='#0072B2')
# c:\Users\---\AppData\Local\Programs\Python\Python312\Lib\site-packages\prophet\plot.py:354: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   df_y['ds'].dt.to_pydatetime(), seas[name + '_lower'],

# %% [markdown]
# ### MODELO REDES NEURONALES

# %%
PASOS=336
 
# convert series to supervised learning
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
    n_vars = 1 if type(data) is list else data.shape[1]
    df = pd.DataFrame(data)
    cols, names = list(), list()
    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
        else:
            names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
    # put it all together
    agg = pd.concat(cols, axis=1)
    agg.columns = names
    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    return agg
 
# load dataset
values = df_provincia27['count'].values
# ensure all data is float
values = values.astype('float32')
# normalize features
scaler = MinMaxScaler(feature_range=(-1, 1))
values=values.reshape(-1, 1) # esto lo hacemos porque tenemos 1 sola dimension
scaled = scaler.fit_transform(values)
# frame as supervised learning
reframed = series_to_supervised(scaled, PASOS, 1)
reframed.head()
# Out:
#      var1(t-336)  var1(t-335)  var1(t-334)  var1(t-333)  var1(t-332)  \
# 336     0.285714     0.285714     0.285714     0.285714     0.285714
# 337     0.285714     0.285714     0.285714     0.285714     0.285714
# 338     0.285714     0.285714     0.285714     0.285714     0.285714
# 339     0.285714     0.285714     0.285714     0.285714     0.285714
# 340     0.285714     0.285714     0.285714     0.285714     0.285714
#
#      var1(t-331)  var1(t-330)  var1(t-329)  var1(t-328)  var1(t-327)  ...  \
# 336     0.285714     0.285714     0.285714     0.285714     0.285714  ...
# 337     0.285714     0.285714     0.285714     0.285714     0.285714  ...
# 338     0.285714     0.285714     0.285714     0.285714     0.285714  ...
# 339     0.285714     0.285714     0.285714     0.285714     0.285714  ...
# 340     0.285714     0.285714     0.285714     0.285714     0.285714  ...
#
#      var1(t-9)  var1(t-8)  var1(t-7)  var1(t-6)  var1(t-5)  var1(t-4)  \
# 336   0.428571   0.428571   0.142857   0.142857   0.142857   0.142857
# 337   0.428571   0.142857   0.142857   0.142857   0.142857   0.142857
# 338   0.142857   0.142857   0.142857   0.142857   0.142857   0.142857
# 339   0.142857   0.142857   0.142857   0.142857   0.142857   0.000000
# 340   0.142857   0.142857   0.142857   0.142857   0.000000   0.000000
#
#      var1(t-3)  var1(t-2)  var1(t-1)  var1(t)
# 336   0.142857   0.142857        0.0      0.0
# 337   0.142857   0.000000        0.0      0.0
# 338   0.000000   0.000000        0.0      0.0
# 339   0.000000   0.000000        0.0      0.0
# 340   0.000000   0.000000        0.0      0.0
#
# [5 rows x 337 columns]

# %%
values = reframed.values
n_train_days = 1600
train = values[:n_train_days, :]
test = values[n_train_days:, :]
# split isnto input and outputs
x_train, y_train = train[:, :-1], train[:, -1]
x_val, y_val = test[:, :-1], test[:, -1]
# reshape input to be 3D [samples, timesteps, features]
x_train = x_train.reshape((x_train.shape[0], 1, x_train.shape[1]))
x_val = x_val.reshape((x_val.shape[0], 1, x_val.shape[1]))
print(x_train.shape, y_train.shape, x_val.shape, y_val.shape)
# Out:
# (1600, 1, 336) (1600,) (195, 1, 336) (195,)

# %%
len(values)
# Out:
# 1795

# %%
def crear_modeloFF():
    model = Sequential()
    model.add(Dense(PASOS, input_shape=(1,PASOS),activation='tanh'))
    model.add(Flatten())
    model.add(Dense(1, activation='tanh'))
    model.compile(loss='mean_absolute_error',optimizer='Adam',metrics=["mse"])
    model.summary()
    return model

# %%
EPOCHS=40

model = crear_modeloFF()
 
history=model.fit(x_train,y_train,epochs=EPOCHS,validation_data=(x_val,y_val),batch_size=PASOS)
# Out:
# c:\Users\---\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 1, 336)         │       113,232 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 336)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │           337 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 113,569 (443.63 KB)
#  Trainable params: 113,569 (443.63 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/40
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 0.3907 - mse: 0.2429 - val_loss: 0.2967 - val_mse: 0.1443
# Epoch 2/40
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.2798 - mse: 0.1284 - val_loss: 0.2213 - val_mse: 0.0824
# Epoch 3/40
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.2251 - mse: 0.0904 - val_loss: 0.2002 - val_mse: 0.0689
# Epoch 4/40
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.1890 - mse: 0.0690 - val_loss: 0.1867 - val_mse: 0.0591
# Epoch 5/40
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.1682 - mse: 0.0597 - val_loss: 0.1551 - val_mse: 0.0512
# Epoch 6/40
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.1503 - mse: 0.0537 - val_loss: 0.1549 - val_mse: 0.0494
# Epoch 7/40
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.1365 - mse: 0.0493 - val_loss: 0.1456 - val_mse: 0.0429
# Epoch 8/40
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.1211 - mse: 0.0385 - val_loss: 0.1410 - val_mse: 0.0411
# Epoch 9/40
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.1141 - mse: 0.0393 - val_loss: 0.1211 - val_mse: 0.0350
# Epoch 10/40
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.1098 - mse: 0.0381 - val_loss: 0.1270 - val_mse: 0.0367
# Epoch 11/40
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.1120 - mse: 0.0384 - val_loss: 0.1149 - val_mse: 0.0337
# Epoch 12/40
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.1080 - mse: 0.0411 - val_loss: 0.1552 - val_mse: 0.0424
# Epoch 13/40
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.1070 - mse: 0.0396 - val_loss: 0.1275 - val_mse: 0.0358
# Epoch 14/40
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.1086 - mse: 0.0384 - val_loss: 0.1171 - val_mse: 0.0318
# Epoch 15/40
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.1035 - mse: 0.0372 - val_loss: 0.1287 - val_mse: 0.0355
# Epoch 16/40
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.0980 - mse: 0.0334 - val_loss: 0.0982 - val_mse: 0.0290
# Epoch 17/40
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.0952 - mse: 0.0334 - val_loss: 0.1416 - val_mse: 0.0397
# Epoch 18/40
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.0979 - mse: 0.0347 - val_loss: 0.1025 - val_mse: 0.0286
# Epoch 19/40
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.0955 - mse: 0.0332 - val_loss: 0.1347 - val_mse: 0.0366
# Epoch 20/40
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.0946 - mse: 0.0327 - val_loss: 0.1025 - val_mse: 0.0296
# Epoch 21/40
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.0893 - mse: 0.0328 - val_loss: 0.1023 - val_mse: 0.0297
# Epoch 22/40
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0931 - mse: 0.0365 - val_loss: 0.1022 - val_mse: 0.0290
# Epoch 23/40
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0850 - mse: 0.0302 - val_loss: 0.1147 - val_mse: 0.0321
# Epoch 24/40
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0982 - mse: 0.0384 - val_loss: 0.1211 - val_mse: 0.0338
# Epoch 25/40
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0914 - mse: 0.0328 - val_loss: 0.0974 - val_mse: 0.0277
# Epoch 26/40
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0828 - mse: 0.0316 - val_loss: 0.1086 - val_mse: 0.0309
# Epoch 27/40
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.0901 - mse: 0.0359 - val_loss: 0.1184 - val_mse: 0.0330
# Epoch 28/40
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.0884 - mse: 0.0381 - val_loss: 0.1049 - val_mse: 0.0293
# Epoch 29/40
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.0804 - mse: 0.0309 - val_loss: 0.1003 - val_mse: 0.0289
# Epoch 30/40
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0780 - mse: 0.0317 - val_loss: 0.1028 - val_mse: 0.0297
# Epoch 31/40
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0866 - mse: 0.0345 - val_loss: 0.1209 - val_mse: 0.0334
# Epoch 32/40
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0839 - mse: 0.0346 - val_loss: 0.0999 - val_mse: 0.0283
# Epoch 33/40
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0764 - mse: 0.0302 - val_loss: 0.1065 - val_mse: 0.0298
# Epoch 34/40
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0784 - mse: 0.0311 - val_loss: 0.1011 - val_mse: 0.0289
# Epoch 35/40
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0802 - mse: 0.0311 - val_loss: 0.1121 - val_mse: 0.0303
# Epoch 36/40
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0851 - mse: 0.0327 - val_loss: 0.1007 - val_mse: 0.0296
# Epoch 37/40
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0788 - mse: 0.0309 - val_loss: 0.1115 - val_mse: 0.0313
# Epoch 38/40
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0848 - mse: 0.0377 - val_loss: 0.1086 - val_mse: 0.0292
# Epoch 39/40
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0797 - mse: 0.0309 - val_loss: 0.1012 - val_mse: 0.0293
# Epoch 40/40
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0778 - mse: 0.0312 - val_loss: 0.0973 - val_mse: 0.0281

# %%
results=model.predict(x_val)
plt.scatter(range(len(y_val)),y_val,c='g')
plt.scatter(range(len(results)),results,c='r')
plt.title('validate')
plt.show()
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']

# Graficar la función de pérdida durante el entrenamiento
epochs = range(1, len(loss) + 1)

plt.plot(epochs, loss, 'bo', label='Pérdida de entrenamiento')
plt.plot(epochs, val_loss, 'b', label='Pérdida de validación')
plt.title('Función de pérdida durante el entrenamiento')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
resultados_viajes = scaler.inverse_transform(results)
resultados_viajes
# Out:
# array([[ 9.226656 ],
#        [ 7.5501122],
#        [ 7.29315  ],
#        [ 7.3654613],
#        [ 7.2526975],
#        [ 7.08329  ],
#        [ 7.363209 ],
#        [ 7.4425063],
#        [ 6.228556 ],
#        [ 6.3773794],
#        [ 6.0290403],
#        [ 6.510743 ],
#        [ 5.782621 ],
#        [ 4.715789 ],
#        [ 5.067877 ],
#        [ 4.8825283],
#        [ 5.1273394],
#        [ 3.6724463],
#        [ 3.4927437],
#        [ 2.6543443],
#        [ 2.8725197],
#        [ 2.2265832],
#        [ 5.446425 ],
#        [ 5.429503 ],
#        [ 5.517166 ],
#        [ 6.369508 ],
#        [ 6.522326 ],
#        [ 6.646627 ],
#        [ 6.387611 ],
#        [ 6.308552 ],
#        [ 5.705989 ],
#        [ 5.3537464],
#        [ 5.9096837],
#        [ 5.8970304],
#        [ 5.0178065],
#        [ 5.487246 ],
#        [ 5.4747696],
#        [ 5.321502 ],
#        [ 5.357761 ],
#        [ 5.2036943],
#        [ 3.2734084],
#        [ 2.9827142],
#        [ 3.112972 ],
#        [ 2.5331695],
#        [ 2.493071 ],
#        [ 6.7721887],
#        [ 6.966716 ],
#        [ 7.084762 ],
#        [ 7.360415 ],
#        [ 7.9525647],
#        [ 6.494819 ],
#        [ 6.1709175],
#        [ 5.92011  ],
#        [ 6.270142 ],
#        [ 6.419308 ],
#        [ 6.689895 ],
#        [ 6.912714 ],
#        [ 6.539706 ],
#        [ 6.733854 ],
#        [ 6.519301 ],
#        [ 6.8652864],
#        [ 6.891205 ],
#        [ 7.2785425],
#        [ 6.0568905],
#        [ 6.22964  ],
#        [ 6.5168495],
#        [ 5.7606106],
#        [ 6.3136344],
#        [ 6.388096 ],
#        [ 6.072658 ],
#        [ 6.0973454],
#        [ 6.230174 ],
#        [ 5.597008 ],
#        [ 5.850227 ],
#        [ 5.5010977],
#        [ 5.9688115],
#        [ 5.32174  ],
#        [ 4.3853555],
#        [ 4.4742627],
#        [ 3.889506 ],
#        [ 4.194778 ],
#        [ 6.016218 ],
#        [ 6.264757 ],
#        [ 7.156785 ],
#        [ 6.9051967],
#        [ 6.881499 ],
#        [ 6.710824 ],
#        [ 6.766687 ],
#        [ 6.374601 ],
#        [ 6.787624 ],
#        [ 6.466619 ],
#        [ 7.070532 ],
#        [ 6.920653 ],
#        [ 6.3816013],
#        [ 6.914729 ],
#        [ 6.686112 ],
#        [ 6.847771 ],
#        [ 6.719315 ],
#        [ 7.1155324],
#        [ 6.5335445],
#        [ 5.9237494],
#        [ 5.9738436],
#        [ 6.2278953],
#        [ 5.7363844],
#        [ 4.917489 ],
#        [ 4.8612394],
#        [ 4.7939715],
#        [ 4.665044 ],
#        [ 4.783288 ],
#        [ 3.7491326],
#        [ 3.6870015],
#        [ 3.8965702],
#        [ 3.3387704],
#        [ 3.5752332],
#        [ 3.523594 ],
#        [ 7.4021835],
#        [ 7.349508 ],
#        [ 7.354967 ],
#        [ 7.4729137],
#        [ 7.606147 ],
#        [ 7.4237537],
#        [ 7.2320685],
#        [ 7.887031 ],
#        [ 7.9568825],
#        [ 8.098028 ],
#        [ 7.7785316],
#        [ 7.5195994],
#        [ 5.994371 ],
#        [ 6.221303 ],
#        [ 6.4580574],
#        [ 6.9006944],
#        [ 6.949975 ],
#        [ 7.228476 ],
#        [ 4.9303164],
#        [ 5.1052766],
#        [ 5.2222824],
#        [ 5.234135 ],
#        [ 5.3961086],
#        [ 4.3432994],
#        [ 4.299433 ],
#        [ 4.454965 ],
#        [ 3.1060498],
#        [ 2.847104 ],
#        [ 3.0113418],
#        [ 3.330765 ],
#        [ 8.305479 ],
#        [ 8.586959 ],
#        [ 8.605462 ],
#        [ 9.231127 ],
#        [ 8.53422  ],
#        [ 8.055335 ],
#        [ 8.135147 ],
#        [ 7.062198 ],
#        [ 7.2199664],
#        [ 7.2644334],
#        [ 7.205971 ],
#        [ 7.327005 ],
#        [ 3.983106 ],
#        [ 3.9854686],
#        [ 4.0115905],
#        [ 4.2893972],
#        [ 3.4598236],
#        [ 3.4148126],
#        [ 3.4449427],
#        [ 3.3534186],
#        [ 3.155428 ],
#        [ 3.0487382],
#        [ 2.7624187],
#        [ 2.3342023],
#        [ 8.955492 ],
#        [ 9.671656 ],
#        [ 9.4435215],
#        [ 9.640426 ],
#        [ 9.718438 ],
#        [ 9.453365 ],
#        [10.039422 ],
#        [ 7.0254803],
#        [ 7.1317945],
#        [ 7.259102 ],
#        [ 6.730545 ],
#        [ 6.8103576],
#        [ 7.024205 ],
#        [ 4.814798 ],
#        [ 4.886218 ],
#        [ 5.168066 ],
#        [ 5.099323 ],
#        [ 5.2966633],
#        [ 5.4220114],
#        [ 5.520424 ],
#        [ 4.9794383],
#        [ 4.3318515],
#        [ 4.397741 ],
#        [ 4.527964 ],
#        [ 3.8241649],
#        [ 2.9398417]], dtype=float32)
