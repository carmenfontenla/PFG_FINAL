# %%
import pandas as pd
import numpy as np
import matplotlib.patches as mpatches
import matplotlib.pyplot as plt
import seaborn as sns
from prophet import Prophet
from sklearn.preprocessing import LabelEncoder
from datetime import datetime, timedelta
import statsmodels.api as sm
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import PowerTransformer
from scipy.stats import poisson
import datetime as dt
import matplotlib.pyplot as plt
import statsmodels as st
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.api import ExponentialSmoothing, SimpleExpSmoothing, Holt
import statsmodels.api as sm
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
import seaborn as sns
from tabulate import tabulate
import pmdarima as pm
from dateutil.relativedelta import relativedelta
from keras.models import Sequential
from keras.layers import Dense,Activation,Flatten
from sklearn.preprocessing import MinMaxScaler

# %%
df = pd.read_csv('Datos_preprocesados_accidentes_y_victimas_accidentes.csv')

# %%
db_provincia44 = df[df['COD_PROVINCIA'] == 44]

# %%
num_victimas_dia_semana44 = db_provincia44.groupby(['ANYO', 'MES', 'DIA_SEMANA', 'HORA'])['TOTAL_VICTIMAS_24H'].sum()

# %%
num_victimas_dia_semana44
# Out:
# ANYO  MES  DIA_SEMANA  HORA
# 2016  1    1           9       1
#                        15      1
#            2           19      2
#            4           14      3
#                        21      1
#                               ..
# 2020  12   4           14      1
#                        17      3
#            5           17      1
#            7           8       1
#                        9       1
# Name: TOTAL_VICTIMAS_24H, Length: 867, dtype: int64

# %%
num_accidentes_por_dia_semana44 = db_provincia44.groupby(['ANYO', 'MES'])['DIA_SEMANA'].value_counts()

# %%
num_accidentes_por_dia_semana44
# Out:
# ANYO  MES  DIA_SEMANA
# 2016  1    7             3
#            1             2
#            4             2
#            5             2
#            6             2
#                         ..
# 2020  12   3             4
#            2             2
#            4             2
#            7             2
#            5             1
# Name: count, Length: 359, dtype: int64

# %%
plt.plot(num_accidentes_por_dia_semana44.values)

# %%
plt.plot(num_victimas_dia_semana44.values)

# %%
num_accidentes_por_dia_semana44 = num_accidentes_por_dia_semana44.reset_index()

# %%
num_accidentes_por_dia_semana44['FECHA'] = num_accidentes_por_dia_semana44.apply(lambda row: str(row['ANYO']) + '/' + str(row['MES']) + '/' + str(row['DIA_SEMANA']), axis = 1)

# %%
num_accidentes_por_dia_semana44
# Out:
#      ANYO  MES  DIA_SEMANA  count      FECHA
# 0    2016    1           7      3   2016/1/7
# 1    2016    1           1      2   2016/1/1
# 2    2016    1           4      2   2016/1/4
# 3    2016    1           5      2   2016/1/5
# 4    2016    1           6      2   2016/1/6
# ..    ...  ...         ...    ...        ...
# 354  2020   12           3      4  2020/12/3
# 355  2020   12           2      2  2020/12/2
# 356  2020   12           4      2  2020/12/4
# 357  2020   12           7      2  2020/12/7
# 358  2020   12           5      1  2020/12/5
#
# [359 rows x 5 columns]

# %%
num_victimas_dia_semana44 = num_victimas_dia_semana44.reset_index()

# %%
num_victimas_dia_semana44
# Out:
#      ANYO  MES  DIA_SEMANA  HORA  TOTAL_VICTIMAS_24H
# 0    2016    1           1     9                   1
# 1    2016    1           1    15                   1
# 2    2016    1           2    19                   2
# 3    2016    1           4    14                   3
# 4    2016    1           4    21                   1
# ..    ...  ...         ...   ...                 ...
# 862  2020   12           4    14                   1
# 863  2020   12           4    17                   3
# 864  2020   12           5    17                   1
# 865  2020   12           7     8                   1
# 866  2020   12           7     9                   1
#
# [867 rows x 5 columns]

# %%
num_victimas_dia_semana44['FECHA'] = num_victimas_dia_semana44.apply(lambda row: str(row['ANYO']) + '/' + str(row['MES']) + '/' + str(row['DIA_SEMANA']), axis = 1)

# %%
num_victimas_dia_semana44
# Out:
#      ANYO  MES  DIA_SEMANA  HORA  TOTAL_VICTIMAS_24H      FECHA
# 0    2016    1           1     9                   1   2016/1/1
# 1    2016    1           1    15                   1   2016/1/1
# 2    2016    1           2    19                   2   2016/1/2
# 3    2016    1           4    14                   3   2016/1/4
# 4    2016    1           4    21                   1   2016/1/4
# ..    ...  ...         ...   ...                 ...        ...
# 862  2020   12           4    14                   1  2020/12/4
# 863  2020   12           4    17                   3  2020/12/4
# 864  2020   12           5    17                   1  2020/12/5
# 865  2020   12           7     8                   1  2020/12/7
# 866  2020   12           7     9                   1  2020/12/7
#
# [867 rows x 6 columns]

# %%
num_accidentes_por_dia_semana44
# Out:
#      ANYO  MES  DIA_SEMANA  count      FECHA
# 0    2016    1           7      3   2016/1/7
# 1    2016    1           1      2   2016/1/1
# 2    2016    1           4      2   2016/1/4
# 3    2016    1           5      2   2016/1/5
# 4    2016    1           6      2   2016/1/6
# ..    ...  ...         ...    ...        ...
# 354  2020   12           3      4  2020/12/3
# 355  2020   12           2      2  2020/12/2
# 356  2020   12           4      2  2020/12/4
# 357  2020   12           7      2  2020/12/7
# 358  2020   12           5      1  2020/12/5
#
# [359 rows x 5 columns]

# %%
num_victimas_dia_semana44
# Out:
#      ANYO  MES  DIA_SEMANA  HORA  TOTAL_VICTIMAS_24H      FECHA
# 0    2016    1           1     9                   1   2016/1/1
# 1    2016    1           1    15                   1   2016/1/1
# 2    2016    1           2    19                   2   2016/1/2
# 3    2016    1           4    14                   3   2016/1/4
# 4    2016    1           4    21                   1   2016/1/4
# ..    ...  ...         ...   ...                 ...        ...
# 862  2020   12           4    14                   1  2020/12/4
# 863  2020   12           4    17                   3  2020/12/4
# 864  2020   12           5    17                   1  2020/12/5
# 865  2020   12           7     8                   1  2020/12/7
# 866  2020   12           7     9                   1  2020/12/7
#
# [867 rows x 6 columns]

# %%
df_provincia44 = num_accidentes_por_dia_semana44.merge(num_victimas_dia_semana44, on = 'FECHA')

# %%
df_provincia44 = df_provincia44[['ANYO_x', 'FECHA', 'count', 'TOTAL_VICTIMAS_24H']]

# %%
df_provincia44.describe()
# Out:
#             ANYO_x       count  TOTAL_VICTIMAS_24H
# count   867.000000  867.000000           867.00000
# mean   2017.938870    3.494810             1.55248
# std       1.395208    1.867037             1.03538
# min    2016.000000    1.000000             1.00000
# 25%    2017.000000    2.000000             1.00000
# 50%    2018.000000    3.000000             1.00000
# 75%    2019.000000    5.000000             2.00000
# max    2020.000000   10.000000             8.00000

# %% [markdown]
# ### MODELO PROPHET

# %%
df_provincia44['y'] = df_provincia44['count']
df_provincia44['ds'] = pd.to_datetime(pd.to_datetime(df_provincia44['FECHA']).dt.date)

# %%
ts = df_provincia44[['ds', 'y']]
model = Prophet(
   yearly_seasonality=True,
   seasonality_mode=['additive','multiplicative'][0]
   ).add_country_holidays(country_name='ESP'
   ).fit(ts)

future = model.make_future_dataframe(periods=10)
forecast = model.predict(future)
fig1 = model.plot(forecast)
# Out:
# 18:41:31 - cmdstanpy - INFO - Chain [1] start processing
# 18:41:31 - cmdstanpy - INFO - Chain [1] done processing
# c:\Users\---\AppData\Local\Programs\Python\Python312\Lib\site-packages\prophet\plot.py:72: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   fcst_t = fcst['ds'].dt.to_pydatetime()
# c:\Users\---\AppData\Local\Programs\Python\Python312\Lib\site-packages\prophet\plot.py:73: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   ax.plot(m.history['ds'].dt.to_pydatetime(), m.history['y'], 'k.',

# %%
fig2 = model.plot_components(forecast)
# Out:
# c:\Users\---\AppData\Local\Programs\Python\Python312\Lib\site-packages\prophet\plot.py:228: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   fcst_t = fcst['ds'].dt.to_pydatetime()
# c:\Users\---\AppData\Local\Programs\Python\Python312\Lib\site-packages\prophet\plot.py:351: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   df_y['ds'].dt.to_pydatetime(), seas[name], ls='-', c='#0072B2')
# c:\Users\---\AppData\Local\Programs\Python\Python312\Lib\site-packages\prophet\plot.py:354: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   df_y['ds'].dt.to_pydatetime(), seas[name + '_lower'],

# %% [markdown]
# ### MODELO REDES NEURONALES

# %%
PASOS=336
 
# convert series to supervised learning
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
    n_vars = 1 if type(data) is list else data.shape[1]
    df = pd.DataFrame(data)
    cols, names = list(), list()
    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
        else:
            names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
    # put it all together
    agg = pd.concat(cols, axis=1)
    agg.columns = names
    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    return agg
 
# load dataset
values = df_provincia44['count'].values
# ensure all data is float
values = values.astype('float32')
# normalize features
scaler = MinMaxScaler(feature_range=(-1, 1))
values=values.reshape(-1, 1) # esto lo hacemos porque tenemos 1 sola dimension
scaled = scaler.fit_transform(values)
# frame as supervised learning
reframed = series_to_supervised(scaled, PASOS, 1)
reframed.head()
# Out:
#      var1(t-336)  var1(t-335)  var1(t-334)  var1(t-333)  var1(t-332)  \
# 336    -0.555556    -0.555556    -0.555556    -0.777778    -0.777778
# 337    -0.555556    -0.555556    -0.777778    -0.777778    -0.777778
# 338    -0.555556    -0.777778    -0.777778    -0.777778    -0.777778
# 339    -0.777778    -0.777778    -0.777778    -0.777778    -0.777778
# 340    -0.777778    -0.777778    -0.777778    -0.777778    -0.777778
#
#      var1(t-331)  var1(t-330)  var1(t-329)  var1(t-328)  var1(t-327)  ...  \
# 336    -0.777778    -0.777778    -0.777778    -0.777778    -0.777778  ...
# 337    -0.777778    -0.777778    -0.777778    -0.777778    -0.777778  ...
# 338    -0.777778    -0.777778    -0.777778    -0.777778    -1.000000  ...
# 339    -0.777778    -0.777778    -0.777778    -1.000000    -0.777778  ...
# 340    -0.777778    -0.777778    -1.000000    -0.777778    -0.777778  ...
#
#      var1(t-9)  var1(t-8)  var1(t-7)  var1(t-6)  var1(t-5)  var1(t-4)  \
# 336  -0.555556  -0.555556  -0.555556  -1.000000  -0.111111  -0.111111
# 337  -0.555556  -0.555556  -1.000000  -0.111111  -0.111111  -0.111111
# 338  -0.555556  -1.000000  -0.111111  -0.111111  -0.111111  -0.111111
# 339  -1.000000  -0.111111  -0.111111  -0.111111  -0.111111  -0.111111
# 340  -0.111111  -0.111111  -0.111111  -0.111111  -0.111111  -0.333333
#
#      var1(t-3)  var1(t-2)  var1(t-1)   var1(t)
# 336  -0.111111  -0.111111  -0.111111 -0.333333
# 337  -0.111111  -0.111111  -0.333333 -0.333333
# 338  -0.111111  -0.333333  -0.333333 -0.333333
# 339  -0.333333  -0.333333  -0.333333 -0.333333
# 340  -0.333333  -0.333333  -0.333333 -0.555556
#
# [5 rows x 337 columns]

# %%
values = reframed.values
n_train_days = 367
train = values[:n_train_days, :]
test = values[n_train_days:, :]
# split isnto input and outputs
x_train, y_train = train[:, :-1], train[:, -1]
x_val, y_val = test[:, :-1], test[:, -1]
# reshape input to be 3D [samples, timesteps, features]
x_train = x_train.reshape((x_train.shape[0], 1, x_train.shape[1]))
x_val = x_val.reshape((x_val.shape[0], 1, x_val.shape[1]))
print(x_train.shape, y_train.shape, x_val.shape, y_val.shape)
# Out:
# (367, 1, 336) (367,) (164, 1, 336) (164,)

# %%
len(values)
# Out:
# 531

# %%
def crear_modeloFF():
    model = Sequential()
    model.add(Dense(PASOS, input_shape=(1,PASOS),activation='tanh'))
    model.add(Flatten())
    model.add(Dense(1, activation='tanh'))
    model.compile(loss='mean_absolute_error',optimizer='Adam',metrics=["mse"])
    model.summary()
    return model

# %%
EPOCHS=40

model = crear_modeloFF()
 
history=model.fit(x_train,y_train,epochs=EPOCHS,validation_data=(x_val,y_val),batch_size=PASOS)
# Out:
# c:\Users\---\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 1, 336)         │       113,232 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 336)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │           337 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 113,569 (443.63 KB)
#  Trainable params: 113,569 (443.63 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/40
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 116ms/step - loss: 0.7475 - mse: 0.7627 - val_loss: 0.5776 - val_mse: 0.5096
# Epoch 2/40
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.5354 - mse: 0.4530 - val_loss: 0.5786 - val_mse: 0.5110
# Epoch 3/40
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.5365 - mse: 0.4542 - val_loss: 0.5786 - val_mse: 0.5110
# Epoch 4/40
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.5352 - mse: 0.4500 - val_loss: 0.5786 - val_mse: 0.5110
# Epoch 5/40
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.5334 - mse: 0.4493 - val_loss: 0.5786 - val_mse: 0.5110
# Epoch 6/40
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.5371 - mse: 0.4555 - val_loss: 0.5786 - val_mse: 0.5110
# Epoch 7/40
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.5374 - mse: 0.4551 - val_loss: 0.5786 - val_mse: 0.5110
# Epoch 8/40
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.5400 - mse: 0.4583 - val_loss: 0.5786 - val_mse: 0.5110
# Epoch 9/40
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.5356 - mse: 0.4504 - val_loss: 0.5786 - val_mse: 0.5110
# Epoch 10/40
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.5360 - mse: 0.4518 - val_loss: 0.5786 - val_mse: 0.5110
# Epoch 11/40
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.5354 - mse: 0.4515 - val_loss: 0.5786 - val_mse: 0.5110
# Epoch 12/40
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.5393 - mse: 0.4568 - val_loss: 0.5786 - val_mse: 0.5110
# Epoch 13/40
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.5358 - mse: 0.4498 - val_loss: 0.5786 - val_mse: 0.5110
# Epoch 14/40
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.5376 - mse: 0.4530 - val_loss: 0.5786 - val_mse: 0.5110
# Epoch 15/40
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.5358 - mse: 0.4508 - val_loss: 0.5786 - val_mse: 0.5110
# Epoch 16/40
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.5345 - mse: 0.4457 - val_loss: 0.5786 - val_mse: 0.5110
# Epoch 17/40
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.5338 - mse: 0.4494 - val_loss: 0.5786 - val_mse: 0.5110
# Epoch 18/40
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.5347 - mse: 0.4528 - val_loss: 0.5786 - val_mse: 0.5110
# Epoch 19/40
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.5345 - mse: 0.4511 - val_loss: 0.5786 - val_mse: 0.5110
# Epoch 20/40
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.5385 - mse: 0.4564 - val_loss: 0.5786 - val_mse: 0.5110
# Epoch 21/40
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.5363 - mse: 0.4550 - val_loss: 0.5786 - val_mse: 0.5110
# Epoch 22/40
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.5354 - mse: 0.4507 - val_loss: 0.5786 - val_mse: 0.5110
# Epoch 23/40
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.5321 - mse: 0.4419 - val_loss: 0.5786 - val_mse: 0.5110
# Epoch 24/40
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.5358 - mse: 0.4520 - val_loss: 0.5786 - val_mse: 0.5110
# Epoch 25/40
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.5345 - mse: 0.4501 - val_loss: 0.5786 - val_mse: 0.5110
# Epoch 26/40
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.5354 - mse: 0.4474 - val_loss: 0.5786 - val_mse: 0.5110
# Epoch 27/40
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.5407 - mse: 0.4585 - val_loss: 0.5786 - val_mse: 0.5110
# Epoch 28/40
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.5371 - mse: 0.4560 - val_loss: 0.5786 - val_mse: 0.5110
# Epoch 29/40
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.5352 - mse: 0.4527 - val_loss: 0.5786 - val_mse: 0.5110
# Epoch 30/40
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.5358 - mse: 0.4517 - val_loss: 0.5786 - val_mse: 0.5110
# Epoch 31/40
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.5374 - mse: 0.4553 - val_loss: 0.5786 - val_mse: 0.5110
# Epoch 32/40
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.5371 - mse: 0.4556 - val_loss: 0.5786 - val_mse: 0.5110
# Epoch 33/40
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.5334 - mse: 0.4517 - val_loss: 0.5786 - val_mse: 0.5110
# Epoch 34/40
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.5336 - mse: 0.4493 - val_loss: 0.5786 - val_mse: 0.5110
# Epoch 35/40
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.5356 - mse: 0.4502 - val_loss: 0.5786 - val_mse: 0.5110
# Epoch 36/40
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.5314 - mse: 0.4430 - val_loss: 0.5786 - val_mse: 0.5110
# Epoch 37/40
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.5393 - mse: 0.4581 - val_loss: 0.5786 - val_mse: 0.5110
# Epoch 38/40
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.5325 - mse: 0.4465 - val_loss: 0.5786 - val_mse: 0.5110
# Epoch 39/40
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.5349 - mse: 0.4523 - val_loss: 0.5786 - val_mse: 0.5110
# Epoch 40/40
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.5374 - mse: 0.4545 - val_loss: 0.5786 - val_mse: 0.5110

# %%
results=model.predict(x_val)
plt.scatter(range(len(y_val)),y_val,c='g')
plt.scatter(range(len(results)),results,c='r')
plt.title('validate')
plt.show()
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']

# Graficar la función de pérdida durante el entrenamiento
epochs = range(1, len(loss) + 1)

plt.plot(epochs, loss, 'bo', label='Pérdida de entrenamiento')
plt.plot(epochs, val_loss, 'b', label='Pérdida de validación')
plt.title('Función de pérdida durante el entrenamiento')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
resultados_viajes = scaler.inverse_transform(results)
resultados_viajes
# Out:
# array([[0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994],
#        [0.99999994]], dtype=float32)
