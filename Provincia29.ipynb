# %%
import pandas as pd
import numpy as np
import matplotlib.patches as mpatches
import matplotlib.pyplot as plt
import seaborn as sns
from prophet import Prophet
from sklearn.preprocessing import LabelEncoder
from datetime import datetime, timedelta
import statsmodels.api as sm
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import PowerTransformer
from scipy.stats import poisson
import datetime as dt
import matplotlib.pyplot as plt
import statsmodels as st
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.api import ExponentialSmoothing, SimpleExpSmoothing, Holt
import statsmodels.api as sm
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
import seaborn as sns
from tabulate import tabulate
import pmdarima as pm
from dateutil.relativedelta import relativedelta
from keras.models import Sequential
from keras.layers import Dense,Activation,Flatten
from sklearn.preprocessing import MinMaxScaler

# %%
df = pd.read_csv('Datos_preprocesados_accidentes_y_victimas_accidentes.csv')

# %%
db_provincia29 = df[df['COD_PROVINCIA'] == 29]

# %%
num_victimas_dia_semana29 = db_provincia29.groupby(['ANYO', 'MES', 'DIA_SEMANA', 'HORA'])['TOTAL_VICTIMAS_24H'].sum()

# %%
num_victimas_dia_semana29
# Out:
# ANYO  MES  DIA_SEMANA  HORA
# 2016  1    1           7       1
#                        8       6
#                        9       1
#                        11      3
#                        12      1
#                               ..
# 2020  12   7           19      8
#                        20      4
#                        21      6
#                        22      5
#                        23      1
# Name: TOTAL_VICTIMAS_24H, Length: 6662, dtype: int64

# %%
num_accidentes_por_dia_semana29 = db_provincia29.groupby(['ANYO', 'MES'])['DIA_SEMANA'].value_counts()

# %%
num_accidentes_por_dia_semana29
# Out:
# ANYO  MES  DIA_SEMANA
# 2016  1    6             34
#            1             33
#            4             32
#            7             29
#            5             27
#                          ..
# 2020  12   4             60
#            5             54
#            6             50
#            1             42
#            7             35
# Name: count, Length: 420, dtype: int64

# %%
plt.plot(num_accidentes_por_dia_semana29.values)

# %%
plt.plot(num_victimas_dia_semana29.values)

# %%
num_accidentes_por_dia_semana29 = num_accidentes_por_dia_semana29.reset_index()

# %%
num_accidentes_por_dia_semana29['FECHA'] = num_accidentes_por_dia_semana29.apply(lambda row: str(row['ANYO']) + '/' + str(row['MES']) + '/' + str(row['DIA_SEMANA']), axis = 1)

# %%
num_accidentes_por_dia_semana29
# Out:
#      ANYO  MES  DIA_SEMANA  count      FECHA
# 0    2016    1           6     34   2016/1/6
# 1    2016    1           1     33   2016/1/1
# 2    2016    1           4     32   2016/1/4
# 3    2016    1           7     29   2016/1/7
# 4    2016    1           5     27   2016/1/5
# ..    ...  ...         ...    ...        ...
# 415  2020   12           4     60  2020/12/4
# 416  2020   12           5     54  2020/12/5
# 417  2020   12           6     50  2020/12/6
# 418  2020   12           1     42  2020/12/1
# 419  2020   12           7     35  2020/12/7
#
# [420 rows x 5 columns]

# %%
num_victimas_dia_semana29 = num_victimas_dia_semana29.reset_index()

# %%
num_victimas_dia_semana29
# Out:
#       ANYO  MES  DIA_SEMANA  HORA  TOTAL_VICTIMAS_24H
# 0     2016    1           1     7                   1
# 1     2016    1           1     8                   6
# 2     2016    1           1     9                   1
# 3     2016    1           1    11                   3
# 4     2016    1           1    12                   1
# ...    ...  ...         ...   ...                 ...
# 6657  2020   12           7    19                   8
# 6658  2020   12           7    20                   4
# 6659  2020   12           7    21                   6
# 6660  2020   12           7    22                   5
# 6661  2020   12           7    23                   1
#
# [6662 rows x 5 columns]

# %%
num_victimas_dia_semana29['FECHA'] = num_victimas_dia_semana29.apply(lambda row: str(row['ANYO']) + '/' + str(row['MES']) + '/' + str(row['DIA_SEMANA']), axis = 1)

# %%
num_victimas_dia_semana29
# Out:
#       ANYO  MES  DIA_SEMANA  HORA  TOTAL_VICTIMAS_24H      FECHA
# 0     2016    1           1     7                   1   2016/1/1
# 1     2016    1           1     8                   6   2016/1/1
# 2     2016    1           1     9                   1   2016/1/1
# 3     2016    1           1    11                   3   2016/1/1
# 4     2016    1           1    12                   1   2016/1/1
# ...    ...  ...         ...   ...                 ...        ...
# 6657  2020   12           7    19                   8  2020/12/7
# 6658  2020   12           7    20                   4  2020/12/7
# 6659  2020   12           7    21                   6  2020/12/7
# 6660  2020   12           7    22                   5  2020/12/7
# 6661  2020   12           7    23                   1  2020/12/7
#
# [6662 rows x 6 columns]

# %%
num_accidentes_por_dia_semana29
# Out:
#      ANYO  MES  DIA_SEMANA  count      FECHA
# 0    2016    1           6     34   2016/1/6
# 1    2016    1           1     33   2016/1/1
# 2    2016    1           4     32   2016/1/4
# 3    2016    1           7     29   2016/1/7
# 4    2016    1           5     27   2016/1/5
# ..    ...  ...         ...    ...        ...
# 415  2020   12           4     60  2020/12/4
# 416  2020   12           5     54  2020/12/5
# 417  2020   12           6     50  2020/12/6
# 418  2020   12           1     42  2020/12/1
# 419  2020   12           7     35  2020/12/7
#
# [420 rows x 5 columns]

# %%
num_victimas_dia_semana29
# Out:
#       ANYO  MES  DIA_SEMANA  HORA  TOTAL_VICTIMAS_24H      FECHA
# 0     2016    1           1     7                   1   2016/1/1
# 1     2016    1           1     8                   6   2016/1/1
# 2     2016    1           1     9                   1   2016/1/1
# 3     2016    1           1    11                   3   2016/1/1
# 4     2016    1           1    12                   1   2016/1/1
# ...    ...  ...         ...   ...                 ...        ...
# 6657  2020   12           7    19                   8  2020/12/7
# 6658  2020   12           7    20                   4  2020/12/7
# 6659  2020   12           7    21                   6  2020/12/7
# 6660  2020   12           7    22                   5  2020/12/7
# 6661  2020   12           7    23                   1  2020/12/7
#
# [6662 rows x 6 columns]

# %%
df_provincia29 = num_accidentes_por_dia_semana29.merge(num_victimas_dia_semana29, on = 'FECHA')

# %%
df_provincia29 = df_provincia29[['ANYO_x', 'FECHA', 'count', 'TOTAL_VICTIMAS_24H']]

# %%
df_provincia29.describe()
# Out:
#             ANYO_x        count  TOTAL_VICTIMAS_24H
# count  6662.000000  6662.000000         6662.000000
# mean   2018.100420    43.790153            3.533173
# std       1.378836    18.815233            2.722081
# min    2016.000000     1.000000            1.000000
# 25%    2017.000
40
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0472 - mse: 0.0068 - val_loss: 0.0417 - val_mse: 0.0088
# Epoch 18/40
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0444 - mse: 0.0069 - val_loss: 0.0437 - val_mse: 0.0084
# Epoch 19/40
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0524 - mse: 0.0085 - val_loss: 0.0407 - val_mse: 0.0087
# Epoch 20/40
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0564 - mse: 0.0081 - val_loss: 0.0407 - val_mse: 0.0080
# Epoch 21/40
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0455 - mse: 0.0065 - val_loss: 0.0388 - val_mse: 0.0084
# Epoch 22/40
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - loss: 0.0434 - mse: 0.0070 - val_loss: 0.0387 - val_mse: 0.0078
# Epoch 23/40
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0540 - mse: 0.0092 - val_loss: 0.0508 - val_mse: 0.0093
# Epoch 24/40
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.1003 - mse: 0.0194 - val_loss: 0.0422 - val_mse: 0.0088
# Epoch 25/40
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0599 - mse: 0.0089 - val_loss: 0.0459 - val_mse: 0.0091
# Epoch 26/40
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0541 - mse: 0.0083 - val_loss: 0.0427 - val_mse: 0.0084
# Epoch 27/40
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0550 - mse: 0.0079 - val_loss: 0.0467 - val_mse: 0.0085
# Epoch 28/40
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.0657 - mse: 0.0098 - val_loss: 0.0457 - val_mse: 0.0095
# Epoch 29/40
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0560 - mse: 0.0088 - val_loss: 0.0340 - val_mse: 0.0078
# Epoch 30/40
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0394 - mse: 0.0060 - val_loss: 0.0347 - val_mse: 0.0077
# Epoch 31/40
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.0514 - mse: 0.0076 - val_loss: 0.0356 - val_mse: 0.0077
# Epoch 32/40
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.0642 - mse: 0.0096 - val_loss: 0.0397 - val_mse: 0.0080
# Epoch 33/40
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.0516 - mse: 0.0082 - val_loss: 0.0357 - val_mse: 0.0079
# Epoch 34/40
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.0448 - mse: 0.0064 - val_loss: 0.0378 - val_mse: 0.0077
# Epoch 35/40
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 0.0362 - mse: 0.0061 - val_loss: 0.0323 - val_mse: 0.0075
# Epoch 36/40
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0503 - mse: 0.0091 - val_loss: 0.0368 - val_mse: 0.0077
# Epoch 37/40
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0348 - mse: 0.0049 - val_loss: 0.0370 - val_mse: 0.0079
# Epoch 38/40
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.0322 - mse: 0.0056 - val_loss: 0.0365 - val_mse: 0.0074
# Epoch 39/40
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0385 - mse: 0.0059 - val_loss: 0.0289 - val_mse: 0.0073
# Epoch 40/40
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0345 - mse: 0.0051 - val_loss: 0.0358 - val_mse: 0.0076

# %%
results=model.predict(x_val)
plt.scatter(range(len(y_val)),y_val,c='g')
plt.scatter(range(len(results)),results,c='r')
plt.title('validate')
plt.show()
# Out:
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']

# Graficar la función de pérdida durante el entrenamiento
epochs = range(1, len(loss) + 1)

plt.plot(epochs, loss, 'bo', label='Pérdida de entrenamiento')
plt.plot(epochs, val_loss, 'b', label='Pérdida de validación')
plt.title('Función de pérdida durante el entrenamiento')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
resultados_viajes = scaler.inverse_transform(results)
resultados_viajes
# Out:
# array([[28.786966],
#        [29.46515 ],
#        [29.394484],
#        [29.492735],
#        [29.770615],
#        [29.417053],
#        [29.875452],
#        [29.379864],
#        [29.187927],
#        [28.964947],
#        [28.68153 ],
#        [29.105963],
#        [28.065466],
#        [28.908125],
#        [28.267723],
#        [61.970406],
#        [66.6595  ],
#        [65.26841 ],
#        [63.51028 ],
#        [62.079346],
#        [62.74521 ],
#        [62.079773],
#        [61.863285],
#        [61.803787],
#        [61.08846 ],
#        [61.303616],
#        [62.864716],
#        [61.116314],
#        [61.40057 ],
#        [62.006725],
#        [41.943195],
#        [40.52093 ],
#        [40.91021 ],
#        [42.12397 ],
#        [41.476658],
#        [41.74898 ],
#        [42.765472],
#        [41.84665 ],
#        [41.444695],
#        [41.292316],
#        [40.779232],
#        [41.55388 ],
#        [41.356636],
#        [41.81095 ],
#        [41.300438],
#        [41.61897 ],
#        [40.187378],
#        [40.421913],
#        [40.55382 ],
#        [39.928497],
#        [41.271038],
#        [40.62928 ],
#        [42.497734],
#        [42.506386],
#        [42.126324],
#        [43.967335],
#        [42.09601 ],
#        [42.662014],
#        [42.450554],
#        [43.01113 ],
#        [42.409557],
#        [42.789406],
#        [42.659973],
#        [43.2911  ],
#        [42.767406],
#        [43.3183  ],
#        [41.882206],
#        [42.128242],
#        [41.913376],
#        [40.92986 ],
#        [42.074295],
#        [41.334026],
#        [41.15943 ],
#        [41.679672],
#        [42.14741 ],
#        [36.13815 ],
#        [36.069603],
#        [36.25069 ],
#        [36.958614],
#        [37.019844],
#        [36.813835],
#        [36.83744 ],
#        [36.73409 ],
#        [38.424725],
#        [38.87482 ],
#        [37.00279 ],
#        [36.94024 ],
#        [37.712765],
#        [36.38851 ],
#        [28.144876],
#        [27.41373 ],
#        [26.6574  ],
#        [26.802065],
#        [27.01311 ],
#        [26.836346],
#        [26.919994],
#        [27.093279],
#        [27.275845],
#        [27.021984],
#        [27.42455 ],
#        [27.2999  ],
#        [27.378248],
#        [25.343586],
#        [25.640814],
#        [26.412554],
#        [26.636425],
#        [25.864033],
#        [25.785992],
#        [25.930119],
#        [25.830437],
#        [26.29591 ],
#        [27.229649],
#        [26.788069],
#        [26.107206],
#        [26.539951],
#        [67.58101 ],
#        [74.02129 ],
#        [73.72067 ],
#        [73.00428 ],
#        [72.08854 ],
#        [71.40364 ],
#        [71.48914 ],
#        [70.92893 ],
#        [70.31582 ],
#        [70.965614],
#        [69.92088 ],
#        [71.96378 ],
#        [70.72431 ],
#        [71.30978 ],
#        [71.85528 ],
#        [70.81159 ],
#        [71.92735 ],
#        [66.16751 ],
#        [65.50035 ],
#        [65.36611 ],
#        [66.080315],
#        [67.19618 ],
#        [66.57771 ],
#        [65.282074],
#        [66.0446  ],
#        [65.048676],
#        [66.18925 ],
#        [64.32909 ],
#        [65.89528 ],
#        [65.254425],
#        [63.4825  ],
#        [64.50492 ],
#        [65.39905 ],
#        [64.72882 ],
#        [59.649418],
#        [58.4365  ],
#        [58.985744],
#        [61.58509 ],
#        [60.079712],
#        [60.338737],
#        [60.871887],
#        [61.35622 ],
#        [61.088135],
#        [61.738846],
#        [61.02926 ],
#        [60.261345],
#        [60.481136],
#        [59.89367 ],
#        [59.170536],
#        [59.556267],
#        [59.813583],
#        [53.333862],
#        [52.993374],
#        [53.643616],
#        [51.835735],
#        [54.115696],
#        [53.097763],
#        [55.854256],
#        [53.689716],
#        [53.09042 ],
#        [52.69708 ],
#        [54.12743 ],
#        [52.69844 ],
#        [54.413033],
#        [54.069973],
#        [54.247993],
#        [54.02692 ],
#        [49.673252],
#        [50.26521 ],
#        [49.228897],
#        [50.461334],
#        [52.312866],
#        [51.9315  ],
#        [50.04439 ],
#        [51.275517],
#        [50.663067],
#        [50.748558],
#        [50.918613],
#        [51.080463],
#        [50.61738 ],
#        [51.51945 ],
#        [51.771645],
#        [51.343437],
#        [51.099888],
#        [43.443275],
#        [42.505997],
#        [43.534985],
#        [42.032185],
#        [43.06002 ],
#        [43.319168],
#        [45.428577],
#        [44.52104 ],
#        [46.105328],
#        [45.111366],
#        [43.90575 ],
#        [44.56439 ],
#        [44.233006],
#        [44.686684],
#        [38.066162],
#        [37.793224],
#        [37.564816],
#        [36.574787],
#        [38.272778],
#        [36.841057],
#        [37.08255 ],
#        [36.00364 ],
#        [36.44078 ],
#        [35.86933 ],
#        [36.015182],
#        [37.290676],
#        [35.703003]], dtype=float32)
