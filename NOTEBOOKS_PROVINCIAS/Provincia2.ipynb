# %%
import pandas as pd
import numpy as np
import matplotlib.patches as mpatches
import matplotlib.pyplot as plt
import seaborn as sns
from prophet import Prophet
from sklearn.preprocessing import LabelEncoder
from datetime import datetime, timedelta
import statsmodels.api as sm
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import PowerTransformer
from scipy.stats import poisson
import datetime as dt
import matplotlib.pyplot as plt
import statsmodels as st
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.api import ExponentialSmoothing, SimpleExpSmoothing, Holt
import statsmodels.api as sm
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
import seaborn as sns
from tabulate import tabulate
import pmdarima as pm
from dateutil.relativedelta import relativedelta
from keras.models import Sequential
from keras.layers import Dense,Activation,Flatten
from sklearn.preprocessing import MinMaxScaler

# %%
df = pd.read_csv('../BBDD/Datos_preprocesados_accidentes_y_victimas_accidentes.csv')

# %%
db_provincia2 = df[df['COD_PROVINCIA'] == 2]

# %%
num_victimas_dia_semana2 = db_provincia2.groupby(['ANYO', 'MES', 'DIA_SEMANA'])['TOTAL_VICTIMAS_24H'].sum()

# %%
num_victimas_dia_semana2 = num_victimas_dia_semana2.reset_index()

# %%
num_victimas_dia_semana2['FECHA'] = num_victimas_dia_semana2.apply(lambda row: str(row['ANYO']) + '/' + str(row['MES']) + '/' + str(row['DIA_SEMANA']), axis = 1)

# %%
num_accidentes_por_dia_semana2 = db_provincia2.groupby(['ANYO', 'MES'])['DIA_SEMANA'].value_counts()

# %%
num_accidentes_por_dia_semana2
# Out:
# ANYO  MES  DIA_SEMANA
# 2016  1    4              8
#            5              8
#            7              8
#            1              7
#            3              7
#                          ..
# 2020  12   4             10
#            5              8
#            6              8
#            3              7
#            7              6
# Name: count, Length: 415, dtype: int64

# %%
plt.plot(num_accidentes_por_dia_semana2.values)

# %%
plt.plot(num_victimas_dia_semana2['TOTAL_VICTIMAS_24H'])

# %%
num_accidentes_por_dia_semana2 = num_accidentes_por_dia_semana2.reset_index()

# %%
num_accidentes_por_dia_semana2['FECHA'] = num_accidentes_por_dia_semana2.apply(lambda row: str(row['ANYO']) + '/' + str(row['MES']) + '/' + str(row['DIA_SEMANA']), axis = 1)

# %%
num_accidentes_por_dia_semana2.sort_values(by='FECHA')
# Out:
#      ANYO  MES  DIA_SEMANA  count     FECHA
# 3    2016    1           1      7  2016/1/1
# 5    2016    1           2      6  2016/1/2
# 4    2016    1           3      7  2016/1/3
# 0    2016    1           4      8  2016/1/4
# 1    2016    1           5      8  2016/1/5
# ..    ...  ...         ...    ...       ...
# 389  2020    9           3     11  2020/9/3
# 387  2020    9           4     12  2020/9/4
# 390  2020    9           5     10  2020/9/5
# 391  2020    9           6      7  2020/9/6
# 393  2020    9           7      2  2020/9/7
#
# [415 rows x 5 columns]

# %%
num_accidentes_por_dia_semana2
# Out:
#      ANYO  MES  DIA_SEMANA  count      FECHA
# 0    2016    1           4      8   2016/1/4
# 1    2016    1           5      8   2016/1/5
# 2    2016    1           7      8   2016/1/7
# 3    2016    1           1      7   2016/1/1
# 4    2016    1           3      7   2016/1/3
# ..    ...  ...         ...    ...        ...
# 410  2020   12           4     10  2020/12/4
# 411  2020   12           5      8  2020/12/5
# 412  2020   12           6      8  2020/12/6
# 413  2020   12           3      7  2020/12/3
# 414  2020   12           7      6  2020/12/7
#
# [415 rows x 5 columns]

# %%
num_victimas_dia_semana2 = num_victimas_dia_semana2.reset_index()

# %%
num_victimas_dia_semana2
# Out:
#      index  ANYO  MES  DIA_SEMANA  TOTAL_VICTIMAS_24H      FECHA
# 0        0  2016    1           1                  11   2016/1/1
# 1        1  2016    1           2                   8   2016/1/2
# 2        2  2016    1           3                  12   2016/1/3
# 3        3  2016    1           4                  15   2016/1/4
# 4        4  2016    1           5                  16   2016/1/5
# ..     ...   ...  ...         ...                 ...        ...
# 410    410  2020   12           3                  11  2020/12/3
# 411    411  2020   12           4                  16  2020/12/4
# 412    412  2020   12           5                  10  2020/12/5
# 413    413  2020   12           6                   9  2020/12/6
# 414    414  2020   12           7                  10  2020/12/7
#
# [415 rows x 6 columns]

# %%
num_victimas_dia_semana2['FECHA'] = num_victimas_dia_semana2.apply(lambda row: str(row['ANYO']) + '/' + str(row['MES']) + '/' + str(row['DIA_SEMANA']), axis = 1)

# %%
num_victimas_dia_semana2
# Out:
#      index  ANYO  MES  DIA_SEMANA  TOTAL_VICTIMAS_24H      FECHA
# 0        0  2016    1           1                  11   2016/1/1
# 1        1  2016    1           2                   8   2016/1/2
# 2        2  2016    1           3                  12   2016/1/3
# 3        3  2016    1           4                  15   2016/1/4
# 4        4  2016    1           5                  16   2016/1/5
# ..     ...   ...  ...         ...                 ...        ...
# 410    410  2020   12           3                  11  2020/12/3
# 411    411  2020   12           4                  16  2020/12/4
# 412    412  2020   12           5                  10  2020/12/5
# 413    413  2020   12           6                   9  2020/12/6
# 414    414  2020   12           7                  10  2020/12/7
#
# [415 rows x 6 columns]

# %%
num_accidentes_por_dia_semana2
# Out:
#      ANYO  MES  DIA_SEMANA  count      FECHA
# 0    2016    1           4      8   2016/1/4
# 1    2016    1           5      8   2016/1/5
# 2    2016    1           7      8   2016/1/7
# 3    2016    1           1      7   2016/1/1
# 4    2016    1           3      7   2016/1/3
# ..    ...  ...         ...    ...        ...
# 410  2020   12           4     10  2020/12/4
# 411  2020   12           5      8  2020/12/5
# 412  2020   12           6      8  2020/12/6
# 413  2020   12           3      7  2020/12/3
# 414  2020   12           7      6  2020/12/7
#
# [415 rows x 5 columns]

# %%
num_victimas_dia_semana2
# Out:
#      index  ANYO  MES  DIA_SEMANA  TOTAL_VICTIMAS_24H      FECHA
# 0        0  2016    1           1                  11   2016/1/1
# 1        1  2016    1           2                   8   2016/1/2
# 2        2  2016    1           3                  12   2016/1/3
# 3        3  2016    1           4                  15   2016/1/4
# 4        4  2016    1           5                  16   2016/1/5
# ..     ...   ...  ...         ...                 ...        ...
# 410    410  2020   12           3                  11  2020/12/3
# 411    411  2020   12           4                  16  2020/12/4
# 412    412  2020   12           5                  10  2020/12/5
# 413    413  2020   12           6                   9  2020/12/6
# 414    414  2020   12           7                  10  2020/12/7
#
# [415 rows x 6 columns]

# %%
df_provincia2 = num_accidentes_por_dia_semana2.merge(num_victimas_dia_semana2, on = 'FECHA')

# %%
df_provincia2 = df_provincia2[['ANYO_x', 'FECHA', 'count', 'TOTAL_VICTIMAS_24H']]

# %%
df_provincia2.describe()
# Out:
#             ANYO_x       count  TOTAL_VICTIMAS_24H
# count   415.000000  415.000000          415.000000
# mean   2017.995181    8.115663           10.792771
# std       1.407357    3.308768            4.895571
# min    2016.000000    1.000000            1.000000
# 25%    2017.000000    6.000000            7.000000
# 50%    2018.000000    8.000000           10.000000
# 75%    2019.000000   10.000000           14.000000
# max    2020.000000   24.000000           32.000000

# %% [markdown]
# # PREDICCION DE NÚMERO DE ACCIDENTES

# %% [markdown]
# ### MODELO PROPHET

# %%
df_provincia2['y'] = df_provincia2['count']
df_provincia2['ds'] = pd.to_datetime(pd.to_datetime(df_provincia2['FECHA']).dt.date)

# %%
ts = df_provincia2[['ds', 'y']]
model = Prophet(
   yearly_seasonality=True,
   seasonality_mode=['additive','multiplicative'][0]
   ).add_country_holidays(country_name='ESP'
   ).fit(ts)

future = model.make_future_dataframe(periods=10)
forecast = model.predict(future)
fig1 = model.plot(forecast)
# Out:
# 18:43:09 - cmdstanpy - INFO - Chain [1] start processing
# 18:43:09 - cmdstanpy - INFO - Chain [1] done processing
# c:\Users\---\AppData\Local\Programs\Python\Python312\Lib\site-packages\prophet\plot.py:72: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   fcst_t = fcst['ds'].dt.to_pydatetime()
# c:\Users\---\AppData\Local\Programs\Python\Python312\Lib\site-packages\prophet\plot.py:73: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   ax.plot(m.history['ds'].dt.to_pydatetime(), m.history['y'], 'k.',

# %%
fig2 = model.plot_components(forecast)
# Out:
# c:\Users\---\AppData\Local\Programs\Python\Python312\Lib\site-packages\prophet\plot.py:228: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   fcst_t = fcst['ds'].dt.to_pydatetime()
# c:\Users\---\AppData\Local\Programs\Python\Python312\Lib\site-packages\prophet\plot.py:351: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   df_y['ds'].dt.to_pydatetime(), seas[name], ls='-', c='#0072B2')
# c:\Users\---\AppData\Local\Programs\Python\Python312\Lib\site-packages\prophet\plot.py:354: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   df_y['ds'].dt.to_pydatetime(), seas[name + '_lower'],

# %%
from prophet.diagnostics import cross_validation
df_cv = cross_validation(model, initial='336 days', period='84 days', horizon = '20 days')
# Out:
# Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
#   0%|          | 0/16 [00:00<?, ?it/s]18:43:11 - cmdstanpy - INFO - Chain [1] start processing
# 18:43:14 - cmdstanpy - INFO - Chain [1] done processing
#   6%|▋         | 1/16 [00:03<00:48,  3.23s/it]18:43:14 - cmdstanpy - INFO - Chain [1] start processing
# 18:43:14 - cmdstanpy - INFO - Chain [1] done processing
#  12%|█▎        | 2/16 [00:03<00:20,  1.48s/it]18:43:15 - cmdstanpy - INFO - Chain [1] start processing
# 18:43:15 - cmdstanpy - INFO - Chain [1] done processing
#  19%|█▉        | 3/16 [00:03<00:12,  1.08it/s]18:43:15 - cmdstanpy - INFO - Chain [1] start processing
# 18:43:15 - cmdstanpy - INFO - Chain [1] done processing
#  25%|██▌       | 4/16 [00:04<00:08,  1.46it/s]18:43:15 - cmdstanpy - INFO - Chain [1] start processing
# 18:43:15 - cmdstanpy - INFO - Chain [1] done processing
#  31%|███▏      | 5/16 [00:04<00:06,  1.79it/s]18:43:16 - cmdstanpy - INFO - Chain [1] start processing
# 18:43:16 - cmdstanpy - INFO - Chain [1] done processing
#  38%|███▊      | 6/16 [00:04<00:04,  2.18it/s]18:43:16 - cmdstanpy - INFO - Chain [1] start processing
# 18:43:16 - cmdstanpy - INFO - Chain [1] done processing
#  44%|████▍     | 7/16 [00:04<00:03,  2.52it/s]18:43:16 - cmdstanpy - INFO - Chain [1] start processing
# 18:43:16 - cmdstanpy - INFO - Chain [1] done processing
#  50%|█████     | 8/16 [00:05<00:02,  2.68it/s]18:43:17 - cmdstanpy - INFO - Chain [1] start processing
# 18:43:17 - cmdstanpy - INFO - Chain [1] done processing
#  56%|█████▋    | 9/16 [00:05<00:02,  2.69it/s]18:43:17 - cmdstanpy - INFO - Chain [1] start processing
# 18:43:17 - cmdstanpy - INFO - Chain [1] done processing
#  62%|██████▎   | 10/16 [00:05<00:02,  2.80it/s]18:43:17 - cmdstanpy - INFO - Chain [1] start processing
# 18:43:17 - cmdstanpy - INFO - Chain [1] done processing
#  69%|██████▉   | 11/16 [00:06<00:01,  2.97it/s]18:43:17 - cmdstanpy - INFO - Chain [1] start processing
# 18:43:18 - cmdstanpy - INFO - Chain [1] done processing
#  75%|███████▌  | 12/16 [00:06<00:01,  2.99it/s]18:43:18 - cmdstanpy - INFO - Chain [1] start processing
# 18:43:18 - cmdstanpy - INFO - Chain [1] done processing
#  81%|████████▏ | 13/16 [00:06<00:00,  3.12it/s]18:43:18 - cmdstanpy - INFO - Chain [1] start processing
# 18:43:18 - cmdstanpy - INFO - Chain [1] done processing
#  88%|████████▊ | 14/16 [00:07<00:00,  3.19it/s]18:43:18 - cmdstanpy - INFO - Chain [1] start processing
# 18:43:18 - cmdstanpy - INFO - Chain [1] done processing
#  94%|█████████▍| 15/16 [00:07<00:00,  3.20it/s]18:43:19 - cmdstanpy - INFO - Chain [1] start processing
# 18:43:19 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 16/16 [00:07<00:00,  2.06it/s]

# %%
from prophet.diagnostics import performance_metrics
df_p = performance_metrics(df_cv)

# %%
from prophet.plot import plot_cross_validation_metric
fig = plot_cross_validation_metric(df_cv, metric='mape') # MAPE ES EL ERROR ABSOLUTO (+-) PORCENTUAL
# Out:
# c:\Users\---\AppData\Local\Programs\Python\Python312\Lib\site-packages\prophet\plot.py:546: FutureWarning: Series.view is deprecated and will be removed in a future version. Use ``astype`` as an alternative to change the dtype.
#   x_plt = df_none['horizon'].astype('timedelta64[ns]').view(np.int64) / float(dt_conversions[i])
# c:\Users\---\AppData\Local\Programs\Python\Python312\Lib\site-packages\prophet\plot.py:547: FutureWarning: Series.view is deprecated and will be removed in a future version. Use ``astype`` as an alternative to change the dtype.
#   x_plt_h = df_h['horizon'].astype('timedelta64[ns]').view(np.int64) / float(dt_conversions[i])

# %%
df_provincia2.describe()
# Out:
#             ANYO_x       count  TOTAL_VICTIMAS_24H           y  \
# count   415.000000  415.000000          415.000000  415.000000
# mean   2017.995181    8.115663           10.792771    8.115663
# min    2016.000000    1.000000            1.000000    1.000000
# 25%    2017.000000    6.000000            7.000000    6.000000
# 50%    2018.000000    8.000000           10.000000    8.000000
# 75%    2019.000000   10.000000           14.000000   10.000000
# max    2020.000000   24.000000           32.000000   24.000000
# std       1.407357    3.308768            4.895571    3.308768
#
#                                   ds
# count                            415
# mean   2018-06-18 08:19:39.759036160
# min              2016-01-01 00:00:00
# 25%              2017-04-01 12:00:00
# 50%              2018-06-07 00:00:00
# 75%              2019-09-05 12:00:00
# max              2020-12-07 00:00:00
# std                              NaN

# %% [markdown]
# De acuerdo con los datos de validación de nuestro modelo de Prophet, se realiza una predicción anual donde hay periodos donde pueden ocurrir o 0 accidentes o el doble. En la gráfica están alrededor del 5º y 13º en adelante, que corresponden con viernes y sábado (es decir, le resulta dificil predecir la cantidad de accidentes por esas fechas).

# %% [markdown]
# ### MODELO REDES NEURONALES

# %%
PASOS=84
 
# convert series to supervised learning
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
    n_vars = 1 if type(data) is list else data.shape[1]
    df = pd.DataFrame(data)
    cols, names = list(), list()
    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
        else:
            names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
    # put it all together
    agg = pd.concat(cols, axis=1)
    agg.columns = names
    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    return agg
 
# load dataset
values = df_provincia2['count'].values
# ensure all data is float
values = values.astype('float32')
# normalize features
scaler = MinMaxScaler(feature_range=(-1, 1))
values=values.reshape(-1, 1) # esto lo hacemos porque tenemos 1 sola dimension
scaled = scaler.fit_transform(values)
# frame as supervised learning
reframed = series_to_supervised(scaled, PASOS, 1)
reframed.head()
# Out:
#     var1(t-84)  var1(t-83)  var1(t-82)  var1(t-81)  var1(t-80)  var1(t-79)  \
# 84   -0.391304   -0.391304   -0.391304   -0.478261   -0.478261   -0.565217
# 85   -0.391304   -0.391304   -0.478261   -0.478261   -0.565217   -0.739130
# 86   -0.391304   -0.478261   -0.478261   -0.565217   -0.739130    0.130435
# 87   -0.478261   -0.478261   -0.565217   -0.739130    0.130435   -0.043478
# 88   -0.478261   -0.565217   -0.739130    0.130435   -0.043478   -0.130435
#
#     var1(t-78)  var1(t-77)  var1(t-76)  var1(t-75)  ...  var1(t-9)  var1(t-8)  \
# 84   -0.739130    0.130435   -0.043478   -0.130435  ...  -0.652174  -0.217391
# 85    0.130435   -0.043478   -0.130435   -0.391304  ...  -0.217391  -0.304348
# 86   -0.043478   -0.130435   -0.391304   -0.565217  ...  -0.304348  -0.304348
# 87   -0.130435   -0.391304   -0.565217   -0.652174  ...  -0.304348  -0.391304
# 88   -0.391304   -0.565217   -0.652174   -0.217391  ...  -0.391304  -0.652174
#
#     var1(t-7)  var1(t-6)  var1(t-5)  var1(t-4)  var1(t-3)  var1(t-2)  \
# 84  -0.304348  -0.304348  -0.391304  -0.652174  -0.739130   0.043478
# 85  -0.304348  -0.391304  -0.652174  -0.739130   0.043478  -0.391304
# 86  -0.391304  -0.652174  -0.739130   0.043478  -0.391304  -0.478261
# 87  -0.652174  -0.739130   0.043478  -0.391304  -0.478261  -0.478261
# 88  -0.739130   0.043478  -0.391304  -0.478261  -0.478261  -0.478261
#
#     var1(t-1)   var1(t)
# 84  -0.391304 -0.478261
# 85  -0.478261 -0.478261
# 86  -0.478261 -0.478261
# 87  -0.478261 -0.565217
# 88  -0.565217 -0.565217
#
# [5 rows x 85 columns]

# %%
values = reframed.values
n_train_days = 320
train = values[:n_train_days, :]
test = values[n_train_days:, :]
# split isnto input and outputs
x_train, y_train = train[:, :-1], train[:, -1]
x_val, y_val = test[:, :-1], test[:, -1]
# reshape input to be 3D [samples, timesteps, features]
x_train = x_train.reshape((x_train.shape[0], 1, x_train.shape[1]))
x_val = x_val.reshape((x_val.shape[0], 1, x_val.shape[1]))
print(x_train.shape, y_train.shape, x_val.shape, y_val.shape)
# Out:
# (320, 1, 84) (320,) (11, 1, 84) (11,)

# %%
len(values)
# Out:
# 331

# %%
def crear_modeloFF():
    model = Sequential()
    model.add(Dense(PASOS, input_shape=(1,PASOS),activation='tanh'))
    model.add(Flatten())
    model.add(Dense(1, activation='tanh'))
    model.compile(loss='mse',optimizer='Adam',metrics=["mae"])
    model.summary()
    return model

# %%
EPOCHS=20

model = crear_modeloFF()
 
history=model.fit(x_train,y_train,epochs=EPOCHS,validation_data=(x_val,y_val),batch_size=PASOS)
# Out:
# c:\Users\---\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_6 (Dense)                 │ (None, 1, 84)          │         7,140 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_3 (Flatten)             │ (None, 84)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 1)              │            85 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 7,225 (28.22 KB)
#  Trainable params: 7,225 (28.22 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 103ms/step - loss: 0.2318 - mae: 0.3839 - val_loss: 0.1289 - val_mae: 0.3234
# Epoch 2/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.1836 - mae: 0.3392 - val_loss: 0.0722 - val_mae: 0.2350
# Epoch 3/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.1360 - mae: 0.2909 - val_loss: 0.0372 - val_mae: 0.1687
# Epoch 4/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1313 - mae: 0.2915 - val_loss: 0.0245 - val_mae: 0.1404
# Epoch 5/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.1067 - mae: 0.2513 - val_loss: 0.0516 - val_mae: 0.1825
# Epoch 6/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0981 - mae: 0.2426 - val_loss: 0.0297 - val_mae: 0.1613
# Epoch 7/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0770 - mae: 0.2167 - val_loss: 0.0421 - val_mae: 0.1662
# Epoch 8/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0690 - mae: 0.2060 - val_loss: 0.0359 - val_mae: 0.1690
# Epoch 9/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0635 - mae: 0.2029 - val_loss: 0.0359 - val_mae: 0.1681
# Epoch 10/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0590 - mae: 0.1914 - val_loss: 0.0463 - val_mae: 0.1729
# Epoch 11/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0599 - mae: 0.1936 - val_loss: 0.0343 - val_mae: 0.1604
# Epoch 12/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0559 - mae: 0.1827 - val_loss: 0.0336 - val_mae: 0.1581
# Epoch 13/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0517 - mae: 0.1790 - val_loss: 0.0331 - val_mae: 0.1482
# Epoch 14/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0519 - mae: 0.1782 - val_loss: 0.0297 - val_mae: 0.1397
# Epoch 15/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0500 - mae: 0.1722 - val_loss: 0.0278 - val_mae: 0.1345
# Epoch 16/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0486 - mae: 0.1705 - val_loss: 0.0261 - val_mae: 0.1318
# Epoch 17/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0413 - mae: 0.1592 - val_loss: 0.0249 - val_mae: 0.1283
# Epoch 18/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0441 - mae: 0.1610 - val_loss: 0.0240 - val_mae: 0.1191
# Epoch 19/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0431 - mae: 0.1608 - val_loss: 0.0243 - val_mae: 0.1320
# Epoch 20/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0421 - mae: 0.1584 - val_loss: 0.0216 - val_mae: 0.1188

# %%
results=model.predict(x_val)
plt.scatter(range(len(y_val)),y_val,c='g')
plt.scatter(range(len(results)),results,c='r')
plt.title('validate')
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step

# %%
loss = history.history['mae']
val_loss = history.history['val_mae']

# Graficar la función de pérdida durante el entrenamiento
epochs = range(1, len(loss) + 1)

plt.plot(epochs, loss, 'bo', label='Pérdida de entrenamiento')
plt.plot(epochs, val_loss, 'b', label='Pérdida de validación')
plt.title('Función de pérdida durante el entrenamiento')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
resultados_viajes = scaler.inverse_transform(results)
resultados_viajes
# Out:
# array([[ 8.875359 ],
#        [ 6.321109 ],
#        [ 4.3950496],
#        [ 3.8933828],
#        [12.192146 ],
#        [ 8.770803 ],
#        [ 8.955476 ],
#        [ 7.7465563],
#        [ 6.254176 ],
#        [ 3.8807795],
#        [ 4.4606743]], dtype=float32)

# %% [markdown]
# Si bien el modelo de redes neuronales hace una buena predicción, para el número de accidentes en cada día de la semana para los meses en un año, el modelo no tiene la mejor curva de aprendizaje, por lo que los resultados son poco confiables. Por otro lado, Prophet, es el que tiene un mejor rendimiento, aunque hay que tener cuidado en los meses de abril y diciembre, donde los resultados no son tan confiables. Por tanto nos quedaremos con el modelo de Prophet para futuras predicciones.

# %%
#Hacemos una predicción para una fecha 
fecha_viaje = '01/01/2020'
ultima_fecha = datetime.strptime('12/07/2019', '%d/%m/%Y').date()
fecha_viaje_correcto = datetime.strptime(fecha_viaje, '%d/%m/%Y').date()
diferencia = fecha_viaje_correcto - ultima_fecha
diferencia_dias = diferencia.days
diferencia_dias
# Out:
# 173

# %%
ultimos_datos = df_provincia2[: -PASOS*2]['count'].values
ultimos_valores = ultimos_datos.reshape(-1, 1)
datos_escalados = scaler.transform(ultimos_valores)
datos_supervisados = series_to_supervised(datos_escalados, PASOS, 1)
datos_supervisados.drop(datos_supervisados.columns[[PASOS]], axis = 1, inplace = True)
valores_pre = datos_supervisados.values
x_test = valores_pre[PASOS - 1:, :]
x_test = x_test.reshape((x_test.shape[0], 1, x_test.shape[1]))
def agregarNuevoValor(x_test,nuevoValor):
    for i in range(x_test.shape[2]-1):
        x_test[0][0][i] = x_test[0][0][i+1]
    x_test[0][0][x_test.shape[2]-1]=nuevoValor
    return x_test

results=[]
for i in range(diferencia_dias):
    parcial=model.predict(x_test)
    results.append(parcial[0])
    x_test=agregarNuevoValor(x_test,parcial[0])
results = [x for x in results]
datos_predichos = scaler.inverse_transform(results)
datos_predichos[-1]
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# C:\Users\---\AppData\Local\Temp\ipykernel_17760\1154682006.py:12: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   x_test[0][0][x_test.shape[2]-1]=nuevoValor
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 439us/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 757us/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 924us/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 786us/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 655us/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 852us/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 754us/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 950us/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 845us/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# array([6.67746838])

# %% [markdown]
# # PREDICCIÓN PARA EL NÚMERO DE VICTIMAS

# %% [markdown]
# ### MODELO PROPHET

# %% [markdown]
# CAMBIAR COUNT POR TOTAL_VICTIMAS_24H

# %%
df_provincia2['y'] = df_provincia2['TOTAL_VICTIMAS_24H']
df_provincia2['ds'] = pd.to_datetime(pd.to_datetime(df_provincia2['FECHA']).dt.date)

# %%
ts = df_provincia2[['ds', 'y']]
model = Prophet(
   yearly_seasonality=True,
   seasonality_mode=['additive','multiplicative'][0]
   ).add_country_holidays(country_name='ESP'
   ).fit(ts)

future = model.make_future_dataframe(periods=10)
forecast = model.predict(future)
fig1 = model.plot(forecast)
# Out:
# 18:43:38 - cmdstanpy - INFO - Chain [1] start processing
# 18:43:38 - cmdstanpy - INFO - Chain [1] done processing
# c:\Users\---\AppData\Local\Programs\Python\Python312\Lib\site-packages\prophet\plot.py:72: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   fcst_t = fcst['ds'].dt.to_pydatetime()
# c:\Users\---\AppData\Local\Programs\Python\Python312\Lib\site-packages\prophet\plot.py:73: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   ax.plot(m.history['ds'].dt.to_pydatetime(), m.history['y'], 'k.',

# %%
fig2 = model.plot_components(forecast)
# Out:
# c:\Users\---\AppData\Local\Programs\Python\Python312\Lib\site-packages\prophet\plot.py:228: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   fcst_t = fcst['ds'].dt.to_pydatetime()
# c:\Users\---\AppData\Local\Programs\Python\Python312\Lib\site-packages\prophet\plot.py:351: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   df_y['ds'].dt.to_pydatetime(), seas[name], ls='-', c='#0072B2')
# c:\Users\---\AppData\Local\Programs\Python\Python312\Lib\site-packages\prophet\plot.py:354: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   df_y['ds'].dt.to_pydatetime(), seas[name + '_lower'],

# %%
from prophet.diagnostics import cross_validation
df_cv = cross_validation(model, initial='336 days', period='84 days', horizon = '20 days')
# Out:
# Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
#   0%|          | 0/16 [00:00<?, ?it/s]18:43:40 - cmdstanpy - INFO - Chain [1] start processing
# 18:43:40 - cmdstanpy - INFO - Chain [1] done processing
#   6%|▋         | 1/16 [00:00<00:10,  1.38it/s]18:43:40 - cmdstanpy - INFO - Chain [1] start processing
# 18:43:40 - cmdstanpy - INFO - Chain [1] done processing
#  12%|█▎        | 2/16 [00:00<00:05,  2.34it/s]18:43:41 - cmdstanpy - INFO - Chain [1] start processing
# 18:43:41 - cmdstanpy - INFO - Chain [1] done processing
#  19%|█▉        | 3/16 [00:01<00:04,  2.97it/s]18:43:41 - cmdstanpy - INFO - Chain [1] start processing
# 18:43:41 - cmdstanpy - INFO - Chain [1] done processing
#  25%|██▌       | 4/16 [00:01<00:03,  3.20it/s]18:43:41 - cmdstanpy - INFO - Chain [1] start processing
# 18:43:41 - cmdstanpy - INFO - Chain [1] done processing
#  31%|███▏      | 5/16 [00:01<00:03,  3.35it/s]18:43:41 - cmdstanpy - INFO - Chain [1] start processing
# 18:43:41 - cmdstanpy - INFO - Chain [1] done processing
#  38%|███▊      | 6/16 [00:01<00:02,  3.56it/s]18:43:42 - cmdstanpy - INFO - Chain [1] start processing
# 18:43:42 - cmdstanpy - INFO - Chain [1] done processing
#  44%|████▍     | 7/16 [00:02<00:02,  3.81it/s]18:43:42 - cmdstanpy - INFO - Chain [1] start processing
# 18:43:42 - cmdstanpy - INFO - Chain [1] done processing
#  50%|█████     | 8/16 [00:02<00:02,  3.78it/s]18:43:42 - cmdstanpy - INFO - Chain [1] start processing
# 18:43:42 - cmdstanpy - INFO - Chain [1] done processing
#  56%|█████▋    | 9/16 [00:02<00:01,  3.62it/s]18:43:42 - cmdstanpy - INFO - Chain [1] start processing
# 18:43:43 - cmdstanpy - INFO - Chain [1] done processing
#  62%|██████▎   | 10/16 [00:03<00:01,  3.40it/s]18:43:43 - cmdstanpy - INFO - Chain [1] start processing
# 18:43:43 - cmdstanpy - INFO - Chain [1] done processing
#  69%|██████▉   | 11/16 [00:03<00:01,  3.66it/s]18:43:43 - cmdstanpy - INFO - Chain [1] start processing
# 18:43:43 - cmdstanpy - INFO - Chain [1] done processing
#  75%|███████▌  | 12/16 [00:03<00:01,  3.58it/s]18:43:43 - cmdstanpy - INFO - Chain [1] start processing
# 18:43:43 - cmdstanpy - INFO - Chain [1] done processing
#  81%|████████▏ | 13/16 [00:03<00:00,  3.35it/s]18:43:44 - cmdstanpy - INFO - Chain [1] start processing
# 18:43:44 - cmdstanpy - INFO - Chain [1] done processing
#  88%|████████▊ | 14/16 [00:04<00:00,  3.36it/s]18:43:44 - cmdstanpy - INFO - Chain [1] start processing
# 18:43:44 - cmdstanpy - INFO - Chain [1] done processing
#  94%|█████████▍| 15/16 [00:04<00:00,  3.39it/s]18:43:44 - cmdstanpy - INFO - Chain [1] start processing
# 18:43:44 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 16/16 [00:04<00:00,  3.29it/s]

# %%
from prophet.diagnostics import performance_metrics
df_p = performance_metrics(df_cv)

# %%
from prophet.plot import plot_cross_validation_metric
fig = plot_cross_validation_metric(df_cv, metric='mape') # MAPE ES EL ERROR ABSOLUTO (+-) PORCENTUAL
# Out:
# c:\Users\---\AppData\Local\Programs\Python\Python312\Lib\site-packages\prophet\plot.py:546: FutureWarning: Series.view is deprecated and will be removed in a future version. Use ``astype`` as an alternative to change the dtype.
#   x_plt = df_none['horizon'].astype('timedelta64[ns]').view(np.int64) / float(dt_conversions[i])
# c:\Users\---\AppData\Local\Programs\Python\Python312\Lib\site-packages\prophet\plot.py:547: FutureWarning: Series.view is deprecated and will be removed in a future version. Use ``astype`` as an alternative to change the dtype.
#   x_plt_h = df_h['horizon'].astype('timedelta64[ns]').view(np.int64) / float(dt_conversions[i])

# %%
df_provincia2.describe()
# Out:
#             ANYO_x       count  TOTAL_VICTIMAS_24H           y  \
# count   415.000000  415.000000          415.000000  415.000000
# mean   2017.995181    8.115663           10.792771   10.792771
# min    2016.000000    1.000000            1.000000    1.000000
# 25%    2017.000000    6.000000            7.000000    7.000000
# 50%    2018.000000    8.000000           10.000000   10.000000
# 75%    2019.000000   10.000000           14.000000   14.000000
# max    2020.000000   24.000000           32.000000   32.000000
# std       1.407357    3.308768            4.895571    4.895571
#
#                                   ds
# count                            415
# mean   2018-06-18 08:19:39.759036160
# min              2016-01-01 00:00:00
# 25%              2017-04-01 12:00:00
# 50%              2018-06-07 00:00:00
# 75%              2019-09-05 12:00:00
# max              2020-12-07 00:00:00
# std                              NaN

# %% [markdown]
# ### MODELO REDES NEURONALES

# %%
PASOS=84
 
# convert series to supervised learning
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
    n_vars = 1 if type(data) is list else data.shape[1]
    df = pd.DataFrame(data)
    cols, names = list(), list()
    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
        else:
            names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
    # put it all together
    agg = pd.concat(cols, axis=1)
    agg.columns = names
    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    return agg
 
# load dataset
values = df_provincia2['TOTAL_VICTIMAS_24H'].values
# ensure all data is float
values = values.astype('float32')
# normalize features
scaler = MinMaxScaler(feature_range=(-1, 1))
values=values.reshape(-1, 1) # esto lo hacemos porque tenemos 1 sola dimension
scaled = scaler.fit_transform(values)
# frame as supervised learning
reframed = series_to_supervised(scaled, PASOS, 1)
reframed.head()
# Out:
#     var1(t-84)  var1(t-83)  var1(t-82)  var1(t-81)  var1(t-80)  var1(t-79)  \
# 84   -0.096774   -0.032258   -0.032258   -0.354839   -0.290323   -0.548387
# 85   -0.032258   -0.032258   -0.354839   -0.290323   -0.548387   -0.806452
# 86   -0.032258   -0.354839   -0.290323   -0.548387   -0.806452   -0.096774
# 87   -0.354839   -0.290323   -0.548387   -0.806452   -0.096774   -0.161290
# 88   -0.290323   -0.548387   -0.806452   -0.096774   -0.161290   -0.096774
#
#     var1(t-78)  var1(t-77)  var1(t-76)  var1(t-75)  ...  var1(t-9)  var1(t-8)  \
# 84   -0.806452   -0.096774   -0.161290   -0.096774  ...  -0.677419  -0.290323
# 85   -0.096774   -0.161290   -0.096774   -0.354839  ...  -0.290323  -0.161290
# 86   -0.161290   -0.096774   -0.354839   -0.290323  ...  -0.161290  -0.483871
# 87   -0.096774   -0.354839   -0.290323   -0.612903  ...  -0.483871  -0.548387
# 88   -0.354839   -0.290323   -0.612903   -0.161290  ...  -0.548387  -0.612903
#
#     var1(t-7)  var1(t-6)  var1(t-5)  var1(t-4)  var1(t-3)  var1(t-2)  \
# 84  -0.161290  -0.483871  -0.548387  -0.612903  -0.548387  -0.032258
# 85  -0.483871  -0.548387  -0.612903  -0.548387  -0.032258  -0.354839
# 86  -0.548387  -0.612903  -0.548387  -0.032258  -0.354839  -0.548387
# 87  -0.612903  -0.548387  -0.032258  -0.354839  -0.548387  -0.483871
# 88  -0.548387  -0.032258  -0.354839  -0.548387  -0.483871  -0.548387
#
#     var1(t-1)   var1(t)
# 84  -0.354839 -0.548387
# 85  -0.548387 -0.483871
# 86  -0.483871 -0.548387
# 87  -0.548387 -0.290323
# 88  -0.290323 -0.483871
#
# [5 rows x 85 columns]

# %%
values = reframed.values
n_train_days = 320
train = values[:n_train_days, :]
test = values[n_train_days:, :]
# split isnto input and outputs
x_train, y_train = train[:, :-1], train[:, -1]
x_val, y_val = test[:, :-1], test[:, -1]
# reshape input to be 3D [samples, timesteps, features]
x_train = x_train.reshape((x_train.shape[0], 1, x_train.shape[1]))
x_val = x_val.reshape((x_val.shape[0], 1, x_val.shape[1]))
print(x_train.shape, y_train.shape, x_val.shape, y_val.shape)
# Out:
# (320, 1, 84) (320,) (11, 1, 84) (11,)

# %%
len(values)
# Out:
# 331

# %%
def crear_modeloFF():
    model = Sequential()
    model.add(Dense(PASOS, input_shape=(1,PASOS),activation='tanh'))
    model.add(Flatten())
    model.add(Dense(1, activation='tanh'))
    model.compile(loss='mse',optimizer='Adam',metrics=["mae"])
    model.summary()
    return model

# %%
EPOCHS=20

model = crear_modeloFF()
 
history=model.fit(x_train,y_train,epochs=EPOCHS,validation_data=(x_val,y_val),batch_size=PASOS)
# Out:
# c:\Users\---\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_8 (Dense)                 │ (None, 1, 84)          │         7,140 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_4 (Flatten)             │ (None, 84)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 1)              │            85 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 7,225 (28.22 KB)
#  Trainable params: 7,225 (28.22 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 108ms/step - loss: 0.3476 - mae: 0.4718 - val_loss: 0.1954 - val_mae: 0.3640
# Epoch 2/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.2211 - mae: 0.3722 - val_loss: 0.2542 - val_mae: 0.4488
# Epoch 3/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.2411 - mae: 0.3897 - val_loss: 0.1494 - val_mae: 0.3027
# Epoch 4/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.1300 - mae: 0.2816 - val_loss: 0.0803 - val_mae: 0.2224
# Epoch 5/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.1382 - mae: 0.2991 - val_loss: 0.0802 - val_mae: 0.2243
# Epoch 6/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1141 - mae: 0.2696 - val_loss: 0.0970 - val_mae: 0.2235
# Epoch 7/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.1049 - mae: 0.2473 - val_loss: 0.1194 - val_mae: 0.2607
# Epoch 8/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0983 - mae: 0.2380 - val_loss: 0.0740 - val_mae: 0.2150
# Epoch 9/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0905 - mae: 0.2350 - val_loss: 0.0588 - val_mae: 0.2109
# Epoch 10/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0838 - mae: 0.2337 - val_loss: 0.0630 - val_mae: 0.2125
# Epoch 11/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0782 - mae: 0.2163 - val_loss: 0.0826 - val_mae: 0.2178
# Epoch 12/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0686 - mae: 0.2015 - val_loss: 0.0649 - val_mae: 0.2121
# Epoch 13/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0643 - mae: 0.1991 - val_loss: 0.0545 - val_mae: 0.2079
# Epoch 14/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0693 - mae: 0.2116 - val_loss: 0.0586 - val_mae: 0.2100
# Epoch 15/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0641 - mae: 0.1990 - val_loss: 0.0640 - val_mae: 0.2109
# Epoch 16/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0629 - mae: 0.1934 - val_loss: 0.0552 - val_mae: 0.2087
# Epoch 17/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0612 - mae: 0.1955 - val_loss: 0.0541 - val_mae: 0.2078
# Epoch 18/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0548 - mae: 0.1891 - val_loss: 0.0585 - val_mae: 0.2097
# Epoch 19/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0534 - mae: 0.1834 - val_loss: 0.0567 - val_mae: 0.2095
# Epoch 20/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0601 - mae: 0.1939 - val_loss: 0.0551 - val_mae: 0.2087

# %%
results=model.predict(x_val)
plt.scatter(range(len(y_val)),y_val,c='g')
plt.scatter(range(len(results)),results,c='r')
plt.title('validate')
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step

# %%
loss = history.history['mae']
val_loss = history.history['val_mae']

# Graficar la función de pérdida durante el entrenamiento
epochs = range(1, len(loss) + 1)

plt.plot(epochs, loss, 'bo', label='Pérdida de entrenamiento')
plt.plot(epochs, val_loss, 'b', label='Pérdida de validación')
plt.title('Función de pérdida durante el entrenamiento')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
resultados_viajes = scaler.inverse_transform(results)
resultados_viajes
# Out:
# array([[ 7.935646 ],
#        [ 8.089543 ],
#        [ 6.256635 ],
#        [ 8.69207  ],
#        [16.129139 ],
#        [ 8.265606 ],
#        [11.189628 ],
#        [ 8.444565 ],
#        [12.093792 ],
#        [ 7.8582735],
#        [ 7.6683145]], dtype=float32)

# %%
ultimos_datos = df_provincia2[: -PASOS*2]['TOTAL_VICTIMAS_24H'].values
ultimos_valores = ultimos_datos.reshape(-1, 1)
datos_escalados = scaler.transform(ultimos_valores)
datos_supervisados = series_to_supervised(datos_escalados, PASOS, 1)
datos_supervisados.drop(datos_supervisados.columns[[PASOS]], axis = 1, inplace = True)
valores_pre = datos_supervisados.values
x_test = valores_pre[PASOS - 1:, :]
x_test = x_test.reshape((x_test.shape[0], 1, x_test.shape[1]))
def agregarNuevoValor(x_test,nuevoValor):
    for i in range(x_test.shape[2]-1):
        x_test[0][0][i] = x_test[0][0][i+1]
    x_test[0][0][x_test.shape[2]-1]=nuevoValor
    return x_test
 
results=[]
for i in range(diferencia_dias):
    parcial=model.predict(x_test)
    results.append(parcial[0])
    x_test=agregarNuevoValor(x_test,parcial[0])
results = [x for x in results]
datos_predichos = scaler.inverse_transform(results)
datos_predichos[-1]
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# C:\Users\---\AppData\Local\Temp\ipykernel_17760\1904847402.py:12: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   x_test[0][0][x_test.shape[2]-1]=nuevoValor
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 961us/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 338us/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 776us/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 963us/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 657us/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 243us/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 974us/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 561us/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 960us/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 619us/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 736us/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# array([8.57952459])
