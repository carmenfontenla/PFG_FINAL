# %%
import pandas as pd
import numpy as np
import matplotlib.patches as mpatches
import matplotlib.pyplot as plt
import seaborn as sns
from prophet import Prophet
from sklearn.preprocessing import LabelEncoder
from datetime import datetime, timedelta
import statsmodels.api as sm
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import PowerTransformer
from scipy.stats import poisson
import datetime as dt
import matplotlib.pyplot as plt
import statsmodels as st
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.api import ExponentialSmoothing, SimpleExpSmoothing, Holt
import statsmodels.api as sm
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
import seaborn as sns
from tabulate import tabulate
import pmdarima as pm
from dateutil.relativedelta import relativedelta
from keras.models import Sequential
from keras.layers import Dense,Activation,Flatten
from sklearn.preprocessing import MinMaxScaler

# %%
df = pd.read_csv('Datos_preprocesados_accidentes_y_victimas_accidentes.csv')

# %%
db_provincia39 = df[df['COD_PROVINCIA'] == 39]

# %%
num_victimas_dia_semana39 = db_provincia39.groupby(['ANYO', 'MES', 'DIA_SEMANA', 'HORA'])['TOTAL_VICTIMAS_24H'].sum()

# %%
num_victimas_dia_semana39
# Out:
# ANYO  MES  DIA_SEMANA  HORA
# 2016  1    1           8       1
#                        10      2
#                        12      1
#                        13      1
#                        14      2
#                               ..
# 2020  12   6           21      1
#            7           10      1
#                        16      1
#                        20      1
#                        21      1
# Name: TOTAL_VICTIMAS_24H, Length: 2899, dtype: int64

# %%
num_accidentes_por_dia_semana39 = db_provincia39.groupby(['ANYO', 'MES'])['DIA_SEMANA'].value_counts()

# %%
num_accidentes_por_dia_semana39
# Out:
# ANYO  MES  DIA_SEMANA
# 2016  1    1             12
#            6             12
#            7             12
#            4             11
#            2              9
#                          ..
# 2020  12   2             11
#            5             11
#            3              9
#            7              4
#            6              3
# Name: count, Length: 418, dtype: int64

# %%
plt.plot(num_accidentes_por_dia_semana39.values)

# %%
plt.plot(num_victimas_dia_semana39.values)

# %%
num_accidentes_por_dia_semana39 = num_accidentes_por_dia_semana39.reset_index()

# %%
num_accidentes_por_dia_semana39['FECHA'] = num_accidentes_por_dia_semana39.apply(lambda row: str(row['ANYO']) + '/' + str(row['MES']) + '/' + str(row['DIA_SEMANA']), axis = 1)

# %%
num_accidentes_por_dia_semana39
# Out:
#      ANYO  MES  DIA_SEMANA  count      FECHA
# 0    2016    1           1     12   2016/1/1
# 1    2016    1           6     12   2016/1/6
# 2    2016    1           7     12   2016/1/7
# 3    2016    1           4     11   2016/1/4
# 4    2016    1           2      9   2016/1/2
# ..    ...  ...         ...    ...        ...
# 413  2020   12           2     11  2020/12/2
# 414  2020   12           5     11  2020/12/5
# 415  2020   12           3      9  2020/12/3
# 416  2020   12           7      4  2020/12/7
# 417  2020   12           6      3  2020/12/6
#
# [418 rows x 5 columns]

# %%
num_victimas_dia_semana39 = num_victimas_dia_semana39.reset_index()

# %%
num_victimas_dia_semana39
# Out:
#       ANYO  MES  DIA_SEMANA  HORA  TOTAL_VICTIMAS_24H
# 0     2016    1           1     8                   1
# 1     2016    1           1    10                   2
# 2     2016    1           1    12                   1
# 3     2016    1           1    13                   1
# 4     2016    1           1    14                   2
# ...    ...  ...         ...   ...                 ...
# 2894  2020   12           6    21                   1
# 2895  2020   12           7    10                   1
# 2896  2020   12           7    16                   1
# 2897  2020   12           7    20                   1
# 2898  2020   12           7    21                   1
#
# [2899 rows x 5 columns]

# %%
num_victimas_dia_semana39['FECHA'] = num_victimas_dia_semana39.apply(lambda row: str(row['ANYO']) + '/' + str(row['MES']) + '/' + str(row['DIA_SEMANA']), axis = 1)

# %%
num_victimas_dia_semana39
# Out:
#       ANYO  MES  DIA_SEMANA  HORA  TOTAL_VICTIMAS_24H      FECHA
# 0     2016    1           1     8                   1   2016/1/1
# 1     2016    1           1    10                   2   2016/1/1
# 2     2016    1           1    12                   1   2016/1/1
# 3     2016    1           1    13                   1   2016/1/1
# 4     2016    1           1    14                   2   2016/1/1
# ...    ...  ...         ...   ...                 ...        ...
# 2894  2020   12           6    21                   1  2020/12/6
# 2895  2020   12           7    10                   1  2020/12/7
# 2896  2020   12           7    16                   1  2020/12/7
# 2897  2020   12           7    20                   1  2020/12/7
# 2898  2020   12           7    21                   1  2020/12/7
#
# [2899 rows x 6 columns]

# %%
num_accidentes_por_dia_semana39
# Out:
#      ANYO  MES  DIA_SEMANA  count      FECHA
# 0    2016    1           1     12   2016/1/1
# 1    2016    1           6     12   2016/1/6
# 2    2016    1           7     12   2016/1/7
# 3    2016    1           4     11   2016/1/4
# 4    2016    1           2      9   2016/1/2
# ..    ...  ...         ...    ...        ...
# 413  2020   12           2     11  2020/12/2
# 414  2020   12           5     11  2020/12/5
# 415  2020   12           3      9  2020/12/3
# 416  2020   12           7      4  2020/12/7
# 417  2020   12           6      3  2020/12/6
#
# [418 rows x 5 columns]

# %%
num_victimas_dia_semana39
# Out:
#       ANYO  MES  DIA_SEMANA  HORA  TOTAL_VICTIMAS_24H      FECHA
# 0     2016    1           1     8                   1   2016/1/1
# 1     2016    1           1    10                   2   2016/1/1
# 2     2016    1           1    12                   1   2016/1/1
# 3     2016    1           1    13                   1   2016/1/1
# 4     2016    1           1    14                   2   2016/1/1
# ...    ...  ...         ...   ...                 ...        ...
# 2894  2020   12           6    21                   1  2020/12/6
# 2895  2020   12           7    10                   1  2020/12/7
# 2896  2020   12           7    16                   1  2020/12/7
# 2897  2020   12           7    20                   1  2020/12/7
# 2898  2020   12           7    21                   1  2020/12/7
#
# [2899 rows x 6 columns]

# %%
df_provincia39 = num_accidentes_por_dia_semana39.merge(num_victimas_dia_semana39, on = 'FECHA')

# %%
df_provincia39 = df_provincia39[['ANYO_x', 'FECHA', 'count', 'TOTAL_VICTIMAS_24H']]

# %%
df_provincia39.describe()
# Out:
#             ANYO_x        count  TOTAL_VICTIMAS_24H
# count  2899.000000  2899.000000         2899.000000
# mean   2018.060021    10.676095            1.926181
# std       1.425340     4.589756            1.465759
# min    2016.000000     1.000000            1.000000
# 25%    2017.000000     7.000000            1.000000
# 50%    2018.000000    10.000000            1.000000
# 75%    2019.000000    13.000000            2.000000
# max    2020.000000    24.000000           17.000000

# %% [markdown]
# ### MODELO PROPHET

# %%
df_provincia39['y'] = df_provincia39['count']
df_provincia39['ds'] = pd.to_datetime(pd.to_datetime(df_provincia39['FECHA']).dt.date)

# %%
ts = df_provincia39[['ds', 'y']]
model = Prophet(
   yearly_seasonality=True,
   seasonality_mode=['additive','multiplicative'][0]
   ).add_country_holidays(country_name='ESP'
   ).fit(ts)

future = model.make_future_dataframe(periods=10)
forecast = model.predict(future)
fig1 = model.plot(forecast)
# Out:
# 18:18:20 - cmdstanpy - INFO - Chain [1] start processing
# 18:18:21 - cmdstanpy - INFO - Chain [1] done processing
# c:\Users\---\AppData\Local\Programs\Python\Python312\Lib\site-packages\prophet\plot.py:72: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   fcst_t = fcst['ds'].dt.to_pydatetime()
# c:\Users\---\AppData\Local\Programs\Python\Python312\Lib\site-packages\prophet\plot.py:73: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   ax.plot(m.history['ds'].dt.to_pydatetime(), m.history['y'], 'k.',

# %%
fig2 = model.plot_components(forecast)
# Out:
# c:\Users\---\AppData\Local\Programs\Python\Python312\Lib\site-packages\prophet\plot.py:228: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   fcst_t = fcst['ds'].dt.to_pydatetime()
# c:\Users\---\AppData\Local\Programs\Python\Python312\Lib\site-packages\prophet\plot.py:351: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   df_y['ds'].dt.to_pydatetime(), seas[name], ls='-', c='#0072B2')
# c:\Users\---\AppData\Local\Programs\Python\Python312\Lib\site-packages\prophet\plot.py:354: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   df_y['ds'].dt.to_pydatetime(), seas[name + '_lower'],

# %% [markdown]
# ### MODELO REDES NEURONALES

# %%
PASOS=336
 
# convert series to supervised learning
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
    n_vars = 1 if type(data) is list else data.shape[1]
    df = pd.DataFrame(data)
    cols, names = list(), list()
    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
        else:
            names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
    # put it all together
    agg = pd.concat(cols, axis=1)
    agg.columns = names
    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    return agg
 
# load dataset
values = df_provincia39['count'].values
# ensure all data is float
values = values.astype('float32')
# normalize features
scaler = MinMaxScaler(feature_range=(-1, 1))
values=values.reshape(-1, 1) # esto lo hacemos porque tenemos 1 sola dimension
scaled = scaler.fit_transform(values)
# frame as supervised learning
reframed = series_to_supervised(scaled, PASOS, 1)
reframed.head()
# Out:
#      var1(t-336)  var1(t-335)  var1(t-334)  var1(t-333)  var1(t-332)  \
# 336    -0.043478    -0.043478    -0.043478    -0.043478    -0.043478
# 337    -0.043478    -0.043478    -0.043478    -0.043478    -0.043478
# 338    -0.043478    -0.043478    -0.043478    -0.043478    -0.043478
# 339    -0.043478    -0.043478    -0.043478    -0.043478    -0.043478
# 340    -0.043478    -0.043478    -0.043478    -0.043478    -0.043478
#
#      var1(t-331)  var1(t-330)  var1(t-329)  var1(t-328)  var1(t-327)  ...  \
# 336    -0.043478    -0.043478    -0.043478    -0.043478    -0.043478  ...
# 337    -0.043478    -0.043478    -0.043478    -0.043478    -0.043478  ...
# 338    -0.043478    -0.043478    -0.043478    -0.043478    -0.043478  ...
# 339    -0.043478    -0.043478    -0.043478    -0.043478    -0.043478  ...
# 340    -0.043478    -0.043478    -0.043478    -0.043478    -0.043478  ...
#
#      var1(t-9)  var1(t-8)  var1(t-7)  var1(t-6)  var1(t-5)  var1(t-4)  \
# 336  -0.217391  -0.304348  -0.304348  -0.304348  -0.304348  -0.304348
# 337  -0.304348  -0.304348  -0.304348  -0.304348  -0.304348  -0.304348
# 338  -0.304348  -0.304348  -0.304348  -0.304348  -0.304348  -0.304348
# 339  -0.304348  -0.304348  -0.304348  -0.304348  -0.304348  -0.304348
# 340  -0.304348  -0.304348  -0.304348  -0.304348  -0.304348  -0.565217
#
#      var1(t-3)  var1(t-2)  var1(t-1)   var1(t)
# 336  -0.304348  -0.304348  -0.304348 -0.565217
# 337  -0.304348  -0.304348  -0.565217 -0.565217
# 338  -0.304348  -0.565217  -0.565217 -0.565217
# 339  -0.565217  -0.565217  -0.565217 -0.565217
# 340  -0.565217  -0.565217  -0.565217 -0.565217
#
# [5 rows x 337 columns]

# %%
values = reframed.values
n_train_days = 2399
train = values[:n_train_days, :]
test = values[n_train_days:, :]
# split isnto input and outputs
x_train, y_train = train[:, :-1], train[:, -1]
x_val, y_val = test[:, :-1], test[:, -1]
# reshape input to be 3D [samples, timesteps, features]
x_train = x_train.reshape((x_train.shape[0], 1, x_train.shape[1]))
x_val = x_val.reshape((x_val.shape[0], 1, x_val.shape[1]))
print(x_train.shape, y_train.shape, x_val.shape, y_val.shape)
# Out:
# (2399, 1, 336) (2399,) (164, 1, 336) (164,)

# %%
len(values)
# Out:
# 2563

# %%
def crear_modeloFF():
    model = Sequential()
    model.add(Dense(PASOS, input_shape=(1,PASOS),activation='tanh'))
    model.add(Flatten())
    model.add(Dense(1, activation='tanh'))
    model.compile(loss='mean_absolute_error',optimizer='Adam',metrics=["mse"])
    model.summary()
    return model

# %%
EPOCHS=40

model = crear_modeloFF()
 
history=model.fit(x_train,y_train,epochs=EPOCHS,validation_data=(x_val,y_val),batch_size=PASOS)
# Out:
# c:\Users\---\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 1, 336)         │       113,232 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 336)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │           337 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 113,569 (443.63 KB)
#  Trainable params: 113,569 (443.63 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/40
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.6221 - mse: 0.5270 - val_loss: 0.5874 - val_mse: 0.4934
# Epoch 2/40
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.5273 - mse: 0.3850 - val_loss: 0.5175 - val_mse: 0.3946
# Epoch 3/40
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.4088 - mse: 0.2511 - val_loss: 0.3096 - val_mse: 0.1511
# Epoch 4/40
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.2633 - mse: 0.1206 - val_loss: 0.2562 - val_mse: 0.1005
# Epoch 5/40
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.1870 - mse: 0.0667 - val_loss: 0.2125 - val_mse: 0.0799
# Epoch 6/40
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.1574 - mse: 0.0515 - val_loss: 0.1852 - val_mse: 0.0628
# Epoch 7/40
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.1514 - mse: 0.0454 - val_loss: 0.1538 - val_mse: 0.0469
# Epoch 8/40
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.1205 - mse: 0.0356 - val_loss: 0.1502 - val_mse: 0.0467
# Epoch 9/40
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.1184 - mse: 0.0322 - val_loss: 0.1340 - val_mse: 0.0420
# Epoch 10/40
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.1241 - mse: 0.0358 - val_loss: 0.1270 - val_mse: 0.0356
# Epoch 11/40
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.1323 - mse: 0.0373 - val_loss: 0.1278 - val_mse: 0.0384
# Epoch 12/40
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.1054 - mse: 0.0274 - val_loss: 0.1103 - val_mse: 0.0326
# Epoch 13/40
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.1013 - mse: 0.0259 - val_loss: 0.1171 - val_mse: 0.0341
# Epoch 14/40
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0885 - mse: 0.0267 - val_loss: 0.1122 - val_mse: 0.0331
# Epoch 15/40
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0909 - mse: 0.0248 - val_loss: 0.1149 - val_mse: 0.0337
# Epoch 16/40
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0886 - mse: 0.0218 - val_loss: 0.1135 - val_mse: 0.0322
# Epoch 17/40
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.1003 - mse: 0.0278 - val_loss: 0.0985 - val_mse: 0.0271
# Epoch 18/40
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0861 - mse: 0.0224 - val_loss: 0.1107 - val_mse: 0.0314
# Epoch 19/40
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0807 - mse: 0.0217 - val_loss: 0.0995 - val_mse: 0.0280
# Epoch 20/40
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0799 - mse: 0.0219 - val_loss: 0.1147 - val_mse: 0.0313
# Epoch 21/40
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0800 - mse: 0.0241 - val_loss: 0.1007 - val_mse: 0.0269
# Epoch 22/40
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0795 - mse: 0.0225 - val_loss: 0.1084 - val_mse: 0.0293
# Epoch 23/40
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0792 - mse: 0.0228 - val_loss: 0.0934 - val_mse: 0.0261
# Epoch 24/40
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0795 - mse: 0.0235 - val_loss: 0.1093 - val_mse: 0.0296
# Epoch 25/40
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0707 - mse: 0.0171 - val_loss: 0.0869 - val_mse: 0.0247
# Epoch 26/40
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0672 - mse: 0.0190 - val_loss: 0.0890 - val_mse: 0.0252
# Epoch 27/40
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.1091 - mse: 0.0294 - val_loss: 0.1137 - val_mse: 0.0304
# Epoch 28/40
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.1260 - mse: 0.0343 - val_loss: 0.0891 - val_mse: 0.0268
# Epoch 29/40
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0883 - mse: 0.0248 - val_loss: 0.0851 - val_mse: 0.0247
# Epoch 30/40
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0872 - mse: 0.0217 - val_loss: 0.1131 - val_mse: 0.0296
# Epoch 31/40
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.1112 - mse: 0.0269 - val_loss: 0.1005 - val_mse: 0.0274
# Epoch 32/40
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0841 - mse: 0.0221 - val_loss: 0.1346 - val_mse: 0.0369
# Epoch 33/40
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.1180 - mse: 0.0300 - val_loss: 0.1090 - val_mse: 0.0292
# Epoch 34/40
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0852 - mse: 0.0222 - val_loss: 0.1146 - val_mse: 0.0306
# Epoch 35/40
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0820 - mse: 0.0232 - val_loss: 0.0971 - val_mse: 0.0268
# Epoch 36/40
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0700 - mse: 0.0177 - val_loss: 0.0966 - val_mse: 0.0264
# Epoch 37/40
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.1009 - mse: 0.0233 - val_loss: 0.1052 - val_mse: 0.0292
# Epoch 38/40
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0772 - mse: 0.0206 - val_loss: 0.0989 - val_mse: 0.0277
# Epoch 39/40
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0713 - mse: 0.0232 - val_loss: 0.1004 - val_mse: 0.0265
# Epoch 40/40
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0743 - mse: 0.0209 - val_loss: 0.1041 - val_mse: 0.0282

# %%
results=model.predict(x_val)
plt.scatter(range(len(y_val)),y_val,c='g')
plt.scatter(range(len(results)),results,c='r')
plt.title('validate')
plt.show()
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']

# Graficar la función de pérdida durante el entrenamiento
epochs = range(1, len(loss) + 1)

plt.plot(epochs, loss, 'bo', label='Pérdida de entrenamiento')
plt.plot(epochs, val_loss, 'b', label='Pérdida de validación')
plt.title('Función de pérdida durante el entrenamiento')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
resultados_viajes = scaler.inverse_transform(results)
resultados_viajes
# Out:
# array([[ 6.0037527],
#        [ 5.884872 ],
#        [ 5.958721 ],
#        [ 5.4002104],
#        [ 5.5854096],
#        [ 5.6213493],
#        [ 5.5312304],
#        [ 5.8094254],
#        [18.66274  ],
#        [18.82578  ],
#        [19.079144 ],
#        [19.61135  ],
#        [19.944763 ],
#        [19.759113 ],
#        [20.316496 ],
#        [19.595425 ],
#        [19.998196 ],
#        [19.997347 ],
#        [20.081268 ],
#        [19.473902 ],
#        [20.236786 ],
#        [18.549082 ],
#        [18.294378 ],
#        [17.572926 ],
#        [17.918234 ],
#        [17.944382 ],
#        [16.557981 ],
#        [16.914965 ],
#        [16.893726 ],
#        [17.654854 ],
#        [17.669628 ],
#        [17.256361 ],
#        [17.025106 ],
#        [15.927322 ],
#        [16.43139  ],
#        [15.5851755],
#        [16.021595 ],
#        [14.948215 ],
#        [15.962729 ],
#        [15.757918 ],
#        [16.208082 ],
#        [16.20321  ],
#        [14.801508 ],
#        [13.073272 ],
#        [13.73285  ],
#        [14.651247 ],
#        [15.732757 ],
#        [15.064836 ],
#        [15.637799 ],
#        [15.4157715],
#        [15.409734 ],
#        [14.83815  ],
#        [13.811676 ],
#        [ 8.393194 ],
#        [ 8.315195 ],
#        [ 8.723264 ],
#        [ 8.422917 ],
#        [ 8.244922 ],
#        [ 8.639329 ],
#        [ 7.4491034],
#        [ 6.796154 ],
#        [ 7.407385 ],
#        [ 8.1054125],
#        [ 7.5759273],
#        [ 7.212031 ],
#        [ 7.1299367],
#        [ 4.5341797],
#        [ 3.7660906],
#        [ 4.307366 ],
#        [ 4.6530714],
#        [13.040279 ],
#        [14.066147 ],
#        [14.0999565],
#        [14.432482 ],
#        [13.583547 ],
#        [14.628083 ],
#        [15.209625 ],
#        [15.396172 ],
#        [12.009751 ],
#        [11.861748 ],
#        [12.466429 ],
#        [12.9730215],
#        [13.531377 ],
#        [13.433822 ],
#        [13.891847 ],
#        [13.200844 ],
#        [13.619737 ],
#        [10.627142 ],
#        [10.261147 ],
#        [10.338707 ],
#        [10.198669 ],
#        [10.202222 ],
#        [ 9.984909 ],
#        [ 9.41077  ],
#        [10.227245 ],
#        [ 9.608783 ],
#        [10.249518 ],
#        [ 9.579541 ],
#        [ 8.731618 ],
#        [ 7.7089324],
#        [ 7.84947  ],
#        [ 7.8077116],
#        [ 8.3670435],
#        [ 7.26296  ],
#        [ 7.318431 ],
#        [ 7.5794005],
#        [ 6.690949 ],
#        [ 6.110939 ],
#        [ 6.963656 ],
#        [ 7.0960646],
#        [ 7.3262796],
#        [ 5.5791826],
#        [ 5.915567 ],
#        [ 5.1110573],
#        [ 5.522137 ],
#        [14.773138 ],
#        [15.54579  ],
#        [16.034428 ],
#        [15.871587 ],
#        [15.568637 ],
#        [15.454704 ],
#        [16.004572 ],
#        [15.504923 ],
#        [15.569162 ],
#        [15.670216 ],
#        [14.523898 ],
#        [14.706923 ],
#        [14.255657 ],
#        [14.920383 ],
#        [15.276738 ],
#        [13.543663 ],
#        [13.997614 ],
#        [14.114642 ],
#        [ 9.901428 ],
#        [ 9.432149 ],
#        [ 9.902352 ],
#        [10.57948  ],
#        [10.739293 ],
#        [11.084871 ],
#        [10.514668 ],
#        [10.045231 ],
#        [ 9.439942 ],
#        [ 9.128651 ],
#        [ 9.6348715],
#        [10.084224 ],
#        [10.756929 ],
#        [11.00231  ],
#        [10.3503685],
#        [10.748733 ],
#        [ 8.625582 ],
#        [ 7.9423666],
#        [ 7.584278 ],
#        [ 8.700271 ],
#        [ 8.335781 ],
#        [ 8.023228 ],
#        [ 8.001515 ],
#        [ 7.961508 ],
#        [ 7.702544 ],
#        [ 4.724443 ],
#        [ 4.271876 ],
#        [ 4.3861547],
#        [ 4.1479425],
#        [ 3.437418 ],
#        [ 3.4166362]], dtype=float32)
